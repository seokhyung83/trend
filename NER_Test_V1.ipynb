# %%
import pymysql, os, copy, json, time, openpyxl
import pandas as pd
import argparse
import numpy as np
import matplotlib.pyplot as plt
import torch
import re
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm import tqdm
from kss import kss
from pororo import Pororo
from konlpy.tag import Mecab
import pickle

# %%
def _call_db_info():
    return pymysql.connect(
        host = 'trend.cb7jqghocrtb.ap-northeast-2.rds.amazonaws.com',
        port= 3306,
        user = 'root',
        password='ensol2020!',
        db = 'trend',
        charset = 'utf8')
def extract_parenthese(str):
    items_lst = re.findall('\(([^)]+)', str) #extracts string in () 
    newList = [x for x in items_lst if len(x)>=2] # more than 2
    return newList

def extract_quotes(str):
    items_lst = re.findall('"([^"]*)"', str)
    return items_lst

def parentheses_(tmp_input_sent):    
    tmp_input_sent = re.sub(pattern='\(+', repl=' ', string=tmp_input_sent)#tmp_input_sent = re.sub(pattern='\(\(', repl='\(', string=tmp_input_sent)
    tmp_input_sent = re.sub(pattern='\)+', repl=' ', string=tmp_input_sent)#tmp_input_sent = re.sub(pattern='\)\)', repl='\)', string=tmp_input_sent)
    tmp_input_sent = re.sub(pattern=' +', repl=' ', string=tmp_input_sent)
    input_sent = re.sub(pattern='\\\\',   repl='', string=tmp_input_sent)
    return input_sent
    '''
    m = []
    for i in range(0, len(s_m)):
        if s_m[i][1] < e_m[i][0]:
            m.append((s_m[i], e_m[i]))
        else:
            for j in range(i+1, len(e_m)):
                if s_m[i][1] < e_m[j][0]:
                    m.append((s_m[i], e_m[j]))
                    break;

    if len(m) > 0:
        for i in range(0, len(m)):
            if i == 0:
                tmp_sent1.append(input_sent[:m[i][0][0]])
            else :
                tmp_sent1.append(input_sent[m[(i-1)][1][1]:m[i][0][0]])                        
            tmp_sent2.append(input_sent[m[i][0][1]:m[i][1][0]])
        tmp_sent1.append(input_sent[m[-1][1][1]:])    
        return ' '.join(tmp_sent1 + tmp_sent2)
    else:
        return input_sent
    '''
    
def token_generate(sent, tok, MAX_LEN):
    encode_dict = tok.encode_plus(text=sent, 
                                    add_special_tokens=True, max_length=MAX_LEN,
                                    return_token_type_ids=True, padding='max_length', #pad_to_max_length=True,
                                    return_attention_mask=True, truncation=True) # return_tensors='pt',

    input_id = encode_dict['input_ids']
    attention_mask = encode_dict['attention_mask']
    token_type_id = encode_dict['token_type_ids']
    return input_id, attention_mask, token_type_id 

def _read_file(input_file):
    with open(input_file, "r", encoding="utf-8") as f:
        sentences = []
        labels = []
        for line in f:
            split_line = line.strip().split('\t')
            sentences.append(split_line[0])
            labels.append(split_line[1])
        return sentences, labels
    
def eval_input(test, token, args, pad_token_label_id, mask_padding_with_zero = True):

    words = test.split()
    tokens = []
    slot_label_mask = []
    for word in words:
        word = word.strip()
        word_tokens = token.tokenize(word)
        if not word_tokens:
            word_tokens = [unk_token]  # For handling the bad-encoded word
        tokens.extend(word_tokens)
        slot_label_mask.extend([0] + [pad_token_label_id] * (len(word_tokens) - 1))

    # Account for [CLS] and [SEP]
    special_tokens_count = 2
    if len(tokens) > args.max_seq_len - special_tokens_count:
        slot_label_mask = slot_label_mask[:(args.max_seq_len - special_tokens_count)]

    # Add [SEP] token
    slot_label_mask += [pad_token_label_id]
    slot_label_mask = [pad_token_label_id] + slot_label_mask
    padding_length = args.max_seq_len - len(slot_label_mask)
    slot_label_mask = slot_label_mask + ([pad_token_label_id] * padding_length)
    input_id, attention_mask, token_type_id = token_generate(test, token, args.max_seq_len)

    input_ids = torch.tensor(input_id, dtype=torch.long).reshape(1,-1)
    attention_mask = torch.tensor(attention_mask, dtype=torch.long).reshape(1,-1)
    token_type_ids = torch.tensor(token_type_id, dtype=torch.long).reshape(1,-1)
    slot_label_mask = torch.tensor(slot_label_mask, dtype=torch.long).reshape(1,-1)
    
    return input_ids, attention_mask, token_type_ids, slot_label_mask

# %%
from transformers import BertForTokenClassification
from tokenization_kobert import KoBertTokenizer
from transformers import AutoModelForTokenClassification

# %%
device = "cuda" if torch.cuda.is_available() else "cpu" #"cpu"#
model = AutoModelForTokenClassification.from_pretrained('./save/epoch400/')#'monologg/kobert')#, num_labels=len(train_label_l1))
token = KoBertTokenizer.from_pretrained('monologg/kobert')
model.to(device)
model.eval()
print("Model Loaded")

args = argparse.Namespace(  
    max_seq_len = 128
)
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BertTokenizer'.
# The class this function is called from is 'KoBertTokenizer'.
# Model Loaded

# %% [raw]
# conn = _call_db_info()
# curs = conn.cursor()
# tmp_insert_sql = "select * from content where date >= 20210701"#"select * from word_dic"
# curs.execute(tmp_insert_sql)
# tmp_article = pd.DataFrame(curs.fetchall())
# conn.commit()
# conn.close()

# %%
def eval_ft(test_sent, label_lst_, model_, tok, dev, args):
    preds = None
    pad_token = torch.nn.CrossEntropyLoss().ignore_index    
    with torch.no_grad():
        tmp_input, tmp_attention, tmp_token, tmp_slot = eval_input(test_sent, tok, args, pad_token)    
        inputs = {'input_ids':tmp_input.to(device), 'attention_mask':tmp_attention.to(device), 
                  'labels' : None,
                  'token_type_ids': tmp_token.to(device)}
        output = model_(**inputs)
        logits = output[0]

        if preds is None:
            preds = logits.detach().cpu().numpy()
        else:
            preds = np.append(preds, logits.detach().cpu().numpy(), axis=0)

        preds = np.argmax(preds, axis=2)
        slot_label_map = {i : label for i, label in enumerate(label_lst_)}   
    preds_list = []
    for j in range(preds.shape[1]):
        if tmp_slot[0,j] != pad_token:
            preds_list.append(slot_label_map[preds[0][j]])            

    return preds_list

def get_labels(label_path):
    return [label.strip() for label in open(os.path.join(label_path), 'r', encoding='utf-8')]

# %%
with open('Test_LGES_sent_210811.dta', 'rb') as a_sent:
    test_sent = pickle.load(a_sent)
with open('Test_LGES_sent_ner_level1_210811.dta', 'rb') as a_sent_l1:
    test_ner_l1 = pickle.load(a_sent_l1)
with open('Test_LGES_label_l1_210811.dta', 'rb') as a_label1:
    test_label_l1 = pickle.load(a_label1)
with open('LGES_label_l1_210811.dta', 'rb') as a_label1:
    train_label_l1 = pickle.load(a_label1)

# %%
test_sent[0]
# Out:
# 'M 오토데일리 최태인 기자 볼보자동차가 지난 30일 스웨덴 고텐버그에서 개최된 테크 모멘트 Volvo Cars Tech Moment 이벤트를 통해 글로벌 프리미엄 전기차 시장 선두기업으로의 도약을 위한 미래기술 로드맵을 발표했다'

# %%
rslt, rslt_word, acc, score = [], [], [], []
for i in range(0, len(test_sent)):
    #print(test_sent[i])
    preds_list = eval_ft(test_sent[i], train_label_l1, model, token, device, args)
    #print(preds_list)
    ner_preds = [x.split('-')[0] if x != 'UNK' else 'O' for x in preds_list]
    ner_true = test_ner_l1[i].split()
    
    #print(ner_preds, ner_true)
    #print(len(ner_preds), len(ner_true))
    tmp_acc = np.sum([1 if p == t else 0 for t, p in zip(ner_true, ner_preds)]) / len(ner_true)
    
    if np.sum([1 for x in ner_true if x == 'O']) == len(ner_true) :
        tmp_f1score = 999
    else :
        tmp_precision = np.sum([1 if x == ner_true[i] else 0 for i,x in enumerate(ner_preds) if x != 'O' ]) / np.sum([1 for x in ner_preds if x != 'O' ])
        tmp_recall = np.sum([1 if x == ner_preds[i] else 0 for i,x in enumerate(ner_preds) if x != 'O' ]) / np.sum([1 for x in ner_true[:len(ner_preds)] if x != 'O' ])
        tmp_f1score = 2 * (tmp_recall * tmp_precision ) / (tmp_recall + tmp_precision)

        #print('Acc & F1 Score : %.3f / %.3f'%(tmp_acc, tmp_f1score))

    line = ""
    for w, p in zip(test_sent[i].split(), preds_list):
        #line = line + " {}".format(p)
        rslt_word.append([w,p])
        if p == 'UNK':
            line = line + w + " "
        else :
            line = line + "{}[{}] ".format(w, p)
    rslt.append(line)
    acc.append(tmp_acc)
    score.append(tmp_f1score)
score1 = [s for s in score if s < 999]

# %%
np.mean(acc), np.mean(score1)
# Out:
# (0.9706025329025955, 0.9932283009595316)

# %%
rslt
# Out:
# ['M 오토데일리 최태인 기자 볼보자동차가[제품-B] 지난 30일 스웨덴 고텐버그에서 개최된[이벤트-B] 테크 모멘트 Volvo Cars Tech Moment 이벤트를[스펙-B] 통해[스펙-B] 글로벌 프리미엄 전기차[제품-B] 시장 선두기업으로의 도약을 위한 미래기술[기술-B] 로드맵을[이벤트-B] 발표했다[이벤트-B] ',
#  '이번 행사는[이벤트-B] 2030년 전기차[제품-B] 회사로의 전면적인 전환을 계획하고 있는 볼보자동차의[제품-B] 미래 기술을[기술-B] 최초로[이벤트-B] 선보이는 자리로 구글 Google 루미나 Luminar 노스볼트[소재-B] Northvolt 엔비디아 NVIDIA 등 주요 파트너사들[이벤트-B] 대표들이 참가한[이벤트-B] 가운데 함께 진행됐다 ',
#  '이를 통해[스펙-B] 볼보자동차는[제품-B] 완전한 전기차[제품-B] 회사로 전환을 위한 배터리[제품-B] 공급 계획 자체 소프트웨어[제품-B] 개발[이벤트-B] 확대를 위한 계획 컴퓨팅의[기술-B] 중앙 집중화 차세대 안전 기술에[기술-B] 대한 계획 등 핵심 분야에 대한 세부사항을 공개했다[이벤트-B] ',
#  '볼보자동차[제품-B] 최고경영자[이벤트-B] 하칸 사무엘손 Håkan Samuelsson 은 볼보자동차는 오는 2030년까지 프리미엄 순수 전기차[제품-B] 기업으로 전환하기 위해 94년 역사상[트렌드-B] 가장 최고의 자동차를 만드는 데 전념하고 있다며 지금은 이러한 발전에[이벤트-B] 있어 흥미로운 시기로 원활한 연결성 업계 최고 수준의 안전표준 그리고 수준 높은 자율주행을[제품-B] 구현하는[이벤트-B] 순수 전기차에 대한 고객 요구를 만족시킬 것이라고 밝혔다고객 차량의[제품-B] 실시간[스펙-B] 데이터를[기술-B] 활용해[스펙-B] 새로운 안전 기준 설정볼보자동차는 그 동안 새로운 안전 기술을[기술-B] 개발하는데[이벤트-B] 있어 실제 도로[서비스-B] ',
#  '차세대 볼보자동차는[제품-B] 여기서 나아가 고객이 동의한다면[이벤트-B] 더욱 안전한 기술을[기술-B] 개발하기[이벤트-B] 위해 고객의 자동차로부터 실시간[스펙-B] 데이터를[기술-B] 전송받아[서비스-B] 분석하는[스펙-B] 것을 고려하고 있다 ',
#  'M오토데일리 박상우 기자 볼보자동차가[제품-B] 자동차 디자인의[이벤트-B] 새로운 패러다임을 제시할 차세대 순수 전기차의[제품-B] 비전 볼보 컨셉트 리차지 Volvo Concept Recharge 를 공개했다[이벤트-B] ',
#  '최소한의 그러나 더 나은 less but better 이라는 스칸디나비아[스펙-B] 디자인[이벤트-B] 유산을 기반으로 탄생한 컨셉트 리차지는 지속가능한 미래를 위한 패밀리 카의 새로운 방향성을 제시하는 모델이다 ',
#  '특히 순수 전기차를[제품-B] 위해 공기역학적[트렌드-B] 효율을 개선하고[이벤트-B] 배터리[제품-B] 팩을[제품-B] 수용하면서도 넓은 실내[스펙-B] 공간을 갖출 수 있도록 설계된[이벤트-B] 새로운 차체 비율을 선보인다 ',
#  '이를 위해 볼보의[소재-B] 디자이너들은 기존 내연기관의[사건/사고-B] 엔진을[제품-B] 제거한 차체 바닥 전체를 배터리[제품-B] 팩으로[제품-B] 배치해 휠 베이스 및 휠 크기를[스펙-B] 확대했다 ',
#  '그 결과 짧아진 오버행 차체 끝에서 바퀴 중심까지 거리 과 함께 운전석과[제품-B] 조수석 사이 넓은 수납공간을 비롯해 더욱 여유로운 실내[스펙-B] 공간을 만들었다 ',
#  '여기에 낮게 설계된[이벤트-B] 후드와 새로운 시트[제품-B] 포지션 최적화된 루프[제품-B] 형태[스펙-B] 등을 통해[스펙-B] SUV[제품-B] 모델이 지닌 높은 시야를 유지하면서도 주행거리를[스펙-B] 향상시킬[이벤트-B] 수 있도록 공기역학[트렌드-B] 효율성을 개선했다[이벤트-B] ',
#  '또한 컨셉트 리차지는 불필요한 요소를 모두 제거하고 남은 요소들 역시 보다 정밀하고 선명해진 형태의[스펙-B] 새로워진 볼보의[소재-B] 디자인[이벤트-B] 언어가 도입됐다[이벤트-B] ',
#  '먼저 전면 그릴은 시그니처 토르의 망치 Thors Hammer 를 재해석해[트렌드-B] 방패 모양과 같은 구조로 대체됐다 ',
#  '여기에는 야간이면 메인 램프[제품-B] 구성이 드러나는 형태의[스펙-B] 최신 HD 기술이[기술-B] 적용된[이벤트-B] 순수 그래픽이 포함된다 ',
#  '또 다른 볼보자동차의[제품-B] 상징인 수직형[스펙-B] 리어[제품-B] 램프는[제품-B] 빠른 크루징 속도로[서비스-B] 전개되는 날개 세트 형태로 재창조돼 전반적인 공기[트렌드-B] 역학을 더욱 향상시킨다[이벤트-B] ',
#  '볼보자동차[제품-B] 디자인[이벤트-B] 총괄 Head of Design 로빈 페이지 Robin Page 는 컨셉트 리차지는 볼보자동차의 미래뿐만 아니라 새로운 타입의[스펙-B] 자동차를 위한 선언이라며 더욱 다재다능해진 새롭고 현대적인 비율을 보여줄 뿐만 아니라 디자인 측면에서는 어떤 기술을[기술-B] 사용할 수 있는지 제시한다고 소개했다 ',
#  '이와 더불어 볼보자동차는[제품-B] 컨셉트 리차지를 통해[스펙-B] 디자인[이벤트-B] 언어의 새로운 형태를[스펙-B] 제시한다 ',
#  '먼저 평평한 차체 바닥은 모든 탑승자에게 더 많은 공간과 개선된[이벤트-B] 시트[제품-B] 포지션을 제공한다[이벤트-B] ',
#  '새로운 사용자 경험의 중심인 중앙 터치스크린은[제품-B] 차세대 커넥티드[기술-B] 인포테인먼트[기술-B] 시스템을 위해 15인치 대형[스펙-B] 스크린으로 확대됐다 ',
#  '여기에 논리적이면서 직관적인 기술과[기술-B] 깨끗한 라인 지속가능한 천연 소재의 광범위한 사용 통해[스펙-B] 스칸디나비아[스펙-B] 디자인의[이벤트-B] 특징인 평온하면서도 차분한 실내[스펙-B] 경험을 제공한다[이벤트-B] ',
#  '로빈 페이지는 컨셉트 리차지의 인테리어는[제품-B] 진정한 스칸디나비아[스펙-B] 거실의[스펙-B] 느낌을 선사한다며 이를 위해 우리는 최신의 사용자 경험 기술을[기술-B] 아름답고 지속 가능한 천연의 소재와 통합했다[스펙-B] ',
#  '실내에[스펙-B] 각 파트는 마치 하나의 예술품과 같으며 방안에 자리한 가구와 같이 개별적인 역할을 할 수 있다 ',
#  '우리는 단지 기술을[기술-B] 강조하기 위해서가 아닌 기술이 가져올 수 있는 이점에 초점을 맞추고 있다고 덧붙였다 ',
#  '이 밖에도 컨셉트 리차지를 통해[스펙-B] 앞으로 수년 이내에 선보일 안전에 대한 볼보자동차의[제품-B] 새로운 야망을 엿볼 수 있다 ',
#  '특히 안전한 자율 주행 기술[기술-B] 구현을[이벤트-B] 위해 루미나 Luminar 가 개발한[이벤트-B] 라이다 ',
#  'LiDAR[기술-B] 센서를[제품-B] 루프에[제품-B] 탑재해[트렌드-B] 자동차[제품-B] 주변 환경에 대한 데이터를[기술-B] 수집한다 ',
#  '로빈 페이지는 끝으로 컨셉트 리차지를 통해[스펙-B] 우리는 완전히 전기적인[트렌드-B] 미래로 나아가면서 현대적이고 신선한 방식으로[스펙-B] 볼보[소재-B] 디자인[이벤트-B] DNA의 뿌리를 지속적으로 이어갈 것이라며 이는 고객이 기대하는 볼보의 순수 전기차에[제품-B] 모든 것으로 이러한 철학을 선보이게 돼 기쁘다고 밝혔다 ',
#  'M오토데일리 박상우 기자 대한민국 최고의 정유화학[서비스-B] 기업으로 성장해[이벤트-B] 온 SK이노베이션이 탄소[소재-B] 사업에서 그린 중심 사업으로 회사의 정체성을 완전히 바꾼다 ',
#  'SK이노베이션은 1일 서울 여의도 콘래드 호텔에서 김준 총괄사장 김종훈 이사회 의장 등 전 경영진과[이벤트-B] 국내외 시장 및 언론[트렌드-B] 관계자 등 200여명이 온오프라인으로[기술-B] 참석한[이벤트-B] 가운데 SK이노베이션 스토리 데이 Story Day 를 갖고 이같이 밝혔다 ',
#  'SK이노베이션 스토리 데이는 지난 2017년 혁신[기술-B] 방향 제시 2019년 혁신 실행[스펙-B] 전략[이벤트-B] 발표에[이벤트-B] 이은 세번째 행사로[이벤트-B] 이번엔 혁신 완성에[이벤트-B] 대한 구체적인[스펙-B] 방안을 제시한 것으로 SK이노베이션은 글로벌 친환경[트렌드-B] 산업 핵심인 배터리[제품-B] 사업 1테라와트 α 수주[이벤트-B] 역량에 기반해 그린 사업을 새 성장축으로[이벤트-B] 미래 전략을 만들어 가겠다는 것이 핵심이다 ',
#  '김준 총괄사장 등 SK이노베이션 경영진이[이벤트-B] 이날 밝힌 파이낸셜 스토리의 핵심은 한마디로 Carbon to Green 즉 탄소[소재-B] 중심의 사업 구조를 그린 중심의 사업을 영위하는 기업으로 탈바꿈[이벤트-B] 시키겠다는 것이다 ',
#  '올해 신년 경영방침을[이벤트-B] 통해[스펙-B] 회사의 새로운 아이덴티티를 친환경[트렌드-B] 에너지소재[트렌드-B] 회사 Green Energy Materials Co 로 밝힌 바 있는 SK이노베이션은 이날 스토리데이를 통해 구체적인[스펙-B] 완성[이벤트-B] 전략을[이벤트-B] 공개했다[이벤트-B] ',
#  '김준 총괄사장과 SK이노베이션 경영진이[이벤트-B] 밝힌 핵심 전략은[이벤트-B] Green Anchoring 배터리를[제품-B] 중심으로 분리막[소재-B] 폐배터리[제품-B] 리사이클[스펙-B] 등 그린 포트폴리오[소재-B] 강화 Green Transformation 기존 사업을 플라스틱 리사이클 등 친환경[트렌드-B] 비즈니스[스펙-B] 모델로 전환 온실가스[트렌드-B] 배출[이벤트-B] 0 제로 인 넷 제로 Net Zero 조기 달성[이벤트-B] 등 크게 3가지로 요약된다 ',
#  'SK이노베이션은 현재 배터리[제품-B] 수주[이벤트-B] 잔고가 1테라와트 α 에 달한다고 공개했다[이벤트-B] ',
#  '그동안 1테라와트 이상을 수주한[이벤트-B] 곳은 글로벌 상위 두 개사 정도로[서비스-B] 알려져 있었는데 SK의 수주 잔고가 1테라와트 α의 규모라고[이벤트-B] 밝힘에 따라 3개사로 늘어난 것이다 ',
#  '따라서 SK 배터리[제품-B] 사업 목표는 글로벌 Top3에서 글로벌 Top을 향할 수 있게 된 것이다 ',
#  '1테라와트는 SK이노베이션이 배터리[제품-B] 사업을 새로운 성장축으로[이벤트-B] 키우겠다고 밝혔던 2017년 5월 당시의 60GWh 보다 약 17배 늘어난 것으로 한화 환산시 130조원 이상이다 ',
#  '또한 진행 중인 수주[이벤트-B] 프로그램이 완성되면[이벤트-B] 수주 잔고는 더욱 늘어날 것으로 보인다 ',
#  'SK 배터리[제품-B] 사업 지동섭 대표는 내년 말에는 월 판매량에서도[이벤트-B] 세계 3위로 올라설 것이라고 예상했다 ',
#  '이렇게 되면 수주와[이벤트-B] 매출이라는[이벤트-B] 양대 영역에서 글로벌 Top3를 실현하는[스펙-B] 셈이다 ',
#  '지동섭 대표는 SK는 가장 안전하고 가장 빠르게 충전하고[스펙-B] 가장 오래 쓸 수 있는 배터리를[제품-B] 추구하고 있으며 특히 안전은 그 무엇보다 중요한 가치라며 이것이 SK배터리를 탑재한 차량에서[제품-B] 화재사고가[사건/사고-B] 한번도 없었던 이유이자 수주가[이벤트-B] 급격히 증가한 배경이라고 강조했다 ',
#  'SK이노베이션의 생산 규모도[이벤트-B] 크게 늘어난다 ',
#  '지동섭 대표는 현재 40GWh 수준에서 2023년 85GWh 2025년에는 200GWh 2030년에는 500GWh 이상으로 예상하고 있으며 EBITDA[기술-B] 기준 올해 흑자를[이벤트-B] 달성하고[이벤트-B] 2023년 1조원 2025년 25조원까지 각각 창출할 수 있을 것이라고 밝혔다 ',
#  '또한 SK이노베이션은 배터리의[제품-B] 핵심 소재 LiBS 리튬이온전지분리막[소재-B] 사업 자회사 상장[이벤트-B] 성공을[이벤트-B] 계기로 현 14억㎡인 LiBS 생산 규모를[이벤트-B] 2023년 21억㎡로 키운 뒤 전기차[제품-B] 산업의 본격 성장이[이벤트-B] 예상되는 2025년에는 현재의 3배인 40억㎡로 확대할 계획이라며 분리막 시장에서 세계 1위의 기업 위상을 확고히 하겠다는 계획이다 ',
#  '김준 사장은 올해 기준 3천억원 수준인 분리막[소재-B] 사업의 EBITDA를[기술-B] 2025년 14조원까지 키워 이 사업에서만 조원 단위 EBITDA 시대를 만들어 그린 비즈니스의[스펙-B] 핵심으로 육성해 갈 것이라고 밝혔다 ',
#  '폐배터리[제품-B] 재활용 BMR[기술-B] Battery Metal Recycle 사업은 배터리에서 배터리를 캔다는 목표아래 그간 축적된 정유공장[서비스-B] 운영[이벤트-B] 기술을[기술-B] 바탕으로 수산화[스펙-B] 리튬[소재-B] 회수 기술을 자체 개발해[이벤트-B] 54건의 특허를[이벤트-B] 출원해[이벤트-B] 놓은 상태다 ',
#  '이를 활용하면 최초[이벤트-B] 리튬[소재-B] 채굴시 발생하는[이벤트-B] 탄소를[소재-B] 4070%까지 줄일 수 있는 획기적인 사업이다 ',
#  'SK이노베이션은 내년 중 시험생산을[이벤트-B] 시작해 2024년에는 국내외에서 상업생산을[이벤트-B] 목표로 하고 있으며 2025년 기준 연간 30GWh의 배터리를[제품-B] 재활용해[스펙-B] 이 사업에서만 약 3000억원의 EBITDA를[기술-B] 창출할 것으로 예상하고 있다 ',
#  '아울러 SK이노베이션은 전기차[제품-B] 외에 에너지저장장치[스펙-B] ESS[제품-B] 플라잉 카 Flying car 로봇[제품-B] 등으로 배터리[제품-B] 적용[이벤트-B] 영역을 확장하는[이벤트-B] 한편 배터리를 기반으로 하는 신규사업도 개발해[이벤트-B] 집중 육성키로 했다 ',
#  '배터리[제품-B] 생애주기를 연구해[이벤트-B] 배터리 생애주기 Life-time 를 효율적으로 관리하기 위한 BaaS Battery as a Service 플랫폼[서비스-B] 사업이 있다 ',
#  '김준 총괄사장은 SK이노베이션의 그린 전략이[이벤트-B] 추구하는 궁극적인 목표는 화석연료[트렌드-B] 사용에 대한 어떤 흔적도 남기지 않는 것 No Footprint Left Behind 이라며 SK종합화학이 생산하는 플라스틱 100%에 해당하는 물량을 재활용하는 순환경제[트렌드-B] 모델을 완성해[이벤트-B] 갈 것이라고 밝혔다 ',
#  '이에 따라 화학 사업 자회사인 SK종합화학을 중심으로 폐플라스틱으로 다시 석유를[소재-B] 만드는 도시 유전 사업 모델을 도입하기로[이벤트-B] 했다 ',
#  '이렇게 탄생한 원료로 플라스틱을 만드는 이른 바 리사이클[스펙-B] Recycle 기반 화학 사업 회사로 완전히 탈바꿈하기로[이벤트-B] 했다 ',
#  '나경수 SK종합화학 사장은 플라스틱은 유리[제품-B] 강철 등에 비해 생산 과정에서는 친환경적이지만[트렌드-B] 리사이클[스펙-B] 비율이 낮은 것이 문제라며[사건/사고-B] 재활용과 친환경 소재기업으로서 플라스틱 이슈를 위기가[사건/사고-B] 아닌 성장[이벤트-B] 기회로[제품-B] 삼아 나갈 것이라고 천명했다 ',
#  '나 사장은 이어 그간 자체 개발한[이벤트-B] 기술과[기술-B] 글로벌 MA등으로 확보한 역량을 기반으로 2027년 기준 국내외 생산하는 플라스틱 100%인 연간 250만톤 이상 재활용 사용량[스펙-B] 저감 및 재활용 가능 친환경[트렌드-B] 제품[이벤트-B] 비중 100% 달성[이벤트-B] 등을 추진키로[이벤트-B] 했다고 밝혔다 ',
#  '이어 SK종합화학은 2025년 그린 사업으로만 EBITDA[기술-B] 기준 6000억원 이상을 창출해 나간다는 방침이나[이벤트-B] 전체 11조원 중 절반을 넘겨 기존 사업을 앞서 갈 것이라고 강조했다 ',
#  '이와 함께 석유[소재-B] 사업은 원유정제[소재-B] 트레이딩 및 석유개발[이벤트-B] EP 영역 등에서 탄소발생[이벤트-B] 최소화를 중심으로 운영[이벤트-B] 체질을 대폭 개선하기로[이벤트-B] 했다 ',
#  '全 사업장을 低脫 탄소[소재-B] 시스템으로 전환하는 운영최적화[이벤트-B] 수요감소가 예상되는 수송용 연료 생산을 감축하는[사건/사고-B] 대신 석유화학[소재-B] 제품[이벤트-B] 생산 증대 탄소 포집저장[스펙-B] 기술[기술-B] 개발[이벤트-B] 바이오 신재생[트렌드-B] 에너지[트렌드-B] 사업 등 다양한 방식들을[스펙-B] 동시에 추진해[이벤트-B] 갈 방침이다[이벤트-B] ',
#  '또한 석유[소재-B] 사업이 보유한 주유소와[서비스-B] 고객들을 그린 플랫폼[서비스-B] 개념으로 전환해 친환경[트렌드-B] 전기와[트렌드-B] 수소를[소재-B] 생산 판매하는[이벤트-B] 에너지[트렌드-B] 솔루션[소재-B] 사업과 친환경차[제품-B] 대상 구독[서비스-B] 모델 도입[이벤트-B] 등도 추진할[이벤트-B] 계획이다 ',
#  'SK이노베이션은 이날 설명회에서 온실가스[트렌드-B] 넷 제로 Net Zero 를 50년 이전에 달성한다는[이벤트-B] 목표도 밝혔다 ',
#  'SK이노베이션 ESG경영의[이벤트-B] 핵심은 환경 Environment 이고 환경의 핵심은 온실가스[트렌드-B] 순배출을[이벤트-B] 0으로 만드는 것 Net Zero 이며 이는 ESG에 대한 진정성과[이벤트-B] 책임감을 상징하는 핵심 전략이라고[이벤트-B] 설명했다 ',
#  '이날 공표한 SK이노베이션의 넷 제로 Net Zero 로드맵은[이벤트-B] 세 가지 측면에서 차별화된 탈 탄소[소재-B] 전략으로[이벤트-B] 첫째 아시아 기업 최초로[이벤트-B] Scope 123 배출량을[이벤트-B] 모두 포함한 감축[사건/사고-B] 목표의 구체적[스펙-B] 제시 둘째 파리기후협약의[이벤트-B] 15도 온도상승[스펙-B] 시나리오보다 빠르게 감축해 SK이노베이션 계열 전체적으로[스펙-B] 2050년 이전에 Net Zero를 달성[이벤트-B] 특히 Battery LiBS 사업의 경우 2035년 조기 달성을 추진하는[이벤트-B] 것을 목표로 한다 ',
#  '그리고 마지막으로 단순한 석유화학사업의[소재-B] 매각[사건/사고-B] 방식이[스펙-B] 아니라 실질적인[스펙-B] 친환경[트렌드-B] 투자를[이벤트-B] 통한[스펙-B] Net Zero 달성을[이벤트-B] 지향한다 ',
#  '이를 위해 친환경[트렌드-B] 중심 공정개선[이벤트-B] 저탄소[소재-B] 제품[이벤트-B] 전환 및 탄소 포집 등 감축[사건/사고-B] 기술[기술-B] 개발을[이벤트-B] 강력히 실행해[스펙-B] 나가기로 했다 ',
#  '김종훈 이사회 의장은 Net Zero 추진의[이벤트-B] 실행력을[스펙-B] 높이기[스펙-B] 위해 회사의 기후변화[트렌드-B] 대응[사건/사고-B] 성과를[이벤트-B] CEO의 평가 및 보상과[사건/사고-B] 직접 연계하기로 했으며 이는 SK이노베이션의 기후변화 대응에 대한 진정성을 보여주는 것이라고 강조 했다 ',
#  'SK이노베이션은 이사회 중심 경영[이벤트-B] 강화를 위한 거버넌스 Governance 개선안에[이벤트-B] 대해서도 발표했다[이벤트-B] ',
#  '핵심은 이사회의 CEO 평가보상승계[이벤트-B] 등에 대한 의사결정권[이벤트-B] 보유 이사회 모든 안건에 대한 ESG[이벤트-B] 리스크[서비스-B] 사전 검토 의무화 글로벌 컴플라이언스 Compliance 와 사업 리스크의 컨트롤 타워 기능 강화 등이다 ',
#  '우선 이사회 산하에 ESG위원회를[이벤트-B] 신설해[이벤트-B] ESG 전략[이벤트-B] 방향성 검토 및 성과를[이벤트-B] 모니터링[제품-B] 하고 이사회에서 결정되는 모든 안건에 대해 ESG관점의 리스크를[서비스-B] 사전 검토하는 절차를 만들었다 ',
#  'Net Zero 추진뿐만[이벤트-B] 아니라 유망 사업 개발[이벤트-B] 및 투자[이벤트-B] 중장기 전략[이벤트-B] 실행[스펙-B] 등 이사회가 주도적으로 ESG[이벤트-B] 경영을[이벤트-B] 실질적으로 주도한다는 의미다 ',
#  '또한 이사회가 국내 및 글로벌 컴플라이언스 및 리스크[서비스-B] 관리 체계의 컨트롤 타워 역할을 수행하도록 했다 ',
#  '이를 위해 CEO 직속으로 있던 감사실을[스펙-B] 감사위원회 산하로 재배치하는 등 본격적인 실행 의지를 드러냈다 ',
#  '이날 행사에[이벤트-B] 참여한 김종훈 이사회 의장은 이번에 발표된[이벤트-B] SK이노베이션 파이낸셜 스토리를 성공적으로[이벤트-B] 실행하고[스펙-B] ESG[이벤트-B] 경영을[이벤트-B] 가속화하기 위해선 선진 지배구조[트렌드-B] 구축이[이벤트-B] 가장 필수적이라며 이 지배구조를 바탕으로 회사 전략[이벤트-B] 방향성 설정 실행을 관리 감독해 SK이노베이션의 스토리가 흔들림없이[스펙-B] 완성될[이벤트-B] 수 있도록 최선을 다 하겠다고 밝혔다한편 SK이노베이션은 이날 SK이노베이션 자체의 비전 Vision 에 대해서도 밝혔다 ',
#  '김준 사장은 SK이노베이션은 그린 포트폴리오[소재-B] 개발[이벤트-B] Green Portfolio Designer Developer 을 전문으로 하는 지주회사 역할에 중점을 둬 그린 영역에서의 연구개발[이벤트-B] RD 과 새로운 사업개발[이벤트-B] 및 MA 등을 통해[스펙-B] 제2 제3의 배터리와[제품-B] 분리막[소재-B] LiBS 사업을 발굴해[이벤트-B] 갈 것이라고 말했다 ',
#  'SK이노베이션은 현재 사업부 형태인[스펙-B] 배터리[제품-B] 사업과 석유개발[이벤트-B] EP 사업에 대해서 이해관계자들의 기대를 종합적으로 고려해 포트폴리오[소재-B] 가치를 극대화 할 수 있는 최적의 방안으로 각각 분할을 검토하고 있다고 밝혔다 ',
#  '김준 사장은 이날 발표를[이벤트-B] 통해[스펙-B] 2017년부터 시작한 딥 체인지와 혁신을[기술-B] 이제는 완성하고[이벤트-B] 성과를[이벤트-B] 만들어 내야 할 시점인 만큼 ESG경쟁력을[이벤트-B] 기반으로 이사회 이해관계자들과 함께 파이낸셜 스토리를 완성할 것이라며 그린 중심 성장을[이벤트-B] 위해 25년까지 지난 5년간 투자의[이벤트-B] 2배가 넘는 총 30조원을 집중 투자할 방침이며[이벤트-B] 그 결과로 현재 30% 수준인 그린 자산 비중을 70%까지 늘릴 것이라고 말했다 ',
#  'M 오토데일리 이상원기자 도심 공항 사이를 날아다니다 도로에서는[서비스-B] 일반 자동차처럼[제품-B] 주행이 가능한 에어 카 Air Car 가 곧 현실에[스펙-B] 등장할 전망이다[이벤트-B] ',
#  'CNN 보도에 따르면 슬로바키아의 비행차 개발업체인[이벤트-B] 클라인 비전 Klein Vision은 지난 6월 28일 처음으로 도시 간 비행에 성공했다에어[이벤트-B] 카는 항공 도로[서비스-B] 겸용으로 니트라 공항에서 이륙 30분 조금 넘게 비행한 후 브라티슬라바 공장에 착륙한 후 육로를 통해[스펙-B] 도심으로 향했다에어 카는 비행자동차[제품-B] 발명가인[이벤트-B] 슈테판 클라인교수가 개발한 비행차로 이날 비행에 성공한 항공기는[트렌드-B] 160마력급 BMW[사건/사고-B] ',
#  '이 회사는 현재 300마력급 엔진을[제품-B] 탑재한 에어 카 프로토 타입[스펙-B] 2의 개발을[이벤트-B] 진행하고 있다 ',
#  '더구루김도담 기자 중국 자율주행[제품-B] 스타트업 포니닷에이아이 Ponyai小馬智行 가 신임 최고재무책임자 CFO 로 미국 JP모건 임원을 선임했다 ',
#  '미국 증시[트렌드-B] 상장[이벤트-B] 포석으로 풀이된다 ',
#  '포니닷AI는[기술-B] 최근 로렌스 스테인[소재-B] Lawreance Steyn 전 JP모건 투자은행[이벤트-B] 부문 부회장을 신임 CFO로 영입했다고1일[이벤트-B] 밝혔다 ',
#  '스테인은[제품-B] 금융업계에서[트렌드-B] 30년 경력을 가진 베테랑으로 알려져 있다 ',
#  '더구루길소연 기자 GS에너지가[트렌드-B] 두산중공업이 투자한[이벤트-B] 미국 원자력발전[이벤트-B] 전문회사인 뉴스케일파워 NuScale Power 에 베팅한다 ',
#  'GS에너지의[트렌드-B] 투자[이벤트-B] 참여로 뉴스케일파워의 소형원자로모듈[기술-B] 상업화가[이벤트-B] 속도가 붙을 전망이다[이벤트-B] ',
#  '1일 업계에 따르면 GS에너지[트렌드-B] 북미법인은[트렌드-B] 뉴스케일파워와 소형모듈원전[트렌드-B] SMR[기술-B] 구축을[이벤트-B] 위한 투자계약을[이벤트-B] 체결했다[이벤트-B] ',
#  '투자[이벤트-B] 규모는[이벤트-B] 공개되지[이벤트-B] 않았다 ',
#  'GS에너지는[트렌드-B] 뉴스케일파워 현금 투자와[이벤트-B] 뉴스케일공장 배치를 지원하게[이벤트-B] 된다 ',
#  '또 뉴스케일 발전소의[제품-B] 서비스 제공[이벤트-B] 기회도 개발한다[이벤트-B] ',
#  '존 홉킨스 뉴스케일파워 회장 겸 최고경영자[이벤트-B] CEO 는 뉴스케일은 미국 최초의[이벤트-B] 소형모듈형[스펙-B] 원자로[기술-B] 상용화를[이벤트-B] 도와줄 GS에너지의[트렌드-B] 투자와[이벤트-B] 약속을[이벤트-B] 환영한다고 밝혔다 ',
#  '이번 투자는[이벤트-B] 뉴스케일파워가 지난 몇달간 확보한 투자 모멘텀을 이어가는 것으로 뉴스케일의 SMR[기술-B] 기술[기술-B] 상용화에[이벤트-B] 한발 더 나아가게 됐다 ',
#  '앞서 지난 4월 두산중공업과 일본 엔지니어링기업[기술-B] JSG이 투자에[이벤트-B] 참여했다 ',
#  '본보 2021년 4월 5일 참고 두산 이어 日 JGC[스펙-B] 美 뉴스케일파워 베팅 GS에너지는[트렌드-B] 운송 연료 및 기타 석유[소재-B] 화학 제품의[이벤트-B] 정제 액화천연가스[트렌드-B] LNG[소재-B] 조달과 공급 전력[트렌드-B] 생산 및 지역 난방 석유 및 가스 탐사[이벤트-B] 및 생산 등의 다양한 포트폴리오를[소재-B] 갖고 있다 ',
#  '국내 물론 국제적으로 에너지[트렌드-B] 솔루션[소재-B] 공급자로 자리매김했다 ',
#  '특히 지속적으로 다양한 형태의[스펙-B] 재생[트렌드-B] 에너지와[트렌드-B] 원자력[트렌드-B] 등 신기술[기술-B] 개발을[이벤트-B] 모색해왔다 ',
#  '허용수 GS에너지[트렌드-B] 사장은 GS에너지는 청정[트렌드-B] 에너지 포트폴리오를[소재-B] 확대하기 위해 최선을 다하고 있다며 뉴스케일과 같은 혁신적이고[기술-B] 안전한 SMR[기술-B] 기술은[기술-B] 온실가스[트렌드-B] 넷 제로 NET Zero 경제로의 전환의 중요한 키가 될 것이라고 밝혔다 ',
#  '뉴스케일은 미국 에너지부[트렌드-B] DOE 의 지원을[이벤트-B] 받아 소형모듈원전을[트렌드-B] 개발[이벤트-B] 중이다 ',
#  '뉴스케일파워는 발전사[이벤트-B] UAMPS[제품-B] Utah Associated Municipal Power Systems 가 오는 2026년 상업운전을 목표로 미국 아이다호주에 짓고 있는 첫 소형원전[트렌드-B] 프로젝트에[이벤트-B] 소형모듈원전을 공급할 예정이다 ',
#  '디스플레이반도체[제품-B] 검사장비업체[이벤트-B] 영우디에스피가 의료용 돌봄[서비스-B] 로봇[제품-B] 시장에 진출한다고[이벤트-B] 1일 밝혔다 ',
#  '영우디에스피는 지난달 30일 건양대 지능형[스펙-B] 의지보조 및 의료용 이동기기 트랙레코드 구축사업단과[이벤트-B] 업무협약을[이벤트-B] 맺었다 ',
#  '이 사업은 산업통상자원부[트렌드-B] 주관 산업혁신기반구축사업이다[이벤트-B] ',
#  '5년간 의지보조 장비와 로봇산업을[제품-B] 지원하며[이벤트-B] 총사업비는 280억원이다 ',
#  'M오토데일리 박상우 기자 모빌리티 사업 역량을 강화하는 LG그룹이 카카오모빌리티에 1천억원 규모의[이벤트-B] 지분 투자를[이벤트-B] 단행한다[이벤트-B] ',
#  '2일 업계에 따르면 LG는 모빌리티 플랫폼[서비스-B] 서비스 기업 카카오모빌리티에 1천억원 지분 투자를[이벤트-B] 결정했다 ',
#  'LG는 LG에너지솔루션의[소재-B] 배터리[제품-B] 주행 데이터[기술-B] 확보와 배터리 교환 LG전자의 전기차[제품-B] 충전[스펙-B] 솔루션 등 LG계열사들의[이벤트-B] 미래 모빌리티 분야 신사업[이벤트-B] 기회를 모색하기 위해 이번 투자를[이벤트-B] 단행한[이벤트-B] 것으로 알려졌다 ',
#  'LG에너지솔루션은[소재-B] 배터리[제품-B] 생애주기 전반을 기반으로 하는 산업인 바스 BaaS Battery as a Service 와 관련된 서비스를 발굴하고[이벤트-B] 있다 ',
#  '바스는 전기차[제품-B] 배터리를[제품-B] 생산하는 데 그치지 않고 수리 렌탈 충전[스펙-B] 재사용 재활용 등 배터리 생애주기 전반을 기반으로 하는 서비스 산업으로 단순 배터리 생산 대비 다양하고 높은 수익 창출이 가능하다 ',
#  '특히 BaaS 영역 중 하나인 배터리[제품-B] 임대 서비스를 활용하면 전기차[제품-B] 초기 구매 비용을[이벤트-B] 크게 낮출 뿐만 아니라 성능이[스펙-B] 향상된[이벤트-B] 배터리로 계속 교체할[이벤트-B] 수 있고 무엇보다 구매 부담이 크게 줄기 때문에 전기차의 잠재 고객층을 넓힐 수 있다 ',
#  '또 사용된 배터리에서[제품-B] 추출한 리튬[소재-B] 니켈[소재-B] 코발트[소재-B] 등을 재활용하면 배터리 생산비용을[이벤트-B] 절감할 수 있어 배터리 공급 가격뿐만 아니라 전기차[제품-B] 가격도 낮출 수 있어 전기차 구매를 촉진할 수 있다 ',
#  'LG에너지솔루션은[소재-B] BaaS와 관련 서비스를 개발하고자[이벤트-B] 지난 4월에는 롯데렌탈과 지난달에는 엔카닷컴과 업무협약을[이벤트-B] 체결[이벤트-B] 다양한 전기차[제품-B] 특화 서비스를 개발하기로 했다 ',
#  'LG전자는 지난해 말 전기차[제품-B] 충전[스펙-B] 상황 모니터링[제품-B] 원격[서비스-B] 제어 및 진단 등 충전소 통합관리[스펙-B] 솔루션[소재-B] 시범[이벤트-B] 서비스를 선보인 바 있다 ',
#  'LG와 카카오모빌리티는 전략적[이벤트-B] 파트너십으로[이벤트-B] 발전할[이벤트-B] 수 있도록 정기적으로 협력[이벤트-B] 방안을 논의하고[이벤트-B] LG의 배터리전장[제품-B] 관련 역량과 카카오모빌리티의 플랫폼[서비스-B] 역량을 결합해[스펙-B] 신사업[이벤트-B] 기회를 공동 발굴해[이벤트-B] 나간다는 계획이다 ',
#  'LG가 카카오모빌리티에 1천억원을 지분 투자하기로[이벤트-B] 했다고 2일 밝혔다 ',
#  'LG 측은 이번 투자는[이벤트-B] ESG[이벤트-B] 경영[이벤트-B] 관점에서 카카오모빌리티와 협력을[이벤트-B] 통해[스펙-B] LG에너지솔루션의[소재-B] 배터리[제품-B] 주행 데이터[기술-B] 확보 및 배터리 교환 LG전자의 전기차[제품-B] 충전[스펙-B] 솔루션 등 LG 계열사들이[이벤트-B] 미래 모빌리티 분야에서 신사업[이벤트-B] 기회를 모색하고 잠재 시너지[이벤트-B] 효과를 고려해 이뤄졌다고 설명했다 ',
#  '카카오모빌리티는 카카오T를 기반으로 다양한 이동 서비스를 제공하고[이벤트-B] 있는 모빌리티 플랫폼[서비스-B] 서비스 기업이다 ',
#  '친환경[트렌드-B] 전기차[제품-B] 도입을[이벤트-B] 가속화하고 빅데이터와[기술-B] 분석[스펙-B] 노하우를[이벤트-B] 바탕으로 서비스사물의 이동으로 플랫폼[서비스-B] 영역을 확대하고 있다 ',
#  'LG에너지솔루션은[소재-B] 전기차[제품-B] 배터리의[제품-B] 제조부터 활용 재사용까지 이어지는 생애주기별 관리 및 진단 서비스인 BaaS Battery as a Service 사업 역량을 강화하고 있으며 LG전자는 지난해 말 전기차 충전[스펙-B] 상황 모니터링[제품-B] 원격[서비스-B] 제어 및 진단 등 충전소 통합관리[스펙-B] 솔루션 시범[이벤트-B] 서비스를 선보인 바 있다 ',
#  'LG와 카카오모빌리티는 전략적[이벤트-B] 파트너십으로[이벤트-B] 발전할[이벤트-B] 수 있도록 정기적으로 협력[이벤트-B] 방안을 논의할[이벤트-B] 예정이다 ',
#  '향후 LG의 배터리[제품-B] 및 전장[제품-B] 관련 역량과 카카오모빌리티의 플랫폼[서비스-B] 역량을 결합해[스펙-B] 신사업[이벤트-B] 기회를 공동 개발해[이벤트-B] 나간다는 계획이다 ',
#  'LG 관계자는 이번 투자를[이벤트-B] 통해[스펙-B] 모빌리티 플랫폼[서비스-B] 비즈니스[스펙-B] 상에서 고객 접점에 대한 이해도를 높이고[스펙-B] 협력[이벤트-B] 관계를 통해 시너지를[이벤트-B] 창출해 나갈 계획이라고 밝혔다 ',
#  '차세대지능형교통시스템[스펙-B] C-ITS[서비스-B] 인프라[서비스-B] 구축이[이벤트-B] 지연되고 있다 ',
#  '주요 부처 입장 차이로[이벤트-B] 표준기술선정부터[이벤트-B] 난항을[사건/사고-B] 겪는 중이다 ',
#  '관련 업계는 흔들림[스펙-B] 없는 사업 추진을[이벤트-B] 촉구하고 나섰다 ',
#  '더 늦으면 글로벌 경쟁에서[이벤트-B] 밀릴 수 있다는 우려도[사건/사고-B] 나타냈다 ',
#  '기획재정부는[트렌드-B] 지난 6월 23일 C-ITS[서비스-B] 인프라[서비스-B] 구축에[이벤트-B] 필요한 통신기술표준[기술-B] 실증사업을[스펙-B] 내년에 추진하겠다고[이벤트-B] 밝혔다 ',
#  '이 같은 발표를[이벤트-B] 접한 관련 업계는 강하게 반발했다[사건/사고-B] ',
#  '늦어도 올해 안에 투자를[이벤트-B] 결정해야 한다고 했다 ',
#  '1일 C-ITS[서비스-B] 조기 추진을[이벤트-B] 위한 얼라이언스는 정부와 기업이 10년 이상 진행한 투자를[이벤트-B] 허물고 주요 정책을 무효화 시키고 있다며 갑작스러운 지연 발표에[이벤트-B] 우려를[사건/사고-B] 표했다 ',
#  'C-ITS[서비스-B] 조기 추진을[이벤트-B] 위한 얼라이언스에는 대보정보통신㈜[스펙-B] ㈜아이티텔레콤 ㈜에티포스 ㈜이씨스 ㈜카네비컴 ㈜켐트로닉스 등이 속해 있다 ',
#  'C-ITS[서비스-B] Cooperative-Intelligent Transport Systems 는 차량사물통신[스펙-B] V2X Vehicle to Everything 을 활용해[스펙-B] 주변 도로[서비스-B] 상황을 실시간으로[스펙-B] 제공하는[이벤트-B] 서비스다 ',
#  '차량-차량[제품-B] 차량-도로[서비스-B] 간 데이터를[기술-B] 양방향으로 공유할[서비스-B] 수 있다 ',
#  '도로에서[서비스-B] 차량이[제품-B] 전복되는[사건/사고-B] 순간 근처 차량에 실시간으로[스펙-B] 정보를[기술-B] 전달해 2차 사고를[사건/사고-B] 예방한다 ',
#  '주요 도로[서비스-B] 완전자율주행[제품-B] 레벨 4 에 꼭 필요한 교통[스펙-B] 인프라로[서비스-B] 여겨진다 ',
#  'C-ITS[서비스-B] 구축은[이벤트-B] 크게 두 가지 방식으로[스펙-B] 나뉜다 ',
#  '근거리전용무선통신[스펙-B] DSRC[스펙-B] 웨이브 과 차량사물통신[제품-B] V2X 방식이다[스펙-B] ',
#  '국토교통부는[스펙-B] DSRC[스펙-B] 방식[스펙-B] 실증사업을[스펙-B] 진행해왔다 ',
#  '과학기술정통부는[스펙-B] C-V2X 방식을[스펙-B] 지원한다[이벤트-B] ',
#  '더구루정예린 기자 미국 스타트업 쿨리아나가 식물로 만든 참치 대체을 출시[이벤트-B] 북미 전역에 매장을[이벤트-B] 둔 포케 전문 프랜차이즈[이벤트-B] 브랜드에 공급한다 ',
#  '3일 업계에 따르면 쿨리아나는 포케 바 Poke Bar 와 계약을[이벤트-B] 맺고 자체 개발한[이벤트-B] 참치 대체육을 공급한다 ',
#  '쿨리아나가 개발한[이벤트-B] 참치 대체품은 해조류 무 대나무 섬유질 등 100% 식물을 기반으로 한다 ',
#  '콜레스테롤이 없으며 포화 지방은[소재-B] 05% 미만이다 ',
#  '참치 대체육 100g 당 지방[소재-B] 함량은 5g에 불과하다 ',
#  '쿨리아나는 실제[스펙-B] 참치의 맛과 질감 등 특징을 살리기 위해 세계적으로 유명한 요리사 및 연구개발[이벤트-B] RD 전문가와 긴밀하게 협력했다고[이벤트-B] 설명했다 ',
#  '야첵 프루스 쿨리아나 최고경영자[이벤트-B] CEO 는 우리의 우선 순위는 환경 및 사회적 책임과 관련해 희생하지 않는 맛있는 식물 기반 참치를 제공하는[이벤트-B] 것이라며 이번 파트너십은[이벤트-B] 식물 기반 단백질[소재-B] 대체품에 대한 수요가 증가하고 있음을 보여주고 있으며 우리는 식품 서비스 부문에 접근 가능하고 맛있는 식물 기반 솔루션을[소재-B] 제공하게 된 것을 기쁘게 생각한다고 밝혔다 ',
#  '최근 식물 기반 단백질의[소재-B] 수요가 높아짐에 따라 대체육에 대한 관심도[스펙-B] 증대하고 있다 ',
#  '급격히 높아진 건강[트렌드-B] 웰니스 웰빙 및 가치소비[트렌드-B] 트렌드에도 부합한다 ',
#  '기존 식물성 대체육류를 생산하는 곳은 많았지만 식물성 해산물을 개발하는[이벤트-B] 곳은 많지 않았다 ',
#  '쿨리아나는 지난 2019년 설립된[이벤트-B] 샌프란시스코 소재 식품 전문 스타트업이다 ',
#  '식물을 활용해[스펙-B] 영양이 풍부하고 맛있으면서도 지속 가능한 참치 등 해산물 대체품을 개발한다[이벤트-B] ',
#  '참치 대체품을 시작으로 향후 연어까지 영역을 확장할[이벤트-B] 계획이다 ',
#  '더구루정예린 기자 신종 코로나바이러스[사건/사고-B] 감염증[트렌드-B] 코로나19 여파로 물류대란이 벌어지고 있는 가운데 미국에서 물류로봇[제품-B] 서비스 모델 Robot as a ServiceRaaS 이 해결책으로[소재-B] 떠올랐다 ',
#  '덩달아 관련 로봇[제품-B] 기업들도 주목받고 있다 ',
#  '3일 업계에 따르면 최근 미국 유통업계는[스펙-B] RaaS를 속속 도입하고[이벤트-B] 있다 ',
#  'RaaS는 물류창고에서 사람을 대신할 로봇을[제품-B] 임대하는 사업모델이다 고객은 필요한 만큼 로봇을 대여해 사용하고 사용한 만큼 금액을 지불하면 된다 ',
#  '유통기업들은[스펙-B] 효율적인 물류센터 관리를 위해 RaaS 도입을[이벤트-B] 결정했다 ',
#  '온라인[기술-B] 주문량이 폭증하고 있지만 코로나19로 직원들의 정상적인 출근 어려워져 수요 예측은 물론 재고 처리 등 전반적인 업무가 마비됐기 때문이다 ',
#  '물류로봇은[제품-B] 기존에도 존재했으나 비싼 초기 구입비용이[이벤트-B] 걸림돌로 작용했다 ',
#  'RaaS 사업이 본격화되면서[사건/사고-B] 유통기업들은[스펙-B] 로봇[제품-B] 구입에 들어갈 수백만 달러 지출을 절감하면서도 로봇과 소프트웨어[제품-B] 관리 서비스까지 대여할 수 있게 됐다 ',
#  '미국 RaaS 기업 중에서는 6 리버 패치 로보틱스[기술-B] 인비아[스펙-B] 로보틱스 로쿠스 로보틱스 등이 떠오르고 있다 ',
#  '이들은 소형[스펙-B] 중형의 자율주행[제품-B] 로봇을[제품-B] 제공하며[이벤트-B] 주로 월간 또는 연간 라이선스 구독[서비스-B] 형태로 로봇을 임대한다 ',
#  '6 리버는 물류창고관리용 소형[스펙-B] 자율주행[제품-B] 로봇[제품-B] 척을 개발했다[이벤트-B] ',
#  '내장[스펙-B] 센서와[제품-B] 소프트웨어를[제품-B] 통해[스펙-B] 상품이[이벤트-B] 위치해 있는 진열대까지 직접 찾아갈 수 있다 ',
#  '또 탑재된 모니터로[제품-B] 실시간[스펙-B] 창고 재고 관리도 가능하다 ',
#  '로봇[제품-B] 8대 기준 첫 해 이용료는 임대료 25만 달러와 연간 유지비 5만 달러가 든다 ',
#  '패치 로보틱스는[기술-B] 최대[이벤트-B] 적재무게[스펙-B] 500kg용과 1500kg용 자율주행[제품-B] 물류로봇을[제품-B] 제공한다[이벤트-B] ',
#  '창고 진열대에서 픽업한 상품을[이벤트-B] 컨베이어 벨트까지 이동하거나 사용자가 설정한 목적지까지 스스로 옮길 수 있다 라이다 ',
#  '센서[제품-B] 3D 카메라[제품-B] 맵핑 소프트웨어[제품-B] 탑재로 사람과 사물을 구분해[스펙-B] 안전하게 이동한다 ',
#  '월간 또는 연간 구독[서비스-B] 형태로[스펙-B] 임차할 수 있다 ',
#  '500kg용 로봇[제품-B] 기준 월 이용료는 장비 옵션에 따라 35005000달러다 ',
#  '인비아[스펙-B] 로보틱스는[기술-B] 다른 기업들과 달리 월간이나 연간 구독[서비스-B] 형태가[스펙-B] 아닌 상품[이벤트-B] 당 이용료를 매긴다 ',
#  '진열대에 놓인 상품[이벤트-B] 1개 당 10센트의 구독료가[서비스-B] 든다 ',
#  '미국 대표 전자상거래[이벤트-B] 기업인 아마존은 지난 2012년부터 물류로봇[제품-B] 기업 키아를 인수해[이벤트-B] 활발하게 이용하고 있다 ',
#  '아마존에 따르면 로봇[제품-B] 도입[이벤트-B] 후 물류센터 운영비용[이벤트-B] 20% 절감 순환속도[트렌드-B] 3배 증가 공간활용도 50% 향상[이벤트-B] 등의 효과를 거뒀다 ',
#  '업계 관계자는 특히 임금에 민감한 유통[스펙-B] 등 산업군에서 로봇의[제품-B] 중요성이 더욱 부각되고 있으며 인공지능[기술-B] 사물인터넷[서비스-B] 기술이[기술-B] 적용되면서[이벤트-B] 활용도가 높아지고 있다며 물류로봇 분야는 매우 빠른 속도로[서비스-B] 자동화가[기술-B] 이뤄지고 있고 가장 큰 걸림돌이었던 초기 구입비용[이벤트-B] 부담이 RaaS 모델로 일정 부분 해소되면서 물류창고 RaaS 시장의 성장이[이벤트-B] 기대된다고 전했다 ',
#  'M오토데일리 박상우 기자 현대차그룹의 미래 신사업[이벤트-B] 분야 사내 스타트업 3곳이 독립기업으로 새롭게 출발했다 ',
#  '4일 현대자동차그룹은[제품-B] 디폰[제품-B] Difon 오토엘 AutoL 데이타몬드 DATAMOND 등 유망 사내 벤처[이벤트-B] 3개사를 분사시켰다고 밝혔다 ',
#  '이번 상반기에 분사한 3개 스타트업은 햇빛[트렌드-B] 양을 사용자가 조절하는 스마트 윈도우 필름을 개발한[이벤트-B] 디폰[제품-B] 높은 성능과[스펙-B] 작은 크기[스펙-B] 경제성까지 갖춘 자율주행용[제품-B] 고해상도 라이다를 개발하는 오토엘 고객이 주도하는 쉽고 편리한 포인트 서비스를 제공하는[이벤트-B] 데이타몬드 등이다 ',
#  '자동차[제품-B] 관련 사업뿐만 아니라 시장성과[이벤트-B] 혁신성을[기술-B] 갖춘 신사업[이벤트-B] 영역으로 진출해[이벤트-B] 현대차그룹과 다양한 업무협력을[이벤트-B] 진행할 예정이다 ',
#  '디폰은[제품-B] 창문에 투과되는 햇빛의[트렌드-B] 양을 사용자가 원하는 만큼 조절할 수 있는 투과율 가변 윈도우 필름을 개발했다[이벤트-B] ',
#  '현대차 독자 기술로[기술-B] 제작된[이벤트-B] 투과율[스펙-B] 가변 윈도우 필름은 차량뿐만[제품-B] 아니라 건물에도 적용[이벤트-B] 가능하다 ',
#  '최적화된 디자인으로[이벤트-B] 시공하기 편리할 뿐만 아니라 가격 경쟁력[이벤트-B] 확보 유해 자외선[스펙-B] 차단 냉난방 에너지[트렌드-B] 절감 등 기존 차광방식이[스펙-B] 가진 문제점을[사건/사고-B] 해소한 것이 특징이다 ',
#  '오토엘은 성능과[스펙-B] 크기[스펙-B] 가격 경쟁력까지[이벤트-B] 확보한 자율주행용[제품-B] 고해상도 라이다 ',
#  '센서를[제품-B] 개발하고[이벤트-B] 있다 ',
#  '현재 시판되고 있는 제품들은[이벤트-B] 가격이 비싸고 차량[제품-B] 외부에 돌출형으로[스펙-B] 탑재할 수밖에 없었다 ',
#  '반면 오토엘의 라이다는 기존 라이다의 한계를 뛰어 넘어 소형이면서도[스펙-B] 주변 환경을 보다 정밀하게 인식할 뿐만 아니라 가격 경쟁력도[이벤트-B] 뛰어나고 차량[제품-B] 장착도[이벤트-B] 용이하다 ',
#  '오토엘은 차량[제품-B] 적용을[이벤트-B] 위한 가혹조건 검증을 마친 후 완성차사와[이벤트-B] 협력사에[이벤트-B] 제품을[이벤트-B] 제공하고[이벤트-B] 양산을[이벤트-B] 준비한다는 계획이다 ',
#  '데이타몬드는 고객 참여형[스펙-B] 포인트 플랫폼인[서비스-B] 포인트 몬스터 POINTMONSTER[스펙-B] 로 쉽고 편리한 포인트 사용 적립 서비스를 제공한다[이벤트-B] ',
#  '고객의 포인트 사용을 통해[스펙-B] 가맹점으로 등록될[이벤트-B] 수 있는 선사용 후가맹 방식으로[스펙-B] 가맹점 등록 절차를 획기적으로 단축한[이벤트-B] 것이 특징이다가맹점으로 등록돼 있지 않더라도 고객 제안을 통해 1분 이내에 제휴할[이벤트-B] 수 있어 공급 기업 중심이 아닌 고객 라이프스타일[트렌드-B] 중심의 포인트 생활을 제공한다[이벤트-B] ',
#  '현대차그룹은 창의적인 아이디어를 가진 임직원들을 지원하고[이벤트-B] 미래 신사업[이벤트-B] 추진[이벤트-B] 동력 창출을 위해 지난 2000년부터 사내 스타트업 육성 프로그램인 벤처플라자를[이벤트-B] 운영해왔다[이벤트-B] ',
#  '올해부터는 프로그램 명칭을 제로원 컴퍼니빌더로 바꾸고 기존 오픈이노베이션[이벤트-B] 플랫폼으로[서비스-B] 운영해오던[이벤트-B] 제로원 브랜드와 통합해[스펙-B] 자동차[제품-B] 위주에서 다양한 분야로 사업 선발 범위를 넓혔다 ',
#  '현대차그룹은 제로원 컴퍼니빌더 지원을[이벤트-B] 위해 아이디어를 공모한 직원들을 대상으로 서류 인터뷰 워크숍[이벤트-B] 발표[이벤트-B] 순으로 심사를 진행하고 선발된 업체에게[이벤트-B] 1년간의 제품서비스[이벤트-B] 개발[이벤트-B] 및 사업화[이벤트-B] 기회와 함께 최대[이벤트-B] 3억원의 개발비용을[이벤트-B] 지원한다 ',
#  '1년 후에는 사업성 재무계획[이벤트-B] 창업 의지 등을 심의하고 분사 또는 사내사업화[이벤트-B] 여부를 결정한다 ',
#  '아울러 새로운 분야로 진출하는[이벤트-B] 직원들의 부담을 덜어주는 차원에서 분사 후 3년까지 재입사 기회를 제공한다[이벤트-B] ',
#  '현대차그룹은 사내 스타트업 분사 후에도 기업 경쟁력[이벤트-B] 제고를 위해 당사 오픈[이벤트-B] 이노베이션 플랫폼인[서비스-B] 제로원을 통해[스펙-B] 사업 개발[이벤트-B] 및 확장[이벤트-B] 운용 자금 마련 해외 진출[이벤트-B] 등을 지원한다[이벤트-B] ',
#  '현대차그룹은 이 제도를[트렌드-B] 통해[스펙-B] 그동안 58개 팀을 선발 및 육성했으며 올해까지 모두 25개의 기업을 분사시켰다 ',
#  '지난해에는 총 10곳의 사내 스타트업이 독립기업으로 출범했으며[이벤트-B] 앞으로도 매년 10개 안팎의 사내벤처[이벤트-B] 기업을 육성 및 분사시킬 계획이다 ',
#  '현대자동차가[제품-B] 정보[기술-B] 보안분야 강화를 위해 신입 및 경력사원 채용을[이벤트-B] 진행한다 ',
#  '현대차가 정보보안[기술-B] 분야의 인재[사건/사고-B] 영입에[이벤트-B] 나선 것은 최근 국내외 고객 대상 웹사이트에 대한 사이버 공격의[사건/사고-B] 위협이[사건/사고-B] 날로 높아지고 있고 커넥티드카의[기술-B] 보급 증대로 첨단[기술-B] 보안 기술이[기술-B] 요구되는 한편 업무 시스템의 클라우드화[기술-B] 및 코로나19 확산에 따른 재택근무[트렌드-B] 등 임직원의 근무환경이 크게 변화한 데 따른 것이다 ',
#  '모집[이벤트-B] 직무는 총 6개로 경력사원은 보안 아키텍처 이상징후 분석시스템[스펙-B] 개발[이벤트-B] 이상징후 분석 및 대응[사건/사고-B] 보안기술[기술-B] 기획[이벤트-B] 침해사고[사건/사고-B] 대응 등이며 신입사원은 위험예방 및 보안분석 분야다 ',
#  '모집[이벤트-B] 대상은 올해 입사 가능한 대졸 이상의 경력자로 자격 요건과 수행 직무 등 세부사항은 현대차 채용[이벤트-B] 홈페이지를 통해[스펙-B] 확인할 수 있다 ',
#  '현대차 관계자는 기업의 정보보안[기술-B] 분야는 향후 더욱 복잡해지고 중요해질 것으로 예상된다며 특히 폭발적으로 늘어나는 커넥티드카와[기술-B] 향후 자율주행[제품-B] 등 IT-전장기술의[기술-B] 비중이 높아지는 자동차[제품-B] 분야에서는 정보보안 분야의 역량을 갖춘 인재[사건/사고-B] 확보 경쟁이[이벤트-B] 치열해질 것이라고 밝혔다 ',
#  '제목을 클릭하시면 해당 기사를 보실[스펙-B] 수 있습니다 ',
#  '28일 월 CJ제일제당 CJ 슈완스 美 냉동피자 점유율[이벤트-B] 20%라인업 확대 OCI 美 中신장 폴리실리콘[소재-B] 수입규제[트렌드-B] 추진韓기업에[이벤트-B] 기회 구글MS애플아마존페이스 美 빅테크 자동차[제품-B] 산업 기웃플랫폼[서비스-B] 영향력 확대 금호타이어[제품-B] 금호타이어 모회사 中 500대 브랜드 선정 기아[트렌드-B] 기아 신형[스펙-B] 쏘울 美 출격6개 트림 니폰덴카이[제품-B] 日 니폰덴카이 상장전기차[제품-B] 배터리용[제품-B] 동박[소재-B] 생산 확대 두산인프라코어[서비스-B] 두산中굴착기 ',
#  '포르쉐바르타 포르쉐 바르타 배터리[제품-B] 쓴다韓 의존도 줄이기 시동 페트로차이나[이벤트-B] 中 CNPC[제품-B] 동티모르에 첫 석유[소재-B] 공급 한국국토정보공사[기술-B] 한국국토정보공사 지난해 안전사고[사건/사고-B] 부상자 80명교육원인[트렌드-B] 조사 부실[스펙-B] 한국타이어[제품-B] 한국타이어 유럽 디지털 홍보[이벤트-B] 전문가 구인 한화테크윈 한화테크윈 CCTV[제품-B] 전설의 카마로 지킨다 ',
#  '현대위아 현대위아 북미 딜러망 확장[이벤트-B] 가속도상반기 3곳 가세 현대자동차[제품-B] 현대차 팰리세이드 중앙아시아 출격카자흐스탄 판매[이벤트-B] 시작 현대자동차 현대차 美서 앨란트라 파격 프로모션[이벤트-B] 60개월 무이자 판매 29일 화 CJ CGV CJ CGV 베트남서 신규 상영관[이벤트-B] 오픈V자[이벤트-B] 반등 기대 LG에너지솔루션하만[소재-B] LG엔솔-하만 GM 올해의 우수 공급업체[이벤트-B] 선정 SBI 리플 영국서 비트코인[스펙-B] 추월거래량[이벤트-B] 8배 수직상승[이벤트-B] SPC삼립[제품-B] 파리바게뜨 ',
#  'CJ제일제당 CJ제일제당 美 자회사 슈완스 비영업용 부동산[트렌드-B] 매각선택과[사건/사고-B] 집중 LG에너지솔루션[소재-B] LG에너지솔루션 호주 리튬업체와[이벤트-B] 공급계약[이벤트-B] MOU LG전자 LG전자 이탈리아서[스펙-B] 고효율 태양광[트렌드-B] 모듈 공급 LG화학 캐나다 운용사 시니그처 LG화학 포트폴리오에[소재-B] 담았다 ',
#  'SK에코플랜트[제품-B] SK에코플랜트 우즈벡 발전소[제품-B] 현대화사업 참여 확대 물밑작업 SPC삼립[제품-B] 파리바게뜨 싱가포르 1호점 확장[이벤트-B] 이전플래그십 스토어 신규 오픈[이벤트-B] TSMC비트메인[스펙-B] 세계 최대[이벤트-B] 암호화폐[트렌드-B] 채굴업체[이벤트-B] 비트메인 TSMC 칩 주문 줄인다 ',
#  '두산중공업한국전력공사[트렌드-B] 국내 최대[이벤트-B] 한림해상풍력단지[트렌드-B] 내년 착공 대한항공 대한항공 코로나로 막힌 日 하늘길 대신 동남아 올인 대한항공 대한항공 美 ATW 선정 올해 최고 항공사 수상 롯데상사 롯데상사 러시아서 곡물 수입 검토지방[소재-B] 투자청[이벤트-B] 회동 삼성전자 삼성전자 탈착식 디스플레이[제품-B] 장착[이벤트-B] 스마트폰[제품-B] 디자인[이벤트-B] 특허[이벤트-B] 출원[이벤트-B] 삼성전자 삼성전자 GAA 기반 3나노[기술-B] 생산체계 구축[이벤트-B] 전력 시놉시스 협력[이벤트-B] 삼성전자에릭슨 삼성에릭슨도이치텔레콤 5G 네트워크[기술-B] 슬라이싱 상용화[이벤트-B] 한발 더 아모레퍼시픽 아모레퍼시픽 ',
#  '현대건설[이벤트-B] 현대건설[이벤트-B] 리비아[스펙-B] 복귀 가시화정부 대표단 현지 사업장 점검[이벤트-B] 현대자동차[제품-B] 현대차 코나EV-테슬라[제품-B] 모델3 英 경찰 순찰차[사건/사고-B] 맞짱 현대자동차 제네시스 로렌자나 유럽 세일즈총괄 스페인 Hug of Manolo 수상 현대자동차 현대차 상해연구소[이벤트-B] 中 스마트카 생태계[트렌드-B] 구축이통테크[스펙-B] 공동연구소[이벤트-B] 설립[이벤트-B] 현대자동차 뇌파로 차량[제품-B] 제어 현대차 中서 B2V[서비스-B] 기술[기술-B] 특허[이벤트-B] 받아 ',
#  '효성TNS 효성 멕시코 ATM 수주전[이벤트-B] 中 막판 경쟁내달[이벤트-B] 1일 발표[이벤트-B] 촉각 7월1일 목 CATLBMW[사건/사고-B] CATL-BMW 친환경[트렌드-B] 밀월 깊어진다 ',
#  '소재팀 구성 ITM파워[기술-B] 英ITM파워 칠레 수소사업[소재-B] 참여 시동정부 대표단과 회동 LG전자 LG전자 美 스마트TV[제품-B] 특허침해[사건/사고-B] 소송[사건/사고-B] 4년 만에 완승 SD바이오센서[제품-B] SD바이오센서 진단키트[제품-B] 수출 훨훨러시아 유통사[스펙-B] 맞손 SK이노베이션 SK이노베이션 헝가리공장 지원금[이벤트-B] 추가 확보2공장 증설[이벤트-B] 속도 SK㈜ SK 인수[이벤트-B] 이포스케시 프랑스 정부 지원금 받는다 ',
#  '넷마블 넷마블 마블 렐름 오브 챔피언스 대규모[이벤트-B] 업데이트커스터마이징[이벤트-B] 강화 대한조선 대한조선 3000억원 아프라막스급 원유운반선 4척 수주[이벤트-B] 임박 마이크로소프트 마이크로소프트-솜포 스타트업 위조에 2500만 달러 투자[이벤트-B] ',
#  '미래에셋증권NH투자증권[이벤트-B] 미래에셋NH증권 인니 모바일 쿠폰[제품-B] 플랫폼[서비스-B] 울트라바우처 IPO[이벤트-B] 맞손 삼성SDI EU 삼성SDI 헝가리공장 보조금[트렌드-B] 조사 연장 삼성전자 삼성 엑시노스 애플 A14 대비 우월한 성능[스펙-B] 재확인[이벤트-B] 애디티브 손영권 전 삼성 CSO 독일 3D프린팅 건축기업 엔젤투자자[이벤트-B] 참여 애플 애플 포트리스[서비스-B] 인베스트먼트 상대 소송[사건/사고-B] 철회반독점[이벤트-B] 소송 대응[사건/사고-B] 일환 포스코 인도 NMDC[스펙-B] 포스코 철광석[소재-B] 수출 재개 검토 한국동서발전SK디앤디NH농협생명교보생명[이벤트-B] ',
#  '하나은행 적자[사건/사고-B] 눈덩이 인니 가루다항공 채무[사건/사고-B] 구조조정[사건/사고-B] 안간힘[사건/사고-B] 한화큐셀[제품-B] 美 상원의원 또 한화큐셀 공장 방문청정에너지[트렌드-B] 아이콘 등극 현대건설[이벤트-B] 현대건설[이벤트-B] 눈독 엘살바도르 철도사업 본격화타당성조사[사건/사고-B] 돌입 현대모비스현대위아만도 현대모비스 세계 자동차[제품-B] 부품업계 톱7 현대자동차 현대차 美 앨라배마 생산라인 재정비전기차[제품-B] 플랜B 가동 현대중공업대우조선해양삼성중공업[트렌드-B] 카타르 LNG선[소재-B] 45척 선주 입찰[이벤트-B] 내달 마감연내 발주[이벤트-B] 시동 현대중공업대우조선해양삼성중공업 조선 3사 17조 ',
#  'KB국민신한하나우리은행 국민신한하나우리銀 인니법인[트렌드-B] 최고 신용등급모회사[이벤트-B] 지원능력[이벤트-B] 우수 SD바이오센서[제품-B] SD바이오센서로슈 협업 진단키트[제품-B] 캐나다 출시[이벤트-B] SEAHU[스펙-B] SEAHU 미국서 스포츠 도박사업 추가 추진[이벤트-B] SK이노베이션 SK이노 배터리[제품-B] 분사 빠를수록 좋다연내 흑자[이벤트-B] 전환 기아[트렌드-B] 기아 유럽서 썸머 익스퍼리언스 이색 마케팅[이벤트-B] 진행유나이티드 뮤직 파트너십[이벤트-B] 기아 기아 더 2022 쏘렌토 출시하이브리드[소재-B] 모델도 가세 ',
#  '오뚜기 오뚜기×맥도날드 양념치킨 홍콩 공략세븐일레븐과도 협업 올라일렉트릭 현대차 투자[이벤트-B] 올라일렉트릭 전기차스쿠터[제품-B] 공장 완공 임박 우아한형제들[스펙-B] 우아한형제들-아이프라이스 협업 청사진[이벤트-B] 윤곽플랫폼서비스[서비스-B] 결합[스펙-B] 엣시 엣시 브라질 이커머스 기업 인수남미[이벤트-B] 진출[이벤트-B] 교두보 에코프로이노베이션[트렌드-B] 에코프로이노베이션 美 리튬[소재-B] 업체와[이벤트-B] 공급 계약[이벤트-B] 차지포인트 美 전기차 대장주 차지포인트 경영진[이벤트-B] ',
#  'ELMS[스펙-B] 美전기차[제품-B] 스타트업 ELMS SPAC 합병[이벤트-B] 상장3분기[이벤트-B] 배달용 전기 밴 생산 KB국민은행 인니 델타 변이 대확산KB부코핀 투자자[이벤트-B] 기업설명회[이벤트-B] 연기[사건/사고-B] SK ES[이벤트-B] SK ES 중국 시정부 회동가스[트렌드-B] 협력[이벤트-B] 속도 SK이노베이션 SK이노베이션 美 ESS시장[제품-B] 출사표테라썬과 MOU 국민연금공당[트렌드-B] 국민연금 1조짜리 호주 멜버른 오피스 빌딩 인수[이벤트-B] 기아[트렌드-B] 기아 인도 6월 판매[이벤트-B] 36%디지털 판매 通했다 ',
#  '나노젠[기술-B] 넥스트사이언스 관게사 나노젠 코로나 백신 임상에 지멘스 헬시니어스 협력[이벤트-B] 니콜라 니콜라 美 청정수소[소재-B] 프로젝트[이벤트-B] 투자한화[이벤트-B] 협력 기대감 대우조선해양[트렌드-B] 대우조선 중국에 밀려 풍력설치선[트렌드-B] 수주[이벤트-B] 실패[스펙-B] 대웅제약 대웅제약 임팩타민[제품-B] 인도네시아 출시현지[이벤트-B] 건기식시장 공략 롯데호텔 롯데호텔 러시아 온라인[기술-B] 쇼핑몰 더숍 론칭호텔용품[이벤트-B] 판매[이벤트-B] 루시드모터스 루시드모터스 루시드에어 사전예약 1만건 돌파테슬라 ',
#  '르노그룹로얄더치쉘 르노-쉘 현대차 투자[이벤트-B] 전기차[제품-B] 충전업체[이벤트-B] 아이오니티 지분 눈독 모놀리스[서비스-B] SK 투자 모놀리스 카본블랙[소재-B] 공장 확장[이벤트-B] 장애물[사건/사고-B] 극복 삼성벤처투자[이벤트-B] 삼성 제2의 비트코인[스펙-B] NFT 시장 눈독블록체인[기술-B] 게임사[트렌드-B] 애니모카 투자 ',
#  '삼성화재[사건/사고-B] 삼성화재[사건/사고-B] 투자[이벤트-B] 베트남 피지코 선박화재[사건/사고-B] 보상금[이벤트-B] 250억대규모[이벤트-B] 손실[스펙-B] 불가피 제주항공 제주항공 日 노선 축소[사건/사고-B] 연장괌사이판 집중 테슬라 테슬라 신형[스펙-B] 모델S 플레이드 원인불명[사건/사고-B] 화재[사건/사고-B] 포스코 포스코 탄자니아서 전기차[트렌드-B] 배터리[제품-B] 핵심소재[소재-B] 흑연[소재-B] 조달 임박투자 결실[스펙-B] 포스코 포스코 기술상[기술-B] 주인공 캐나다 리튬기업[소재-B] 이사회 합류 현대엔지니어링[기술-B] 현대엔지니어링 폴란드 폴리체[소재-B] 플랜트[제품-B] 건설[이벤트-B] 하도급 계약[이벤트-B] 현대자동차[제품-B] 현대차 상반기 브라질 시장 4위전년 대비 50% 성장[이벤트-B] 현대자동차 현대차 6월 인도 판매[이벤트-B] 77%회복세 본격화[사건/사고-B] 현대자동차기아[트렌드-B] 세단의 ',
#  'M 오토데일리 최태인 기자 현대차그룹이 오픈이노베이션[이벤트-B] 플랫폼[서비스-B] 제로원 엑셀러레이터[제품-B] ZER01NE ACCELERATOR[소재-B] 의 2021년 하반기 스타트업 공개[이벤트-B] 모집을[이벤트-B] 진행한다고 5일 밝혔다 ',
#  '제로원 엑셀러레이터는[제품-B] 현대차그룹 내 현업 팀이 직접 발제한 아이디어를 기반으로 우수한 역량을 가진 스타트업을 발굴해[이벤트-B] 협업 프로젝트를[이벤트-B] 구축하고[이벤트-B] 다양한 혁신[기술-B] 기술의[기술-B] 전략적[이벤트-B] 활용 가능성을 검증 및 개발하는[이벤트-B] 프로그램이다 ',
#  '현업 팀이 스타트업과 협업하고 싶은 프로젝트를[이벤트-B] 제시하고 선발 과정에도 참여해 최종 선발된 스타트업과 공동으로 프로젝트를 수행하며 회사 간 경계를 넘어서 새로운 기술[기술-B] 개발에[이벤트-B] 대한 시너지를[이벤트-B] 창출해내는 것이 특징이다 ',
#  '이번 제로원 엑셀레이터는[제품-B] 모빌리티물류 MOBILITY[기술-B] LOGISTICS5건[스펙-B] 친환경[트렌드-B] ECO-TECH6건[소재-B] 사용자 경험 IN-CAR[기술-B] UX7건 비전 AI[기술-B] VISION AI6건 데이터[기술-B] 분석[스펙-B] AI ANALYTICS5건 소재 MATERIALS7건 드론로봇[제품-B] DRONES[스펙-B] ROBOTS4건 콘텐츠 INTERACTIVE[스펙-B] CONTENTS 4건 기타 ETC1건 ',
#  '지원[이벤트-B] 시점에 법인[트렌드-B] 설립이[이벤트-B] 완료된 스타트업에 한해 지원이 가능하고 접수는[이벤트-B] 7월 1일부터 29일까지 총 4주간 제로원 엑셀러레이터[제품-B] 공식[이벤트-B] 홈페이지를 통해[스펙-B] 할 수 있다 ',
#  '최종 결과는 서류 인터뷰 심사 등의 과정을 거쳐 오는 9월 발표된다[이벤트-B] ',
#  '최종 선발된 스타트업은 최대[이벤트-B] 5천만원의 프로젝트[이벤트-B] 개발비[이벤트-B] 지원[이벤트-B] 및 제로원 엑셀레이터의[제품-B] 지분 투자[이벤트-B] 검토 대상으로 선정된다 ',
#  '한편 2018년에 시작한 제로원 엑셀러레이터[제품-B] 프로그램은 현대차그룹 내 9개 그룹사 60개 팀과 스타트업 73개 사가 참여하고 있으며 현재까지 64건의 협업 프로젝트[이벤트-B] 및 39개 사 대상 지분 투자[이벤트-B] 집행 등의 성과를[이벤트-B] 이뤄냈다 ',
#  '더구루정예린 기자 현대 SK 한화가 투자한[이벤트-B] 이스라엘 스타트업 아브로보틱스의[기술-B] 상장[이벤트-B] 준비에 제동이[사건/사고-B] 걸렸다 ',
#  '합병[이벤트-B] 계약을[이벤트-B] 체결한[이벤트-B] 기업인수목적회사[이벤트-B] SPAC스팩[제품-B] 가 집단 소송을[사건/사고-B] 당할 위기에[사건/사고-B] 놓이면서다 ',
#  '5일 업계에 따르면 미국 로펌 리그로드스키[스펙-B] 로우는 지난 3월 아브로보틱스와[기술-B] 합병계약을[이벤트-B] 체결한[이벤트-B] 스팩[제품-B] 인더스트리얼 테크 애퀴지션 이하 ITAC[기술-B] 투자자를[이벤트-B] 대상으로 집단 소송[사건/사고-B] 참여자를 모집하고[이벤트-B] 있다 ',
#  '로펌은 아브로보틱스와[기술-B] 합병하기로[이벤트-B] 한 ITAC의[기술-B] 계약[이벤트-B] 관련 신탁 의무 위반[사건/사고-B] 및 기타 법률[트렌드-B] 위반 가능성에 대해 조사하고 있다고 명시했다 ',
#  '아브로보틱스는[기술-B] 지난 2015년 설립된[이벤트-B] 차세대 4D 이미지 레이더[제품-B] 칩셋[제품-B] 솔루션[소재-B] 제공업체다[이벤트-B] ',
#  '자율주행차량[제품-B] 및 첨단운전자보조시스템[기술-B] ADAS[서비스-B] 의 고해상도 감지를 가능케 하는 기술을[기술-B] 보유하고 있다 ',
#  '아브로보틱스의[기술-B] 레이더[제품-B] 기술은[기술-B] 일반 레이더에 비해 100배 가량 정교한 것으로 평가받는다 ',
#  '특히 인식률이 낮았던 기존 센서들과[제품-B] 달리 아브로보틱스의[기술-B] 제품은[이벤트-B] 4D 고해상도 영상 인식이 가능 자율주행[제품-B] 기술[기술-B] 수준과 안전성을[스펙-B] 획기적으로 높일 것으로 기대된다 ',
#  '26개 이상의 주요 자동차[제품-B] OEM 등을 고객사로 두고 있다 ',
#  '지난 3월 나스닥[스펙-B] 상장을[이벤트-B] 위해 ITAC와[기술-B] 합병[이벤트-B] 5억7200만 달러 약 6470억4600만원 의 기업 가치를 인정받았다 ',
#  '양사는[이벤트-B] 3분기 내 주주총회를[이벤트-B] 개최[이벤트-B] 주주의 승인을[이벤트-B] 얻어 거래를[이벤트-B] 마무리할 계획이다 ',
#  '아브로보틱스는[기술-B] 현대자동차와[제품-B] SK텔레콤 한화자산운용이 조성한[스펙-B] 스타트업 투자[이벤트-B] 펀드 AI얼라이언스로부터[기술-B] 투자받았다 ',
#  'AI얼라이언스는[기술-B] 지난해 아브로보틱스의[기술-B] 3200만 달러 약 362억원 규모[이벤트-B] 투자[이벤트-B] 펀딩에[트렌드-B] 참여했다 ',
#  '구체적인[스펙-B] 투자[이벤트-B] 규모는[이벤트-B] 알려지지 않았다 ',
#  'AI얼라이언스는[기술-B] 지난 2017년 현대차와 SK텔레콤 한화자산운용이 혁신[기술-B] 기술을[기술-B] 갖춘 미국 유럽 이스라엘 등 글로벌 스타트업에 투자하기[이벤트-B] 위해 설립한[이벤트-B] 펀드다 ',
#  '3사가 각각 1500만 달러 약 170억원 씩 출자했다[이벤트-B] 한편 아브로보틱스가[기술-B] 강점을 가진 자동차[제품-B] 레이더[제품-B] 시장 규모는[이벤트-B] 2020년 40억 달러 약 4조5000억원 수준에서 2025년 110억 달러 약 12조4000억원 까지 약 3배 급성장할[이벤트-B] 전망이다[이벤트-B] ',
#  '더구루윤진웅 기자 기아가[트렌드-B] 미국 조지아주가[트렌드-B] 추진하는[이벤트-B] 인터스테이트 하이웨이 Interstate highway V2X Vehicle to everything 인프라[서비스-B] 구축[이벤트-B] 사업자로 선정됐다 ',
#  '차량사물[제품-B] 셀룰러[제품-B] 통신[스펙-B] Cellular Vehicle-to-EverythingC-V2X 차량 등을 지원[이벤트-B] 조지아 지역의 커넥티드카[기술-B] 생태계[트렌드-B] 구축에[이벤트-B] 적극 나선다는 계획이다 ',
#  '5일 업계에 따르면 조지아주 교통부[스펙-B] Georgia Department of TransportationGDOT 는 기아를[트렌드-B] V2X 인프라[서비스-B] 구축[이벤트-B] 사업자로 선정했다 ',
#  '더 레이 익스프레스웨이[스펙-B] The Ray Expressway 를 시작으로 자율주행[제품-B] 기반의 커넥티드카[기술-B] 생태계[트렌드-B] 구축한다는[이벤트-B] 것 ',
#  'V2X는 차량이[제품-B] 다른 차량이나 보행자 다양한 교통[스펙-B] 관련 인프라와[서비스-B] 정보를[기술-B] 교환하는 기술을[기술-B] 말한다 ',
#  '신호 우선순위 도로[서비스-B] 작업 구역 경고[사건/사고-B] 등을 운전자에게 실시간으로[스펙-B] 제공해[이벤트-B] 교통[서비스-B] 안전 개선[이벤트-B] 효과를 줄 것으로 업계는 보고[이벤트-B] 있다 ',
#  '또한 자율주행의[제품-B] 완성도를[이벤트-B] 높이는[스펙-B] 데 크게 기여할 것으로 평가하고 있다 ',
#  '실제[스펙-B] 미국 고속도로[서비스-B] 교통안전국[스펙-B] NHTSA[스펙-B] 이 발표한[이벤트-B] 자료에 따르면 V2X 기술[기술-B] 적용[이벤트-B] 시 충돌[스펙-B] 사고[사건/사고-B] 발생을[이벤트-B] 80%가량 줄일 수 있는 것으로 나타났다 ',
#  '기아는[트렌드-B] V2X 인프라[서비스-B] 개발[이벤트-B] 계획 두 번째 단계를 맡게 됐다 ',
#  '현대자동차[제품-B] 미국 기술연구소[이벤트-B] HATCI 의 지원[이벤트-B] 아래 C-V2X 커넥티드[기술-B] 차량[제품-B] 10대를 제공할[이벤트-B] 계획이다 ',
#  '지난 2019년 첫 번째 단계로 V2X 테스트 환경이 조성된[스펙-B] 29km 구간의 레이 도시 고속화 도로에[서비스-B] 투입된다 ',
#  '헤드 업 디스플레이[제품-B] HUD 를 통해[스펙-B] 실시간[스펙-B] 교통[스펙-B] 정보를[기술-B] 전달할 예정이다 ',
#  '특히 GDOT가 오랜 기간 공을 들이고 있는 사업인 만큼 기아의[트렌드-B] 현지 입지도 확대될 전망이다[이벤트-B] ',
#  'GDOT는 지난 2017년부터 애틀랜타 지역의 커넥티드카[기술-B] 생태계[트렌드-B] 구축에[이벤트-B] 적극 투자하고[이벤트-B] 있다 ',
#  '향후 1000개 이상 네트워크[기술-B] 교차로를 구축한다는[이벤트-B] 계획이다 ',
#  '업계 관계자는 V2X는 자동차[제품-B] 안전사고[사건/사고-B] 예방 효과 등으로 최근 주목받고 있는 미래 기술[기술-B] 중 하나라며 이번 사업자 선정이 최근 브랜드 혁신을[기술-B] 발표한[이벤트-B] 기아의[트렌드-B] 이미지를 높이는[스펙-B] 데 일조할 것으로 보인다고 말했다 ',
#  '더구루오소영 기자 미국 빅데이터[기술-B] 전문 회사 팔란티어 테크놀로지스 Palantir Technologies 이하 팔란티어 는 기업인수목적회사[이벤트-B] SPAC스팩[제품-B] 와의 합병으로[이벤트-B] 상장을[이벤트-B] 노리는 스타트업들에 투자를[이벤트-B] 확대하고 있다 ',
#  '자금 조달을 지원하고[이벤트-B] 그 대가로[사건/사고-B] 소프트웨어[제품-B] 공급 계약을[이벤트-B] 맺어 수익을 올린다는 전략이다[이벤트-B] ',
#  '5일 업계에 따르면 팔란티어는 스팩[제품-B] 합병[이벤트-B] 8건에 상장지분사모펀드[이벤트-B] PIPE 로 참여했다 ',
#  '투자액은[이벤트-B] 1억 달러 약 1130억원 가 넘는다 ',
#  '구체적으로[스펙-B] 독일 에어택시[제품-B] 개발[이벤트-B] 스타트업 리리움 4100만 달러 약 460억원 미국 산업용 로봇[제품-B] 전문 업체[이벤트-B] 사코스 로보틱스에[기술-B] 2100만 달러 약 230억원 태반을 활용해[스펙-B] 치료제를 연구하는[이벤트-B] 미국 생명공학 회사 셀룰래리티에[제품-B] 2000만 달러 약 220억원 스위스 글로벌 신약기술[기술-B] 지주업체 로이반트사이언스에 3000만 달러 약 340억원 를 투입했다 ',
#  '영국 원격의료[서비스-B] 스타트업 바빌론 헬스커넥티드카[기술-B] 데이터[기술-B] 업체[이벤트-B] 위조 미국 디지털 치료제 분야 선두 업체 피어 테라퓨틱스온라인[기술-B] 소매업체[이벤트-B] 박스드도 투자[이벤트-B] 명단에 포함됐다 ',
#  '쉬얌 상카르 팔란티어 최고운영책임자[이벤트-B] COO[소재-B] 는 투자전문지[이벤트-B] 배런스 barrons 에서 팔란티어는 3월 말까지 현금 24억 달러 약 2조7100억원 의 10% 미만을 쏟았다고 밝혔다 ',
#  '팔란티어는 투자[이벤트-B] 기업들과 다년간의 소프트웨어[제품-B] 공급 계약을[이벤트-B] 체결했다[이벤트-B] ',
#  'PIPE 참여와 소프트웨어[제품-B] 판매를[이벤트-B] 맞거래[이벤트-B] 하는 방식으로[스펙-B] 신규 고객을 확보했다 ',
#  '팔란티어가 제공하는[이벤트-B] 소프트웨어는[제품-B] 크게 두 가지다 ',
#  '빅데이터[기술-B] 분석을[스펙-B] 기반으로 테러와[트렌드-B] 돈세탁 마약 거래[이벤트-B] 등 범죄를 포착하는 팔란티어 고담과 금융사기[트렌드-B] 피해[사건/사고-B] 방지[이벤트-B] 내부 비리[사건/사고-B] 감지 제품[이벤트-B] 생산 관리 분석 등을 제공하는[이벤트-B] 팔란티어 파운드리다 ',
#  'M오토데일리 박상우 기자 현대차그룹과 미국의 세계적인 예술대학 로드아일랜드[스펙-B] 디자인스쿨[이벤트-B] Rhode Island School of Design RISD 이 미래 도시 디자인을 주제로 공동연구한[이벤트-B] 협업 프로젝트를[이벤트-B] 공개했다[이벤트-B] ',
#  '이번 공동연구는[이벤트-B] 지난해 현대차그룹과 RISD가 미래 모빌리티 비전을 구현하기[이벤트-B] 위해 추진한[이벤트-B] 디자인[이벤트-B] 협업을 계승한 것으로 오랜 시간에 걸쳐 거대한 진보와 발전을[이벤트-B] 거듭하고 있는 자연에서 혁신적인[기술-B] 디자인 아이디어를 발굴하는[이벤트-B] 것을 목표로 진행됐다 ',
#  '특히 이번 프로젝트는[이벤트-B] 지난해 미래 모빌리티 Future Mobility 보다 범위가 확장된[이벤트-B] 미래 도시 Future City 를 주제로 디자인[이벤트-B] 협업이 이뤄졌다 ',
#  '전기차[제품-B] 수소전기차[소재-B] 자율주행차[제품-B] 등 미래 자동차를[제품-B] 비롯해 도심항공모빌리티[제품-B] UAM[제품-B] 스마트 시티 등 미래 모빌리티 생태계[트렌드-B] 구축을[이벤트-B] 추진[이벤트-B] 중인 현대차그룹과 세계 최고 수준의 디자인[이벤트-B] 연구역량을[이벤트-B] 보유한 RISD가 한층 넓어진 미래 도시를 주제로 공동연구를[이벤트-B] 이어간다는 점에서 의미가 크다 ',
#  '현대차그룹과 함께 연구를[이벤트-B] 추진하는[이벤트-B] 곳은 RISD 산하 네이처 랩 Nature Lab 으로 1937년 설립[이벤트-B] 이후 자연 생명체와 생태계에[트렌드-B] 대한 다양하고 심도[스펙-B] 깊은 연구활동을 지원해[이벤트-B] 온 연구기관이며 다양한 동식물 곤충 등의 생물표본과[이벤트-B] 최첨단[기술-B] 연구설비를 보유한 것으로 유명하다 ',
#  'RISD는 현대차그룹과의 공동연구를[이벤트-B] 위해 지난해에 이어 산학협력[이벤트-B] 프로그램을 개설해 운영했다[이벤트-B] ',
#  'RISD 교수진 5명이 프로젝트를[이벤트-B] 이끌었으며 현대차기아[트렌드-B] 디자이너들이 연구를[이벤트-B] 지원했다[이벤트-B] ',
#  '여기에 치열한 경쟁[이벤트-B] 끝에 선발된 건축 그래픽 디자인[이벤트-B] 산업 디자인 등 10개 전공의 RISD 학생 32명도 연구자로[이벤트-B] 참여했다 ',
#  '지난해 공동연구에[이벤트-B] 나선 현대차 소속뿐만 아니라 기아[트렌드-B] 소속의 디자이너가 새롭게 프로젝트에[이벤트-B] 참여하고 연구자로 참여한 학생의 수가 전년 대비 2배 늘어나 협업의 의미를 더했다 ',
#  '공동연구는[이벤트-B] 올해 25월 RISD의 봄 학기 동안 디지털미디어[트렌드-B] Digital Media 산업디자인건축[이벤트-B] Industrial Design Architecture 일러스트레이션 Illustration 텍스타일[트렌드-B] Textiles 등 4개 디자인 분야에 걸쳐 진행됐다 ',
#  '디지털미디어[트렌드-B] 디자인[이벤트-B] 연구팀은[이벤트-B] 자가치유 세포와 바이오센싱을 이용해[스펙-B] 주변 환경과 상호 반응할 수 있는 디자인을 연구했다 ',
#  '또한 박테리아 곰팡이 등 미생물[소재-B] 연구를[이벤트-B] 통해[스펙-B] 환경오염[트렌드-B] 문제[사건/사고-B] 해결을[소재-B] 위한 여러 아이디어를 도출했다 ',
#  '산업디자인건축[이벤트-B] 디자인 연구팀은[이벤트-B] 자연 생태계에[트렌드-B] 대한 탐구를 바탕으로 지속가능한 미래 도시를 구현할[이벤트-B] 여러 연구 모델과 시나리오를 제안했다 ',
#  '이 팀은 미래 사회에 새로운 경험과 가치를 제공할[이벤트-B] 인프라[서비스-B] 환경을 구축하는[이벤트-B] 디자인[이벤트-B] 방안에 대해서도 고민했다 ',
#  '일러스트레이션 디자인[이벤트-B] 연구팀은[이벤트-B] 미디어[트렌드-B] 애니메이션 소리 등 시청각적 요소를 활용해[스펙-B] 복잡한 도시 속 정보를[기술-B] 명료하게 시각화할 수 있는 여러 디자인에 대해 연구했다 ',
#  '마지막으로 텍스타일[트렌드-B] 디자인[이벤트-B] 연구팀은[이벤트-B] 새로운 가치를 창출하는[이벤트-B] 직물과 구조물을 디자인하기 위해 인간의 다양한 행동을 분석했다[스펙-B] ',
#  '또한 누에고치처럼 스스로를 보호하는 자연의 특성을 디자인에[이벤트-B] 응용하는 방안을 연구했다[이벤트-B] ',
#  '현대차그룹과 RISD는 봄 학기에 이어 올여름 학기에는 심화 연구를[이벤트-B] 진행할 예정으로 미래 도시를 구현할[이벤트-B] 다양한 디자인[이벤트-B] 아이디어를 발굴하기[이벤트-B] 위해 지속 협력해[이벤트-B] 나갈 계획이다 ',
#  'M 오토데일리 이상원기자 현대자동차가[제품-B] 지분 투자한[이벤트-B] 크로아티아의 전기차[제품-B] 하이퍼카 스타트업인 리막 Rimac 이 112년 전통의[스펙-B] 수퍼카 브랜드 부가티와 인수[이벤트-B] 합병한다[이벤트-B] ',
#  '리막은 부가티와 합병해[이벤트-B] 새로 탄생하는 부가티-리막 지분 55%를 보유하며 두 브랜드는 같은 배지를 달고 별도로[서비스-B] 제작되지만[이벤트-B] 향후 부가티는 리막의 고성능[스펙-B] 전기[트렌드-B] 드라이브 트레인을 사용하게 된다 ',
#  '또 리막그룹 지분 24%를 보유하고 있는 포르쉐는 부가티-리막의 나머지 지분 45%를 폴크스바겐을 대신해 인수한다[이벤트-B] ',
#  '리막은 오는 9월까지 부가티 인수작업을[이벤트-B] 완료할 예정이다 ',
#  '정식 명칭 리막 오토모빌리 Rimac Automobili 는 2009년에 설립한[이벤트-B] 스타트업으로 고성능[스펙-B] 하이퍼 전동형[스펙-B] 시스템 및 EV[제품-B] 스포츠카 분야에서 선두를 달리고 있으며 현대차와 기아가[트렌드-B] 지난 2019년 8천만유로 1067억 원 를 투자[이벤트-B] 3대 주주 자리에 있다 ',
#  '부가티는 112년 전통을[스펙-B] 자랑하는 폭스바겐그룹 산하 고성능[스펙-B] 수퍼카 브랜드로 지난 2019년 폭스바겐그룹이 신형[스펙-B] 하이브리드[소재-B] 차종의 부품 공급을 위해 리막과 협의를 진행하면서 부가티와의 합병설이[이벤트-B] 거론됐다 ',
#  '당시 리막은 자연흡기 엔진의[제품-B] 하이브리드[소재-B] 파워트레인이[제품-B] 장착된[이벤트-B] 완전히 새로운 자동차를[제품-B] 저렴한 가격에 개발하겠다고[이벤트-B] 제안했으며 폭스바겐은 리막으로부터 신차[제품-B] 엔지니어링[기술-B] 가치의 대부분을 구입하는 대신 리막에 합병을[이벤트-B] 제안했다 ',
#  '이번 계약의[이벤트-B] 일환으로 리막오토모빌리는 리막그룹으로 이름을 바꾸고 부가티-리막을 계열사로[이벤트-B] 두게 된다 ',
#  '더구루오소영 기자 삼성전자가 일본 통신계측[스펙-B] 장비 전문 업체[이벤트-B] 안리쓰와 5세대 5G 테스트 장비 시험에 협력했다[이벤트-B] ',
#  '6일 업계에 따르면 안리쓰는 삼성전자의 5G 엑시노스 모뎀을[제품-B] 사용해[스펙-B] MT8000A의 성능을[스펙-B] 시험했다 ',
#  'MT8000A로 5G 모뎀이[제품-B] 저전력을[트렌드-B] 비롯해 최신 표준인 릴리즈16 R16 에 포함되는 기술을[기술-B] 갖췄는지를 제대로 검증할 수 있는지 살폈다 ',
#  '릴리즈16은 무선통신[스펙-B] 국제표준화 기술협력[이벤트-B] 기구인 3GPP[소재-B] 3rd Partnership Project 가 승인한[이벤트-B] 차세대 5G 규격이다[스펙-B] ',
#  '전력[트렌드-B] 효율과 간섭[스펙-B] 완화 이동성 향상[이벤트-B] 등 5G 성능[스펙-B] 개선에[이벤트-B] 초점을 맞춘 것이 특징이다 ',
#  '자율주행차와[제품-B] 스마트 공장 등에 특화된 기능이 포함됐다 ',
#  '안리쓰는 앞서 미디어텍과도[트렌드-B] MT8000A의 성능을[스펙-B] 테스트했다 ',
#  '잇단 협업으로 테스트 장비의 우수성을[소재-B] 알리고 고객사를 확보할 방침이다[이벤트-B] ',
#  'MT8000A는 일체형[스펙-B] 5G 테스트 장비로 복합표준 NSA 와 단독표준 SA 를 모두 지원한다[이벤트-B] ',
#  '하나의 장비로 6GHz 이하와 밀리미터파 mmWave 주파수 대역의 RF 프로토콜 테스트를 제공한다[이벤트-B] ',
#  '6GHz 대역 이하에서의 4개의 안테나를[제품-B] 동시에 사용 4X4 MIMO 하는 다중안테나 등 최신 기술[기술-B] 테스트도 가능하다 ',
#  '신야 아지로 안리쓰 모바일 솔루션[소재-B] 부문 총괄은 삼성과[이벤트-B] 시장을 선도하는 5G 제품[이벤트-B] 개발에[이벤트-B] 협력할[이벤트-B] 수 있어 기쁘다며 첨단[기술-B] 5G의 길을 닦는 데 삼성과 앞으로 파트너십을[이벤트-B] 지속하기를 기대한다고 밝혔다 ',
#  '김종한 삼성전자 시스템LSI[소재-B] SOC[스펙-B] 개발실[스펙-B] 상무는 안리쓰의 강력한 테스트 플랫폼은[서비스-B] 삼성 5G 엑시노스 모뎀의[제품-B] 성능을[스펙-B] 재입증하는[이벤트-B] 데 도움이 됐다며 안리쓰와의 파트너십을[이벤트-B] 이어가 제품[이벤트-B] 개발에서 출시까지[이벤트-B] 이어지는 시간을 단축할[이벤트-B] 수 있을 것이라고 밝혔다 한편 안리쓰는 120여 년간 통신[스펙-B] 분야의 혁신적인[기술-B] 계측기를 개발해 온 회사다 ',
#  '더구루윤진웅 기자 기아가[트렌드-B] 북아프리카 알제리[서비스-B] 육군 경장갑차 Light Tactical VehicleLTV[제품-B] 수주전[이벤트-B] 승기를 잡았다 ',
#  '3파전으로 전개되고 있는 가운데 기아가[트렌드-B] 최저가 입찰로[이벤트-B] 승부수를 띄우며 분위기[사건/사고-B] 반전에 성공했다[이벤트-B] ',
#  '더구루오소영 기자 미국 인공지능[기술-B] AI[기술-B] 스타트업 빅베어닷에이아이 BigBearai 가 무인항공기[트렌드-B] UAV 업체와[이벤트-B] 상업국방용[트렌드-B] 솔루션을[소재-B] 선보인다 ',
#  '현지 정부 기관을 적극 공략해 실적을[스펙-B] 올리고 나스닥[스펙-B] 상장에[이벤트-B] 드라이브를 건다 ',
#  '빅베어닷에이아이는 1일 현지시간 UAV 팩토리와[제품-B] 상업국방용[트렌드-B] 무인 시스템에 탑재될 AI머신러닝[기술-B] ML 을 개발하고자[이벤트-B] 양해각서[이벤트-B] MOU 를 체결했다고[이벤트-B] 밝혔다 ',
#  '2020년 설립된[이벤트-B] 빅베어닷에이아이는 AI와[기술-B] ML 클라우드[기술-B] 기반 빅데이터[기술-B] 분석[스펙-B] 솔루션을[소재-B] 제공하는[이벤트-B] 회사다 ',
#  '미국 정보부와[기술-B] 국방부[트렌드-B] 등 정부 기관을 비롯해 인프라와[서비스-B] 에너지[트렌드-B] 물류 등 다양한 업종의 고객에게 데이터[기술-B] 분석[스펙-B] 솔루션을[소재-B] 제공한다[이벤트-B] ',
#  '미국 국토안보부[트렌드-B] 과학기술본부[기술-B] 차관 출신 레지 브라더스가 최고경영자[이벤트-B] CEO 로 있다 ',
#  'UAV 팩토리는[제품-B] 소형[스펙-B] UAV를 설계제조하는[이벤트-B] 회사로 2009년 설립됐다[이벤트-B] ',
#  '43개국 165개가 넘는 고객에 제품을[이벤트-B] 공급했다 ',
#  '양사는[이벤트-B] 빅베어닷에이아이의 AIML[기술-B] 기술과[기술-B] UAV 팩토리의[제품-B] UAV 노하우를[이벤트-B] 결합해[스펙-B] 첨단[기술-B] 정보감시활동[사건/사고-B] ISR 서비스를 선보인다 ',
#  'UAV로 수집한 데이터를[기술-B] 분석해[스펙-B] 유의미한 정보를[기술-B] 취득하는데 탁월한 솔루션이[소재-B] 될 것으로 보인다 ',
#  '빅베어닷에이아니는 신규 서비스를 미 국방부정보부[기술-B] 등에 공급하고 고객사를 확보한다 ',
#  '브라더스 빅베어닷에이아이 CEO는 빅베어닷에이아이는 수년간 국방부[트렌드-B] 정보부[기술-B] 상업 부문에 AI[기술-B] 솔루션을[소재-B] 제공한[이벤트-B] 몇 안 되는 회사라며 이 AI 분야에 입증된 역량을 바탕으로 UAV 팩토리와[제품-B] 글로벌 고객사들을 지원하겠다고[이벤트-B] 밝혔다 한편 빅비어닷에이아이는 기업인수목적회사[이벤트-B] SPAC스팩 인 기그캐피탈4 GigCapital4 와의 합병을[이벤트-B] 통해[스펙-B] 증시[트렌드-B] 상장을[이벤트-B] 추진하고[이벤트-B] 있다 ',
#  '올해 3분기 내 나스닥에[스펙-B] 상장할[이벤트-B] 계획으로 상장 후 기업 가치는 약 15억7000만 달러 약 1조7700억원 로 추산된다 ',
#  '반도체[제품-B] 테스트 업계가 삼성전자의 CMOS[스펙-B] 이미지센서[제품-B] CIS 수요 증가로 하반기에 생산시설 재투자를[이벤트-B] 단행할[이벤트-B] 계획이다 ',
#  '6일 업계에 따르면 삼성전자는 CIS 공급량을 늘리면서 테스트 업체에[이벤트-B] 2차 시설 투자를[이벤트-B] 제안한 것으로 알려졌다 ',
#  '이미지센서[제품-B] 패키징[스펙-B] 업체[이벤트-B] 폴라리스웍스는[서비스-B] 이미지센서 설계[이벤트-B] 업체 픽셀플러스에[제품-B] 이달부터 차량용[제품-B] 이미지센서 패키지[스펙-B] 네오팩[제품-B] 인캡[소재-B] 제품을[이벤트-B] 공급한다고 6일 밝혔다 ',
#  '픽셀플러스에[제품-B] 공급하는 차량용[제품-B] 이미지센서[제품-B] 패키지는[스펙-B] 56um 마이크로미터[스펙-B] 픽셀 사이즈의[스펙-B] VGA 688x528 급 자동차[제품-B] 후방 카메라용[제품-B] 제품이다[이벤트-B] ',
#  '중국 자동차[제품-B] 기업을 시작으로 내년 초에는 국내외 자동차 브랜드에 공급될 예정이다 ',
#  '최근 차량용[제품-B] 반도체[제품-B] 공급 부족 문제로[사건/사고-B] 제품[이벤트-B] 개발[이벤트-B] 일정과 신뢰성[트렌드-B] 인증기간이[이벤트-B] 빨라지면서 양산[이벤트-B] 시기도 예상보다 빨라지고 있다는 설명이다 ',
#  '폴라리스웍스와[서비스-B] 픽셀플러스[제품-B] 양사는[이벤트-B] 자동차용[제품-B] VGA 센서[제품-B] 양산을[이벤트-B] 시작으로 고화질 HD 초고화질 FHD 급 센서에 대해서도 추가 개발을[이벤트-B] 진행한다 ',
#  '향후 첨단[기술-B] 운전자 보조시스템 ADAS[서비스-B] 등 자율주행차[제품-B] 센서[제품-B] 시장도 진출할[이벤트-B] 예정이다 ',
#  '폴라리스웍스[서비스-B] 관계자는 최근 차량용[제품-B] 반도체[제품-B] 공급난이 이어지며 자동차용[제품-B] 이미지센서[제품-B] 또한 공급 부족 문제가[사건/사고-B] 있었으나 해당 제품은[이벤트-B] 이미 지난해 말에 반도체 위탁생산[이벤트-B] 파운드리 업체로부터[이벤트-B] 웨이퍼[제품-B] 공급에 대한 준비를 완료했다며 올해 수주물량은[이벤트-B] 지난해 예상했던 예상량보다 10배 가까이 늘어날 것으로 기대된다고 말했다 ',
#  '이어 다른 이미지센서[제품-B] 공급사들의 VGA급 제품[이벤트-B] 단종과 공급난을 보이고 있는 가운데 이미 VGA 센서 개발[이벤트-B] 및 양산[이벤트-B] 준비를 마친 폴라리스웍스와[서비스-B] 픽셀플러스가[제품-B] 안정적인 성장을[이벤트-B] 위한 좋은 기회를 맞이하게 됐다고 덧붙였다시장분석업체[이벤트-B] TSR에 따르면 자동차용[제품-B] 이미지센서 시장은 올해 제품 생산수량 기준 3억개 규모다[이벤트-B] ',
#  '이 중 VGA 제품은[이벤트-B] 25% 수준인 7500만개 규모로[이벤트-B] 추산된다 ',
#  'M오토데일리 박상우 기자 현대차그룹의 지난해 매출액이[이벤트-B] 13개 자동차그룹[제품-B] 중 4위에 해당되지만 RD 투자액은[이벤트-B] 10위에 그친 것으로 나타났다 ',
#  '7일 한국자동차산업협회[제품-B] KAMA 는 현대차 폭스바겐 토요타 등 13개 자동차 그룹의 2020년 RD 투자[이벤트-B] 동향을 조사한 2020년 주요 자동차그룹의 RD 투자 동향과 시사점 보고서를[이벤트-B] 발표했다[이벤트-B] ',
#  '보고서에[이벤트-B] 따르면 현대차그룹의 지난해 매출액은[이벤트-B] 전년대비 04% 줄어든 1221억유로 164조1927억원 로 1543억유로를 기록한 다임러AG 207조원 에 이어 4위에 해당된다 ',
#  '영업이익은 33억유로 4조4406억원 로 37억유로 4조9788억원 를 기록한 FCA[사건/사고-B] 현 스텔란티스 에 이어 8위다 ',
#  'RD 투자액은[이벤트-B] 05% 줄어든 35억유로 4조7111억원 로 38억유로 5조1149억원 를 투자한 FCA에[사건/사고-B] 이어 10위에 해당되는 것으로 나타났다 ',
#  '이를 통해[스펙-B] 현대차그룹의 매출액[이벤트-B] 대비 RD 비중은 29%로 2019년과 비슷한 수준으로 코로나19 펜데믹 속에서도 미래차[제품-B] 개발을[이벤트-B] 위한 투자를[이벤트-B] 지속했다 ',
#  '그러나 138억유로를 투자한[이벤트-B] 폭스바겐그룹 862억유로를 투자한 토요타 861억유로를 투자한 다임러 등 대부분 그룹이 매출액[이벤트-B] 대비 RD 비중이 56% 수준을 나타내는 것을 감안하면 여전히 적은 수준이다 ',
#  '자동차산업의[제품-B] RD 투자[이벤트-B] 및 규모는[이벤트-B] 고부가가치 제품력[이벤트-B] 전동화자율주행[제품-B] 등 첨단기술력의[기술-B] 성과로[이벤트-B] 나타난다 ',
#  '아우디 벤틀리 포르쉐 등 총 3개의 프리미엄 브랜드를 보유하고 있는 폭스바겐그룹의 경우 그룹 전체 대당 매출액은[이벤트-B] 약 4만유로인 반면 3개 고급브랜드의 대당 매출액은 6만유로에 달한다 ',
#  '또 폭스바겐그룹 총 판매대수[이벤트-B] 중 프리미엄 브랜드의 비중은 233%에 불과하나 매출액에서[이벤트-B] 프리미엄브랜드가 차지하는 비중은 429%로 약 18배의 부가가치를 창출한다 ',
#  '고급차 중심의 사업을 영위하는 다임러와 BMW도[사건/사고-B] 판매대수[이벤트-B] 대비 월등히 높은 매출영업이익[이벤트-B] 실적을[스펙-B] 보인다 ',
#  '지난해 다임러의 대당 매출액은[이벤트-B] 5만4천유로 BMW는[사건/사고-B] 4만3천유로로 집계됐다 ',
#  '이 때문에 폭스바겐 다임러 BMW는[사건/사고-B] 투자비용의[이벤트-B] 회수가 빨라 매출액[이벤트-B] 대비 연구개발비[이벤트-B] 비중이 높다 ',
#  '반면 현대차그룹의 대당 매출액은[이벤트-B] 1만9천유로 연결회계중국판매대수 제외[이벤트-B] 기준 로 낮은 편이다 시장확대와[이벤트-B] 기술력을[기술-B] 통한[스펙-B] 브랜드 가치 제고 등을 통해 제네시스 브랜드를 성공적으로[이벤트-B] 안착시켜야 한다 ',
#  '또 현대차그룹은 비교적 빠른 전기차[제품-B] 개발로[이벤트-B] 2017년에 순수전기차 4종으로 상위권에 위치했으나 3년이 지난 2020년에는 10종으로 확대했음에도 GM 9종 VW 16종 다임러 8종 등에 추격을 당하고 있다 ',
#  '특히 현대차의 1톤 전기트럭인[트렌드-B] 포터2 일렉트릭 등 상용[이벤트-B] 전기차를[제품-B] 제외하면[이벤트-B] 승용 전기차 모델수는 6종에 불과해 격차는[이벤트-B] 더욱 좁혀진다시장점유율에서도[이벤트-B] 현대차그룹이 2019년 50%에서 지난해 63%로 13%p 확대하는 동안 폭스바겐은 59%p GM은 50%p 늘렸다 ',
#  '즉 현대차그룹이 산업주도권을 잡기 위해 전기차[제품-B] 전환을 선제적으로 추진했으나[이벤트-B] 폭스바겐 다임러 BMW[사건/사고-B] 등이 RD 기술력자금력브랜드파워를[기술-B] 바탕으로 3년 만에 전기차 시장 주도권을 확보한 것이다 ',
#  '이러한 모습은 자율주행차[제품-B] 개발[이벤트-B] 역량에서도 나타난다 ',
#  '자동차업계의[제품-B] 자율주행[제품-B] 역량은 선제적으로 움직인 미국계와 기술력[기술-B] 프리미엄 브랜드 역량 정부 지원[이벤트-B] 등에 힘입어 뒤따르는 독일계와 일본계가 선도 그룹이며 한국계는 핵심기술력 열위로 격차[이벤트-B] 추격 중이다 ',
#  '미국의 GM 포드 테슬라는 핵심기술[기술-B] 개발[이벤트-B] 및 확보에 선제적으로 착수하여[이벤트-B] 축적된 주행데이터와[기술-B] 기술력을 바탕으로 자율주행[제품-B] 기능의 우수성을[소재-B] 인정받았고 특허[이벤트-B] 등 기술개발 질적 수준도 상위권이다 ',
#  '독일의 경우 아우디가 지난 2018년 세계 최초로[이벤트-B] 대형[스펙-B] 플래그십 세단인 A8에 레벨3 수준의 자율주행기술을[기술-B] 적용했으며[이벤트-B] BMW의[사건/사고-B] 차세대 전기차[제품-B] I넥스트와 벤츠의 플래그십 세단 S클래스에 레벨3 수준의 자율주행기술이 적용된다 ',
#  '한국은 현재 레벨2 수준의 자율주행기술이[기술-B] 적용된[이벤트-B] 모델을 확대하고 있으나 레벨3 자율주행기술 양산화는[스펙-B] 내년 말에 이뤄질 예정이다 ',
#  'KAMA는 고비용의[이벤트-B] 신기술[기술-B] 선적용이[이벤트-B] 가능한 프리미엄 브랜드를 확장[이벤트-B] 대중브랜드와 이원화해 고부가가치 전환을 통해[스펙-B] 증가하는 영업이익으로 RD 투자를[이벤트-B] 확대하는 선순환구조의[트렌드-B] 확립이 필요한다고 밝혔다 ',
#  '또 이를 위한 적정수준의 임금상승률[이벤트-B] 유지와 생산성 향상[이벤트-B] 등을 위한 노사협력과[이벤트-B] 정부차원의 임금 노동 고용[트렌드-B] 등과 관련한 규제완화[트렌드-B] 등 경영여건[이벤트-B] 개선을[이벤트-B] 위한 노력이 필요한다고 덧붙였다 ',
#  '더구루윤진웅 기자 현대자동차[제품-B] 전기차[제품-B] 아이오닉 5이 영국에서 올해의 자동차에 올랐다 ',
#  '현대차 투싼과 고성능[스펙-B] 해치백 i20 N도 수상 모두 6관왕을 차지했다 ',
#  '7일 업계에 따르면 영국 자동차[제품-B] 전문 매체 오토익스프레스[스펙-B] Auto Express 는 최근 뉴 카 어워즈 2021 New Car Awards 2021 을 열고 분야별 최고 자동차 모델을 선정했다 ',
#  '오토익스프레스는[스펙-B] 매년 영국에서 출시되는[이벤트-B] 신차들을[제품-B] 대상으로 올해의 차를 발표한다[이벤트-B] ',
#  '글로벌 자동차[제품-B] 시장 추세에 맞춰 심사기준을 30개로 나눠 올해의 차를 선정한다 ',
#  '더구루오소영 기자 애플이 개발[이벤트-B] 중인 애플카가 미니 전기버스[트렌드-B] 형태로[스펙-B] 출시될[이벤트-B] 수 있다는 전망이[이벤트-B] 나왔다 ',
#  'BMW[사건/사고-B] 전 수석 부사장이자 전기차[제품-B] 스타트업 카누의 공동 설립자인[이벤트-B] 울리히 크란츠가 애플에 새 둥지를 틀어서다 ',
#  '미니 전기버스를[트렌드-B] 개발하려는[이벤트-B] 크란츠 전 부사장의 야심이 애플카로 구현될[이벤트-B] 수 있다는 분석이다[스펙-B] ',
#  '7일 업계에 따르면 애플카는 미니 전기버스[트렌드-B] 모델로 나올 전망이다[이벤트-B] ',
#  '2025년 출시가[이벤트-B] 예상되는 폭스바겐의 ID버즈와 유사할 것으로 예상된다 ',
#  '애플은 애플카 개발을[이벤트-B] 공식화한[이벤트-B] 후 어떤 형태일지에[스펙-B] 대한 정보를[기술-B] 제공하지[이벤트-B] 않았다 ',
#  '더구루정예린 기자 화웨이가 반도체[제품-B] 검사장비 업체를[이벤트-B] 공급망으로 확보했다 ',
#  '미중 무역분쟁[사건/사고-B] 여파로 자체 칩 생산에 난항을[사건/사고-B] 겪고 있는 가운데 반도체[제품-B] 자립에 속도를 낸다 ',
#  '7일 업계에 따르면 화웨이의 팹리스[서비스-B] 자회사 하이실리콘은[스펙-B] 최근 중국 심천JT자동화장비[기술-B] Shenzhen JT Automation Equipment 와 향후 5년 간 법적[트렌드-B] 구속력이 있는 양해각서[이벤트-B] MOU 를 체결했다[이벤트-B] ',
#  '양사는[이벤트-B] 반도체[제품-B] 설계[이벤트-B] 자동화[기술-B] EDA 설계 툴을 비롯해 전반적인 반도체 패키징[스펙-B] 및 테스트 분야에서 협력한다[이벤트-B] ',
#  '심천JT자동화장비는[기술-B] 지난 6일 현지시간 심천증권거래소에[트렌드-B] 제출한 문서에서 하이실리콘은[스펙-B] 국내 칩 패키징[스펙-B] 및 테스트 공급망 구축을[이벤트-B] 위한 노력을 강화하고 있다며 양사는[이벤트-B] 반도체[제품-B] 업계의 병목현상을 해결하고[소재-B] 자급자족을 실현하기[스펙-B] 위해 반도체 패키징 툴 개발에[이벤트-B] 대한 협력을[이벤트-B] 확대할 것이라고 밝혔다 ',
#  '심천JT자동화장비는[기술-B] 지난 2004년 설립된[이벤트-B] 반도체[제품-B] 검사계측장비 기업이다 ',
#  '표면실장기술[기술-B] SMT[스펙-B] 인쇄검사기 SPI 장비 시장 주요 플레이어 중 한 곳이다 ',
#  '반도체[제품-B] 장비 외에도 가전[제품-B] 우주 및 항공 방위 기술[기술-B] 생산에 필요한 다양한 장비를 제조한다 ',
#  '제목을 클릭하시면 해당 기사를 보실[스펙-B] 수 있습니다 ',
#  'BMW[사건/사고-B] BMW 전기차[제품-B] iX 양산[이벤트-B] 시작주행거리[스펙-B] 630km JT친애저축은행 JT친애저축은행 편입 효과 日넥서스뱅크 실적[스펙-B] 급증 LG디스플레이[제품-B] LG디스플레이[제품-B] 中 청소년 눈 건강[트렌드-B] 책임진다OLED[제품-B] TV[제품-B] 기부 SPC삼립[제품-B] 30초 마다 빵 정보[기술-B] 제공파리바게뜨[이벤트-B] 데이터[기술-B] 마케팅[이벤트-B] 中 고객몰이 TSMC[스펙-B] TSMC[스펙-B] 美 공장 착공 초읽기양산 목표 순항 기아 기아 알제리軍 경장갑차 최저가 입찰수주[이벤트-B] 초읽기 넥슨 넥슨 日서 미스터리 ',
#  '리비안 R1T 내장[스펙-B] 주방시설 공개[이벤트-B] 비트코인이더리움[스펙-B] 이더리움 비트코인 대비 40% 상승 전망희소성[이벤트-B] 부각 빅베어닷에이아이 스팩주[제품-B] 빅베어닷에이아이 美 무인항공기[트렌드-B] 업체[이벤트-B] 맞손 삼성전자 日 안리쓰 삼성 엑시노스 모뎀[제품-B] 활용 5G 장비 테스트 소니 소니 재팬스튜디오[이벤트-B] 폐쇄공식[사건/사고-B] 홈페이지서 제거 ',
#  '셀루러리티[제품-B] 스팩주[제품-B] 셀루러리티 의료장비 업체[이벤트-B] 아스렉스와 협업 아마존 아마존 인도 이온에너지[트렌드-B] 투자배터리[제품-B] 솔루션[소재-B] 강점 오리온 오리온 베트남서 초코파이 팥마차 출시현지화[이벤트-B] 전략[이벤트-B] 강화 에어로팜 농업계[트렌드-B] 애플 에어로팜 UAE 연구센터[이벤트-B] 짓는다 ',
#  '조마토 미래에셋네이버 투자[이벤트-B] 동맹[이벤트-B] 잭팟인도 조마토 IPO[이벤트-B] 승인[이벤트-B] 카누 美 전기차[제품-B] 스타트업 카누 스포츠 세단 시제품[이벤트-B] 노출 포스코 포스코 멕시코공장 환경오염[트렌드-B] 논란인근[사건/사고-B] 농민 항의 포스코 포스코 아르헨티나 제2리튬공장[소재-B] 공청회[이벤트-B] 개최환경영향평가[이벤트-B] 발표[이벤트-B] 한화테크윈 한화테크윈 인도네시아 영업망 확대 현대로템 미쓰비시 품질조작 스캔들[사건/사고-B] 현대로템 호주사업 영향 촉각 현대자동차 현대차 이탈리아[스펙-B] 프로축구[트렌드-B] AS로마[서비스-B] 스폰서십[제품-B] 연장무리뉴 효과 기대 현대자동차 반도체[제품-B] ',
#  '더 안전한 자율주행을[제품-B] 위해 다양한 센싱 기술을[기술-B] 접목할[이벤트-B] 필요가 있다 만도는 타이어를[제품-B] 통해[스펙-B] 도로[서비스-B] 노면을 분석하고[스펙-B] 타이어 자체의 마모도를 파악할 수 있는 STMS[스펙-B] 기술을 개발[이벤트-B] 중이다 ',
#  '이는 모든 탈것에 접목할[이벤트-B] 수 있고 차량[제품-B] 정비부터 보험[트렌드-B] 스마트시티[트렌드-B] 관리 등의 서비스에도 활용할 수 있다 ',
#  '김완일 만도헬라일렉트로닉스 전무는 7일 온라인으로[기술-B] 열린 MEMS SENSOR FORUM에서 자율주행[제품-B] 고도화를[스펙-B] 위해 만도헬라가 준비 중인 STMS[스펙-B] Smart Tire Monitoring Sensor 기술을[기술-B] 소개했다 ',
#  'STMS는[스펙-B] 자동차가[제품-B] 타이어의[제품-B] 공기압은[트렌드-B] 물론 타이어 마모도와 도로의[서비스-B] 노면 상태까지 확인해 운전자에게 알려주는 기술을[기술-B] 말한다 ',
#  '이는 타이어[제품-B] 내부에 장착된[이벤트-B] 각종 센서로부터[제품-B] 수집한 데이터를[기술-B] 클라우드[기술-B] 서버로 전송분석하는[스펙-B] 개념으로 기존 TPMS Tire Pressure Monitoring System 보다 주행 안전성을[스펙-B] 높이는[스펙-B] 데 기여할 수 있다 ',
# ...
#  '현대미포조선 현대미포조선 520억원 중형[스펙-B] LPG선[소재-B] 수주[이벤트-B] 현대자동차[제품-B] 현대차 내년 3월 인니공장서 전기차[제품-B] 생산판매한다[이벤트-B] ',
#  '더구루홍성환 기자 중국에서 데이터[기술-B] 수집 운송 농림식물보호 순찰감시[사건/사고-B] 기상모니터[제품-B] 등의 분야에서 쓰이는 공업용 드론[제품-B] 시장이 빠르게 성장하고[이벤트-B] 있다 ',
#  '17일 코트라 중국 시안무역관이[트렌드-B] 작성한 중국 전문 공업용 드론[제품-B] 빠르게 성장[이벤트-B] 중 보고서에[이벤트-B] 따르면 중국 민용 드론의 시장 규모는[이벤트-B] 2015년 68억5000만 위안 약 1조2100억원 에서 지난해 257억1000만 위안 약 4조5300억원 으로 4배 성장한 것으로 나타났다 ',
#  '특히 공업용 드론은[제품-B] 138억1000만 위안 2조4400억원 으로 전체 드론 시장의 절반을 차지했다 ',
#  '중국 내 항공우주[트렌드-B] 선두 산업 지역인 섬서성은 공업용 드론[제품-B] 분야에서 강세를 보이고 있다 ',
#  '섬서성 내 공업용 드론[제품-B] 작업인원 교육기관은[트렌드-B] 2019년 기준으로 17곳이 설립됐고[이벤트-B] 각종 공업용 드론 전문가 양성을 위해 적극적인 교육과 훈련을 진행하고 있다 ',
#  '코트라는 중국의 드론[제품-B] 산업은 그 활용 범위가 계속 확대되는 동시에 각종 신형[스펙-B] 센서[제품-B] 물류망 빅데이터[기술-B] 메타[기술-B] 컴퓨팅의[기술-B] 발전을[이벤트-B] 기반으로 생산비용[이벤트-B] 대비 고기술[기술-B] 산업 분야를 향해 발전하고 있다며 이 가운데 민용 분야에서는 공업용 드론 시장 규모의[이벤트-B] 성장[이벤트-B] 속도가 급등해 세계 선두를 달리고 있다고 전했다 ',
#  'M오토데일리 박상우 기자 전기차[제품-B] 기반의 서비스 발굴[이벤트-B] 및 맞춤형[스펙-B] 차량[제품-B] 제작[이벤트-B] 등을 통해[스펙-B] 미래 물류 시장에 선제적으로 대응하는[사건/사고-B] 한편 스마트 모빌리티 솔루션[소재-B] 기업으로의 전환에 속도를 내는 현대차그룹이 1톤 포터EV를[제품-B] 활용한 도심형 딜리버리 서비스를 선보인다 ',
#  '현대차그룹은 현대백화점 콜드체인 저온유통체계[스펙-B] 물류대행사[이벤트-B] 팀프레시와 함께 전기트럭[트렌드-B] 기반의 차별화된 배송[서비스-B] 서비스를 이달 말부터 10월까지 약 3개월 간 시범[이벤트-B] 운영한다고[이벤트-B] 18일 밝혔다 ',
#  '친환경[트렌드-B] 포터EV[제품-B] 4대를 투입해 주문한 지 최소 10분에서 최대[이벤트-B] 30분 안에 과일 야채 정육 등 친환경 신선식품 배송을[서비스-B] 완료하고 혹 고객이 원하는 시간을 설정할 경우 맞춤형[스펙-B] 예약 배송 서비스도 제공하겠다는[이벤트-B] 계획이다 ',
#  '배송기사[서비스-B] 역시 소음과 진동이[스펙-B] 적고 탄소배출[이벤트-B] 저감 효과가 있는 포터EV[제품-B] 주행으로 업무 피로도를 개선할[이벤트-B] 수 있다 ',
#  '이를 위해 현대차그룹은 차량과[제품-B] 단말 및 플랫폼을[서비스-B] 통한[스펙-B] 물류 솔루션을[소재-B] 제공한다[이벤트-B] ',
#  '현대백화점은 화주사로서 현대식품관 투홈 애플리케이션을 이용한 주문 결재 고객서비스 등을 담당하고 팀프레시는 차량[제품-B] 및 배송기사를[서비스-B] 관리하며 고객에게 상품을[이벤트-B] 전달한다 ',
#  '시범[이벤트-B] 서비스는 현대백화점 압구정 본점 반경 3km 지역에서 이뤄지며 저상차 2대 고상차 1대 투명 윈도우 고상차 1대 등 총 4대 차량이[제품-B] 투입된다 ',
#  '현대차그룹은 양산형[스펙-B] 포터EV를[제품-B] 콜드체인을 갖춘 이동형 마이크로 풀필먼트 센터 소형 물류총괄대행 시설 차량으로[제품-B] 개조해 제공하고[이벤트-B] 향후 물류 차량으로써의 상품성도[이벤트-B] 테스트할 계획이다 ',
#  '저상차는 작업효율과 공간활용을 극대화하고 냉기손실을[스펙-B] 최소화하기 위해 공간을 세 부분 냉장 2칸 냉동 1칸 으로 분할했다 ',
#  '차량[제품-B] 밖에서 상하차 작업이 가능하고 빈 공간 없이 최대한[이벤트-B] 많은 양의 물건을 적재할[스펙-B] 수 있다 ',
#  '또 한 쪽 도어를 열어도 다른 쪽 공간의 냉기 손실은[스펙-B] 거의 발생하지[이벤트-B] 않는다 ',
#  '고상차의 경우 냉장칸과 냉동칸 사이에 슬라이딩 도어를 설치해 동선이 자유롭도록 설계했고[이벤트-B] 투명 윈도우 고상차는 안이 훤히 들여다보이는 창이 있어 신선식품을 자연스럽게 노출하는[이벤트-B] 한편 디스플레이를[제품-B] 장착해[이벤트-B] 광고[이벤트-B] 영상도 내보낼 수 있다 ',
#  '또 현대차그룹은 단말 서비스플랫폼[서비스-B] 충전인프라[서비스-B] 등 통합[스펙-B] 물류 솔루션도[소재-B] 제공[이벤트-B] 및 검증할 계획이다 ',
#  '상용[이벤트-B] FMS PoC 차량[제품-B] 관제 시스템 개념검증[이벤트-B] 단말을 통해[스펙-B] 수집한 EV데이터[기술-B] 충전[스펙-B] 상태 충전 잔여시간 주행가능거리 및 실시간[스펙-B] 온도[스펙-B] 등을 통해 차량을 편리하게 관리할 수 있게 되는 만큼 고객에게 보다 신속하고 정확한 배송[서비스-B] 서비스를 제공할[이벤트-B] 수 있을 것으로 기대된다 ',
#  '이뿐만 아니라 협력사[이벤트-B] 로지스텍을 지원해[이벤트-B] 차량[제품-B] 내 적재된[스펙-B] 물품의 재고를 확인하고 차량 관제 배차를 관리할 수 있는 물류서비스 운영시스템을[이벤트-B] 개발[이벤트-B] 및 운영하며 현대백화점 주변의 급속[서비스-B] 충전[스펙-B] 시설을 충전 인프라로[서비스-B] 우선 활용할 예정이다 ',
#  '현대차그룹은 이번 도심형[스펙-B] 딜리버리 시범[이벤트-B] 서비스 결과를 토대로 배송[서비스-B] 품목과 배송 지역 협력[이벤트-B] 대상 등 사업 영역을 지속 확대하고 향후 자율주행[제품-B] 배송으로 이어질 미래 물류 사업을 주도해 나가기 위한 준비에 박차를 가할 예정이다 ',
#  'M오토데일리 박상우 기자 현대모비스가 18일 2021 지속가능성보고서를[이벤트-B] 발간했다 ',
#  '현대모비스는 지난 2010년부터 경제 사회 환경 등 다양한 분야의 지속가능경영[이벤트-B] 성과를[이벤트-B] 주요 이해관계자들에게 공유하기[서비스-B] 위한 목적으로 매년 지속가능성보고서를[이벤트-B] 발간하고 있다 ',
#  '올해는 중장기 친환경[트렌드-B] 경영전략과[이벤트-B] ESG[이벤트-B] 경영에 대한 추진[이벤트-B] 내용을 상세히 담았다 ',
#  '특히 TCFD 기후변화[트렌드-B] 재무정보공개[이벤트-B] 태스크포스 권고지표 WEF 세계경제포럼[이벤트-B] 국제비즈니스위원회[스펙-B] ESG[이벤트-B] Metrics UN SDGs 지속가능개발목표[이벤트-B] Commitment 등 다양한 글로벌 ESG 정보 가이드라인에서 요구하는 수준을 충실히[스펙-B] 반영했다[이벤트-B] ',
#  '현대모비스는 구동시스템 제어기[제품-B] 배터리시스템[제품-B] 수소연료전지와[제품-B] 같은 전동화 핵심부품 포트폴리오를[소재-B] 갖추고 있으며 인휠모터[제품-B] 구동모듈 수소연료전지셀[제품-B] 배터리시스템의 소프트웨어[제품-B] 등 미래 전동화 핵심기술[기술-B] 개발에도[이벤트-B] 힘을 기울이고 있다 ',
#  '이 과정에서 현대모비스는 관련 분야 특허를[이벤트-B] 다수 확보했다 ',
#  '지난해 현대모비스가 획득한[이벤트-B] 전체 글로벌 지식재산권 2100여 건 가운데 절반에 육박하는 규모다[이벤트-B] ',
#  '친환경[트렌드-B] 모빌리티 관련 특허와[이벤트-B] 친환경 경영분야[이벤트-B] 국제 인증이[이벤트-B] 이에 해당한다 ',
#  '이러한 경쟁력을[이벤트-B] 바탕으로 현대모비스는 앞으로 클린[트렌드-B] 모빌리티 Clean Mobility 실현을[스펙-B] 위한 친환경차[트렌드-B] 시스템을 고도화해[스펙-B] 나간다는 방침이다[이벤트-B] ',
#  '이와 함께 현대모비스는 국내 자동차부품[제품-B] 기업 최초로[이벤트-B] RE100 Renewable energy 100 가입을 추진한다고[이벤트-B] 밝혔다 ',
#  'RE100은 기업에서 사용하는 전력의[트렌드-B] 100%를 재생에너지로[트렌드-B] 전환하고자 하는 글로벌 이니셔티브이다 ',
#  '현대모비스는 국내외 생산공장 및 연구소[이벤트-B] 품질센터 자회사 등을 포함한 전 사업장에 대한 에너지[트렌드-B] 사용 현황 파악을 진행하고 각 국가별 규제[트렌드-B] 및 사회환경 검토를 통해[스펙-B] RE100 이행을 위한 로드맵을[이벤트-B] 구축했다[이벤트-B] ',
#  '이를 통해[스펙-B] 현대모비스는 RE100 기준보다 10년 빠른 2040년까지 국내외 전 사업장에서 재생에너지[트렌드-B] 100% 사용을 달성한다는[이벤트-B] 계획이다 ',
#  '현재 현대모비스는 국내외 사업장에 대한 환경에너지경영[이벤트-B] 시스템 인증[이벤트-B] ISO14001 을 취득했고 탄소정보[기술-B] 공개[이벤트-B] 프로젝트[이벤트-B] CDP 등 글로벌 이니셔티브에도 적극 참여하고 있다 ',
#  '현대모비스는 친환경[트렌드-B] 경영과[이벤트-B] 함께 안전경영도[이벤트-B] 강조하고 있다 ',
#  '이러한 일환으로90%가 넘는 국내외 사업장에서 ISO45001 안전보건경영시스템[이벤트-B] 국제인증[이벤트-B] 를 취득해 체계적인 시스템과 관리 역량을 갖추고 있다 ',
#  '현대모비스는 협력사들의[이벤트-B] 경쟁력[이벤트-B] 제고와 리스크[서비스-B] 관리를 위해서도 다양한 정책을 시행하고 있다 ',
#  '협력사와[이벤트-B] 계약[이벤트-B] 체결[이벤트-B] 시 유해물질[스펙-B] 미사용 환경법규[트렌드-B] 준수 안전경영[이벤트-B] 및 제품생산[이벤트-B] 전 과정에서의 친환경[트렌드-B] 시스템 전환을 독려하고 있다 ',
#  '특히 협력사도[이벤트-B] ESG[이벤트-B] 경영[이벤트-B] 역량을 강화할 수 있도록 협력사와 공동으로 리스크[서비스-B] 점검을[이벤트-B] 진행하고 있다 ',
#  '더구루윤진웅 기자 독일 프랑크푸르트모터쇼가[제품-B] 이름을 바꿔 돌아온다 ',
#  '더구루윤진웅 기자 제네럴모터스[제품-B] GM 가 미국 캘리포니아에 미래 모빌리티 디자인센터를[이벤트-B] 설립한다[이벤트-B] ',
#  '이를 토대로 플라잉카[제품-B] 등 미래 모빌리티 기술에[기술-B] 필요한 역량을 확보한다는 계획이다 ',
#  '18일 업계에 따르면 GM은 총 7100만 달러 한화 약 810억원 를 투자[이벤트-B] 미국 캘리포니아 패서디나 Pasadena 에 미래 모빌리티 디자인센터를[이벤트-B] 설립하기로[이벤트-B] 했다 ',
#  'GM은 이곳에서 하늘을 나는 플라잉카와[제품-B] 달 표면 탐사차량[제품-B] 루나 로버 차 lunar rover vehicles 등에 필요한 첨단[기술-B] 기술을[기술-B] 개발할[이벤트-B] 예정이다 ',
#  '혁신[기술-B] 연구소[이벤트-B] innovation lab 와 증강가상현실이[스펙-B] 포함된 몰입형[스펙-B] 기술[기술-B] 개발에[이벤트-B] 역량을 집중 미래차[제품-B] 프로젝트[이벤트-B] 개발을 전문으로 하는 차세대 디자인[이벤트-B] 센터로 만든다는 계획이다 ',
#  '특히 GM은 디자인센터가[이벤트-B] 들어서는 패서디나의 지리적인 이점을 적극 활용 인적 자원을[트렌드-B] 확보한다는 방침이다[이벤트-B] ',
#  '로스앤젤레스시[스펙-B] 북동쪽 15km에 위치한 패서디나는 공학환경IT[기술-B] 관련 산업이 발달한 지역으로 미국항공우주국[트렌드-B] NASA[서비스-B] 과 협력하는[이벤트-B] 캘리포니아공과대학과 디자인아트센터칼리지[이벤트-B] 등이 인접하다 ',
#  '일류 대학과 디자인[이벤트-B] 스쿨에 재학 중인 학생을 채용하기[이벤트-B] 유리할[제품-B] 것이라고 GM은 판단했다 ',
#  'GM은 올해를 기점으로 미래 모빌리티 기술[기술-B] 개발에[이벤트-B] 박차를 가하고 있다 ',
#  '지난 1월에는 미래형[스펙-B] 플라잉 캐딜락 flying Cadillac 을 선보였다 ',
#  '이 자동차는[제품-B] 수직 이착륙이 가능한 자율주행[제품-B] 자동차로 업계의 주목을 받았다 ',
#  '아울러 화물 적재[스펙-B] 기능을 강화한 상용차[제품-B] 브라이트드랍[제품-B] BrightDrop 과 군용기 제조자 록히드 마틴과 함께 개발한[이벤트-B] 달 탐사차량[제품-B] 등도 개발 중이다 ',
#  '제목을 클릭하시면 해당 기사를 보실[스펙-B] 수 있습니다 ',
#  '12일 월 CATL[사건/사고-B] 中 인산철 배터리[제품-B] 탑재량 연내 삼원계 넘는다 ',
#  'CJ제일제당 CJ제일제당 과일발효초 미초 日 씨푸드 레스토랑 입점 EA EA 피파22 출시[이벤트-B] 정보[기술-B] 유출9월 출시 가능성 EVE에너지파라시스[트렌드-B] 中 상반기 배터리[제품-B] 투자[이벤트-B] 60조 돌파 LG에너지솔루션삼성SDISK이노베이션[소재-B] K-배터리 3총사 美 시장 점령톱5 선정 LG전자 LG전자 이탈리아[스펙-B] 식기세척기 시장 진출[이벤트-B] LG전자 LG전자 두바이에 공조솔루션 쇼룸 오픈중동시장[이벤트-B] 공략 속도 SD바이오센서[제품-B] 사이공하노이상업은행 ',
#  '미래에셋캐피탈 미래에셋캐피탈 베트남 최대[이벤트-B] IT유통업체와[이벤트-B] 100% 온라인[기술-B] 할부금융[트렌드-B] 출시[이벤트-B] 볼보지리자동차[제품-B] 볼보-지리 파워트레인[제품-B] 합작사[이벤트-B] 오로베이 설립[이벤트-B] 삼성물산 삼성물산 대만 타오위안 국제공항[이벤트-B] 확장[이벤트-B] 공사 가속도 예고[이벤트-B] 삼성전자 삼성 TV[제품-B] 플러스 웹버전 출시애플 사용자도 무료 콘텐츠 시청 삼성중공업 삼성중공업 나이지리아 사업장 수리조선소 변신 성공[이벤트-B] 아이셰어즈 인플레이션 우려에[사건/사고-B] 美물가연동국채 펀드 뭉칫돈 몰린다 ',
#  '올라 IPO[이벤트-B] 앞둔 올라 5억 달러 투자[이벤트-B] 유치 테슬라 테슬라 리튬[소재-B] 비용[이벤트-B] 30% 이상 절감추출 기술[기술-B] 개발[이벤트-B] 성공[이벤트-B] 테슬라 테슬라 상하이 공장 투자 이상무증설[이벤트-B] 철수설[사건/사고-B] 부인 포니닷AI 中 포니닷AI 상하이서 로보택시[제품-B] 운영[이벤트-B] 개시자율주행[제품-B] 트럭 상업운행 폭스콘 폭스콘 美 전기차[제품-B] 공장 위스콘신주 유력피스커 반값 전기차 현실화[스펙-B] 한국수력원자력두산중공업[트렌드-B] 팀코리아 체코 원전[트렌드-B] 백년을 약속한다두산중공업[이벤트-B] 조력자로 나서 ',
#  '하나은행 하나은행 인니 최대[이벤트-B] 타이어[제품-B] 제조업체[이벤트-B] 가자퉁갈 유동성 지원[이벤트-B] 현대삼호중공업 현대삼호중공업 러시아서 LNG선[소재-B] 2척 수주하반기[이벤트-B] 발주[이벤트-B] 밸리 시동 현대자동차[제품-B] 현대차 인도 하리아나주에 미래 모빌리티 단지 추진[이벤트-B] 14일 수 GM GM 딜러 지원 온라인[기술-B] 경매 딜러소스 상표권 출원[이벤트-B] HMM HMM 현대중공업 건조 컨테이너선 8척 자금 조달 순항 ITM파워[기술-B] ITM파워 일본서 수소[소재-B] 실험[스펙-B] 시연운영배치[이벤트-B] 합의[이벤트-B] KB증권 KB증권 ',
#  'TSMC[스펙-B] TSMC N5A 공정서 車 반도체만[제품-B] 생산독주 굳히기 들어가나 ',
#  '구글 웨이모 구글 웨이모 가상 도로주행[서비스-B] 시스템 공개자율주행[제품-B] 상용화[이벤트-B] 속도 기아[트렌드-B] 기아 프로젝트[이벤트-B] 3 모빌리티 탄력 예고EU[이벤트-B] 집행위원장 리막 지원[이벤트-B] 약속[이벤트-B] 니오 중국판 테슬라 니오 홍콩 이어 中 상장[이벤트-B] 추진[이벤트-B] 넷마블 넷마블 제2의나라 6월 세계 모바일 게임[트렌드-B] 매출[이벤트-B] 3위 등극 동아에스티 동아에스티 법무실장[스펙-B] 뉴로보 파마슈티컬스 이사회 합류 두산중공업 두산 호주 폐자원에너지화플랜트[제품-B] 시장 진출[이벤트-B] 롯데칠성 롯데칠성 필리핀 자회사 코로나 백신 ',
#  '현대자동차기아[트렌드-B] 현대차기아 인도 질주마루티스즈키 위기론[사건/사고-B] 日서 대두 현대중공업 현대중공업 그리스서[서비스-B] 2120억 LNG선[소재-B] 수주[이벤트-B] 효성첨단소재[소재-B] 효성첨단소재 베트남 임직원 코로나 보너스 지급 15일 목 BMW[사건/사고-B] 올블랙 BMW X5 2022 블랙 버밀리온 출격 LG화학 LG화학 전지소재[제품-B] 1등 기업 올인6조 투자외부[이벤트-B] 협력[이벤트-B] 검토 SD바이오센서[제품-B] 캄보디아 SD바이오센서 코로나 진단키트[제품-B] 사용 권고 TSMC[스펙-B] ',
#  '바이트댄스 틱톡[서비스-B] 모기업 바이트댄스 인터랙티브 커뮤니티앱 피피샤 상표 출원[이벤트-B] 벤슨힐 이마트 투자[이벤트-B] 美 스타트업 벤슨힐 대두 경작지[이벤트-B] 초과 달성건강한[트렌드-B] 먹거리 확보 성큼 삼성물산 삼성물산 대만 공항 공사 인력 수급[이벤트-B] 비상등입국전[사건/사고-B] 백신 접종 의무 삼성전자 삼성 미군 5G 프로젝트[이벤트-B] 본격화테스트베드[사건/사고-B] 구축[이벤트-B] 삼성전자삼성디스플레이[제품-B] 삼성 천안 LCD[제품-B] 공장 반도체[제품-B] 생산기지 전환설 솔솔 상하이자동차[제품-B] 中 상하이차 레벨4 자율주행[제품-B] 로보택시[제품-B] 60대 연내 출격 샤오펑 ',
#  '현대미포조선 현대미포조선 520억원 중형[스펙-B] LPG선[소재-B] 수주[이벤트-B] 현대자동차[제품-B] 현대차 내년 3월 인니공장서 전기차[제품-B] 생산판매한다[이벤트-B] ',
#  '17일 토 CJ ENM 영화 서복 16일 일본 상영공유박보검[서비스-B] 사진 카드 증정 LG전자 LG전자 아프리카 시장 공략 드라이브 JB금융그룹[트렌드-B] JB금융 프놈펜상업은행 모바일 앱 카드관리서비스 도입[이벤트-B] SPC삼립[제품-B] 허영인 SPC 회장 에그슬럿 강남 찍고 싱가포르 진출[이벤트-B] STX조선해양 STX조선 830억원 석유화학운반선[소재-B] 2척 수주[이벤트-B] 넥센타이어[제품-B] 넥센타이어 유럽서 e-러닝 플랫폼[서비스-B] ACE 도입딜러사 지원[이벤트-B] 네오위즈 네오위즈 블레스 언리쉬드 ',
#  'M오토데일리 박상우 기자 KT는 국토교통부가[스펙-B] 주최하는[이벤트-B] 2021 스마트국토엑스포에[이벤트-B] 참여해 KT의 모빌리티 서비스와 사업을 소개한다 ',
#  '올해 13회째를 맞는 스마트국토엑스포[이벤트-B] 행사는[이벤트-B] 또 하나의 대한민국 디지털 트윈국토가 미래를 디자인하다[이벤트-B] Digital Twin Design the Smarter future 라는 주제로 오는 21일부터 23일까지 3일간 메타버스[기술-B] 기반 온라인[기술-B] 플랫폼에서[서비스-B] 개최된다[이벤트-B] ',
#  'KT는 DIGICO[소재-B] KT 스마트 모빌리티 주제로 전시관을[이벤트-B] 운영하며[이벤트-B] 지오마스터 Geomaster 모빌리티 플랫폼[서비스-B] 원내비 내비게이션 AI[기술-B] 인포테인먼트[기술-B] Infotainment 제주도 차세대 교통시스템[서비스-B] C-ITS[서비스-B] 무인 비행체 교통관리[이벤트-B] UTM 까지 다섯 가지 서비스와 사업을 소개한다 ',
#  'KT 전시관에서[이벤트-B] 볼[소재-B] 수 있는 지오마스터는 지도 교통[스펙-B] 장소검색 경로안내[이벤트-B] 기능 확인과 함께 기가지니 AI[기술-B] 음성인식 AI 기반 교통예측 화물 및 전기차량[제품-B] 경로안내 등 특화 기능을 제공하는[이벤트-B] 모빌리티 솔루션이다[소재-B] ',
#  '또 사용자 편의를 향상한[이벤트-B] 원내비의 다양하고 새로운 서비스도 KT 전시관에서[이벤트-B] 확인할 수 있다 ',
#  '원내비는 KT가 제주도에 구축한[이벤트-B] C-ITS와[서비스-B] 연계해 제주도 주요 도로[서비스-B] 약 300km 구간에서 실시간[스펙-B] 신호정보를[기술-B] 제공하고[이벤트-B] 있으며 전국 27개 운전면허시험장의 108개 도로주행시험 코스를 연습할 수 있는 운전면허 특화 서비스 등 다양한 서비스를 제공하고 있다 ',
#  '이와 함께 영상분석[스펙-B] 솔루션과[소재-B] 정밀측위 기술을[기술-B] 활용해[스펙-B] 차량과[제품-B] 차량 차량과 도로[서비스-B] 간 실시간[스펙-B] 양방향 통신을[스펙-B] 구현한[이벤트-B] 제주도 C-ITS[서비스-B] 사업 무인 비행체 교통관리[이벤트-B] UTM 플랫폼과[서비스-B] 차 안에서 즐길 수 있는 AI모빌리티[기술-B] 인포테인먼트도[기술-B] 관람할 수 있다 ',
#  'M오토데일리 박상우 기자 쉐보레의 새로운 전기차[제품-B] 볼트EUV의[소재-B] 출시가[이벤트-B] 초읽기에 들어갔다 ',
#  '19일 환경부 산하 교통환경연구소에[이벤트-B] 따르면 한국지엠은 지난 16일 볼트[소재-B] EUV의 배출가스[트렌드-B] 및 소음인증을[이벤트-B] 완료했다 ',
#  '볼트EUV는[소재-B] 지난 2월 미국에서 처음 ',
#  '공개된[이벤트-B] 쉐보레 볼트EV[제품-B] 부분변경[이벤트-B] 모델을 기반으로 하는 전기SUV로[제품-B] 전장과[제품-B] 휠베이스가 신형[스펙-B] 볼트EV보다 각각 6인치 1524mm 3인치 762mm 더 긴 1695인치 43053mm 와 1053인치 26746mm 다 ',
#  '이 때문에 볼트EUV의[소재-B] 2열 레그룸은 신형[스펙-B] 볼트EV보다[제품-B] 3인치 더 큰 391인치 99314mm 다 ',
#  '반면 전고와 전폭은[스펙-B] 비슷하다 ',
#  '신형[스펙-B] 볼트EV의[제품-B] 전고와 전폭은[스펙-B] 각각 634인치 1610mm 와 695인치 17653mm 볼트EUV의 전고와 전폭은 각각 636인치 16154mm 와 697인치 17704mm 다 ',
#  '실내의[스펙-B] 경우 디지털 계기판과[제품-B] 신형[스펙-B] 102인치 터치스크린이[제품-B] 적용됐다[이벤트-B] ',
#  '이 디스플레이는[제품-B] 새로운 인터페이스뿐만 아니라 무선 애플카플레이 및 안드로이드오토[제품-B] 4G LTE[기술-B] 와이파이 핫스팟 무선 충전을[스펙-B] 사용할 수 있다 ',
#  '또 센터 콘솔에는 선택사양인[스펙-B] 페달[제품-B] 구동 버튼이 있는 새로운 푸시버튼 시프트를 비롯해 더 빠른 유선 충전을[스펙-B] 위한 USB-A와[제품-B] USB-C 포트 12V 액세서리 콘센트 등이 적용됐다[이벤트-B] ',
#  '디스플레이[제품-B] 밑에 있었던 공조장치 버튼은 분리됐으며 물리적 버튼이 적용됐기[이벤트-B] 때문에 운전자가 시선을 옮기지 않아도 공조장치를 제어할 수 있다 ',
#  '오토 비상[사건/사고-B] 제동[사건/사고-B] 전방 충돌[스펙-B] 경고[사건/사고-B] 차선[서비스-B] 이탈[스펙-B] 경고를 포함한 차선 유지 지원[이벤트-B] 및 전방 보행자 감지 기능이 포함된 쉐비 세이프티[스펙-B] 어시스트가 기본적으로 볼트EV와[제품-B] 볼트EUV에 적용된다[이벤트-B] ',
#  '특히 볼트EUV에만[소재-B] GM의 자율주행기능인[제품-B] 슈퍼 크루즈 Super Cruise 운전자 보조기능이 선택사양으로[스펙-B] 탑재된다 ',
#  '이 기능은 20만 마일 이상의 고속도로에서[서비스-B] 손을 대지[트렌드-B] 않고도[스펙-B] 운전할 수가 있다 ',
#  '다만 이 기능은 국내 사정에 따라 한국에서 판매되는[이벤트-B] 볼트EUV에는[소재-B] 적용되지[이벤트-B] 않을 가능성이 있다 ',
#  '배터리는[제품-B] GM과 LG에너지솔루션이[소재-B] 공동개발한[이벤트-B] 얼티움 배터리 대신 이전 모델과 동일하게 LG에너지솔루션이 공급하는 배터리가 탑재되며 용량은[스펙-B] 66kWh이다 ',
#  '그러나 제원상 배터리[제품-B] 용량은[스펙-B] 65kWh로 표시돼있다 ',
#  '배터리[제품-B] 실사용량을[스펙-B] 실제 전체 용량보다 낮게 설정해 화재사고[사건/사고-B] 등을 예방하겠다는 것으로 풀이된다 ',
#  '이 때문에 신형[스펙-B] 볼트EV의[제품-B] 1회 완충 시 주행거리는[스펙-B] 이전과 동일한 259마일 4168km EPA 기준 이며 볼트EUV는 볼트EV보다 무거워 250마일 402km 이다 ',
#  'DC 급속[서비스-B] 충전[스펙-B] 기능이 적용돼[이벤트-B] 볼트EV는[제품-B] 이전과 동일한 30분 안에 100마일 1609km 까지 충전이 가능하며 볼트EUV는 95마일 1529km 이다한국지엠 관계자는 하반기에 투입할 예정이나 아직 정해진 것은 없다고 밝혔다 ',
#  '업계에서는 하반기에 출시한[이벤트-B] 후 출고는 정부의 전기차[제품-B] 구매보조금[트렌드-B] 상황을 고려해 내년 초에 진행할 것으로 전망하고[이벤트-B] 있다 ',
#  '제목을 클릭하시면 해당 기사를 보실[스펙-B] 수 있습니다 ',
#  '더구루윤진웅 기자 현대자동차가[제품-B] 미국 항공우주국[트렌드-B] NASA[서비스-B] 첨단[기술-B] 항공 모빌리티 캠페인에[이벤트-B] 도심항공교통[스펙-B] Urban Air MobilityUAM[제품-B] 관련 핵심 협력사로[이벤트-B] 참여한다 ',
#  '차세대 모빌리티 산업으로 부상하는 UAM[제품-B] 사업에서 우위를 확보하는 한편 정의선[트렌드-B] 현대차그룹 회장이 주도하고 있는 UAM 사업의 그동안의 성과로[이벤트-B] 업계는 분석하고[스펙-B] 있다 ',
#  'NASA는[서비스-B] 18일 현지시간 첨단[기술-B] 항공 모빌리티 시스템 연구를[이벤트-B] 위한 어드밴스 에어 모빌리티 내셔널 캠페인[이벤트-B] Advanced Air Mobility National CampaignAAMNC UAM[제품-B] 관련 협력사로[이벤트-B] 현대차를 선정했다고 밝혔다 ',
#  'UAM은[제품-B] 전기를[트렌드-B] 이용해[스펙-B] 수직이착륙하는 기체 electric Vertical Take Off and LandingeVTOL 를 이용하는 서비스를 말한다 ',
#  'AAMNC는 나사가 안전하고 효과적인 첨단[기술-B] 항공 모빌리티 시스템을 연구하기[이벤트-B] 위해 진행되는 캠페인이다[이벤트-B] ',
#  '팹리스[서비스-B] 업체[이벤트-B] 실리콘아츠가[스펙-B] 19일 인공지능[기술-B] AI[기술-B] 용 범용 그래픽처리장치[제품-B] GPGPU[제품-B] IP인 레이브 RAIV 를 출시했다[이벤트-B] ',
#  'GPGPU는[제품-B] 딥러닝 머신러닝 등 복잡한 AI[기술-B] 소프트웨어를[제품-B] 구현하는[이벤트-B] 데 필요한 부품이다 ',
#  '실리콘아츠의[스펙-B] 레이브는 딥러닝이나 머신러닝 등에서 사용되는 빅데이터를[기술-B] 빠르게 연산처리할 수 있다 ',
#  '다양한 뉴럴 네트워크의[기술-B] 머신러닝 및 추론을 지원한다[이벤트-B] ',
#  'GPU[제품-B] 멀티스레딩으로 애플리케이션을 동시에 처리할 수 있다 ',
#  'AI[기술-B] 자율주행[제품-B] 사물인터넷[서비스-B] IoT[기술-B] 증강현실[스펙-B] 등 고도의[스펙-B] 연산작업이 필요한 개발환경에서도[이벤트-B] 사용 가능하다 ',
#  '레이브는 오픈소스이자[이벤트-B] 확장성이[이벤트-B] 용이한 리스크파이브[서비스-B] RISK-V 를 기반으로 설계됐다[이벤트-B] ',
#  '반도체[제품-B] 회사 또는 개발자들이[이벤트-B] 저비용으로[이벤트-B] 혁신적인[기술-B] 제품을[이벤트-B] 개발할 수 있도록 돕는다 ',
#  '또 AI[기술-B] 가속에 최적화된 SIMT[스펙-B] Single Instruction Multiple Threads 아키텍처로 개발됐다[이벤트-B] ',
#  '실리콘아츠[스펙-B] 관계자는 레이브 출시로[이벤트-B] AI[기술-B] 반도체[제품-B] 시장에도 본격적으로 진출하고[이벤트-B] 3D 그래픽스 시장을 확대하게 됐다며 기존 제품인[이벤트-B] 레이 트레이싱 GPU와[제품-B] 레이브를 결합시켜[스펙-B] 3D 그래픽스와 AI 기능을 모두 처리할 수 있는 칩을 올해 개발할[이벤트-B] 계획이라고 설명했다 ',
#  '지난해 성장이[이벤트-B] 둔화됐던[사건/사고-B] 미세전자기계시스템 MEMS 반도체[제품-B] 시장이 올해 두자릿수 성장을 기록할 것이란 전망이[이벤트-B] 나왔다 ',
#  '스마트폰[제품-B] 웨어러블 분야에서 수요가 급증할 전망이다[이벤트-B] ',
#  'MEMS는 초소형[스펙-B] 기어 미세 크기의[스펙-B] 하드디스크 등의 초미세 시스템이나 기계를 뜻한다 ',
#  'MEMS를 적용한[이벤트-B] 마이크로폰[제품-B] 고감도 센서[제품-B] 등은 스마트폰[제품-B] 가전[제품-B] IT[기술-B] 자동차[제품-B] 등 다양한 분야에 쓰인다 ',
#  '19일 반도체[제품-B] 시장조사[이벤트-B] 업체[이벤트-B] 욜디벨롭먼트에 따르면 지난해 MEMS 시장은 2019년보다 2% 증가한 121억 달러 13조8750억원 를 기록했다 ',
#  '올해 시장규모는[이벤트-B] 지난해보다 11% 성장해[이벤트-B] 134억달러 15조3657억원 에 달할 것으로 전망된다[이벤트-B] ',
#  '이후 매년 한자릿수 이상씩 늘어 2026년에는 182억달러로 규모가[이벤트-B] 커질 것으로 예상된다 ',
#  '전체 MEMS 시장은 소비자[트렌드-B] 부문과 자동차[제품-B] 부문으로 크게 나뉜다 ',
#  '소비자[트렌드-B] 부문이 전체 규모의[이벤트-B] 62%에 달하고 자동차[제품-B] 부문은 약 16%를 차지한다 ',
#  '자동차[제품-B] 부문의 경우 압력센서와[제품-B] 가속도계에 MEMS가 사용된다 ',
#  '욜디벨롭먼트는 지난해의 경우 코로나19 여파로 MEMS 매출[이벤트-B] 감소가 예상됐지만 하반기부터 소비자용[트렌드-B] MEMS 수요가 회복하면서 차량용[제품-B] MEMS 부진을[사건/사고-B] 상쇄했다고 분석했다[스펙-B] ',
#  '올해도 소비자용[트렌드-B] MEMS가 전체 시장 성장세를[이벤트-B] 이끌 것으로 내다봤다 ',
#  '2026년까지 성장폭이[이벤트-B] 가장 클 것으로 전망되는[이벤트-B] 분야는 MEMS 기반의 센서[제품-B] 시프트 광학식손떨림방지[이벤트-B] OIS 다 ',
#  '연평균 214%의 성장이[이벤트-B] 기대된다 ',
#  'OIS는 사진 촬영시 카메라[제품-B] 렌즈가 아닌 카메라 내부센서가[제품-B] 움직이면서 사진이 흔들리는 것을 방지하는[이벤트-B] 기술이다[기술-B] ',
#  '애플이 아이폰12[제품-B] 프로의 카메라[제품-B] 모듈에 처음으로 이 기술을[기술-B] 탑재했다 ',
#  '이 칩은 향후 인쇄회로기판[제품-B] PCB[제품-B] 기반의 센서[제품-B] 시프트를 대체할 것으로 전망되고[이벤트-B] 있다 ',
#  'MEMS 마이크로 스피커도 성장세가[이벤트-B] 기대되는 품목이다 ',
#  '무선이어폰[제품-B] TWS 에서 평형[스펙-B] 전기자[트렌드-B] 스피커를 대체하면서 수요가 늘고 있다 ',
#  '매출[이벤트-B] 규모면에서는[이벤트-B] 웨어러블 무선이어폰[제품-B] 등에서 MEMS 마이크로폰과[제품-B] 관성측정장치 IMU 수요가 늘어날 것으로 전망된다[이벤트-B] ',
#  '인공지능[기술-B] 비서 기능을 위한 음성인식 기술이[기술-B] 중요시되고 있기 때문이다 ',
#  '또 음질 향상을[이벤트-B] 위해 가속도계를 사용한 노이즈 감소 기술에도[기술-B] 쓰일 전망이다[이벤트-B] ',
#  '최근 애플이 스마트폰에[제품-B] 3D 오디오[제품-B] 기술을[기술-B] 넣넣는 방안을 추진하면서[이벤트-B] 향후 안드로이드폰에서도[제품-B] IMU 수요가 급증할 전망이다[이벤트-B] ',
#  '자동차[제품-B] 실내[스펙-B] 공기[트렌드-B] 모니터링을[제품-B] 위한 가스센서용[제품-B] MEMS 수요도 증가하는 추세다 ',
#  '최근 코로나19로 공기에[트렌드-B] 대한 관심이 증가되면서 실내[스펙-B] 및 실외 공기질 모니터링[제품-B] 센서가[제품-B] 스마트워치 등의 웨어러블에도 탑재되고 있어서다 ',
#  ...]

# %%
rslt_word
# Out:
# [['M', 'UNK'],
#  ['오토데일리', 'UNK'],
#  ['최태인', 'UNK'],
#  ['기자', 'UNK'],
#  ['볼보자동차가', '제품-B'],
#  ['지난', 'UNK'],
#  ['30일', 'UNK'],
#  ['스웨덴', 'UNK'],
#  ['고텐버그에서', 'UNK'],
#  ['개최된', '이벤트-B'],
#  ['테크', 'UNK'],
#  ['모멘트', 'UNK'],
#  ['Volvo', 'UNK'],
#  ['Cars', 'UNK'],
#  ['Tech', 'UNK'],
#  ['Moment', 'UNK'],
#  ['이벤트를', '스펙-B'],
#  ['통해', '스펙-B'],
#  ['글로벌', 'UNK'],
#  ['프리미엄', 'UNK'],
#  ['전기차', '제품-B'],
#  ['시장', 'UNK'],
#  ['선두기업으로의', 'UNK'],
#  ['도약을', 'UNK'],
#  ['위한', 'UNK'],
#  ['미래기술', '기술-B'],
#  ['로드맵을', '이벤트-B'],
#  ['발표했다', '이벤트-B'],
#  ['이번', 'UNK'],
#  ['행사는', '이벤트-B'],
#  ['2030년', 'UNK'],
#  ['전기차', '제품-B'],
#  ['회사로의', 'UNK'],
#  ['전면적인', 'UNK'],
#  ['전환을', 'UNK'],
#  ['계획하고', 'UNK'],
#  ['있는', 'UNK'],
#  ['볼보자동차의', '제품-B'],
#  ['미래', 'UNK'],
#  ['기술을', '기술-B'],
#  ['최초로', '이벤트-B'],
#  ['선보이는', 'UNK'],
#  ['자리로', 'UNK'],
#  ['구글', 'UNK'],
#  ['Google', 'UNK'],
#  ['루미나', 'UNK'],
#  ['Luminar', 'UNK'],
#  ['노스볼트', '소재-B'],
#  ['Northvolt', 'UNK'],
#  ['엔비디아', 'UNK'],
#  ['NVIDIA', 'UNK'],
#  ['등', 'UNK'],
#  ['주요', 'UNK'],
#  ['파트너사들', '이벤트-B'],
#  ['대표들이', 'UNK'],
#  ['참가한', '이벤트-B'],
#  ['가운데', 'UNK'],
#  ['함께', 'UNK'],
#  ['진행됐다', 'UNK'],
#  ['이를', 'UNK'],
#  ['통해', '스펙-B'],
#  ['볼보자동차는', '제품-B'],
#  ['완전한', 'UNK'],
#  ['전기차', '제품-B'],
#  ['회사로', 'UNK'],
#  ['전환을', 'UNK'],
#  ['위한', 'UNK'],
#  ['배터리', '제품-B'],
#  ['공급', 'UNK'],
#  ['계획', 'UNK'],
#  ['자체', 'UNK'],
#  ['소프트웨어', '제품-B'],
#  ['개발', '이벤트-B'],
#  ['확대를', 'UNK'],
#  ['위한', 'UNK'],
#  ['계획', 'UNK'],
#  ['컴퓨팅의', '기술-B'],
#  ['중앙', 'UNK'],
#  ['집중화', 'UNK'],
#  ['차세대', 'UNK'],
#  ['안전', 'UNK'],
#  ['기술에', '기술-B'],
#  ['대한', 'UNK'],
#  ['계획', 'UNK'],
#  ['등', 'UNK'],
#  ['핵심', 'UNK'],
#  ['분야에', 'UNK'],
#  ['대한', 'UNK'],
#  ['세부사항을', 'UNK'],
#  ['공개했다', '이벤트-B'],
#  ['볼보자동차', '제품-B'],
#  ['최고경영자', '이벤트-B'],
#  ['하칸', 'UNK'],
#  ['사무엘손', 'UNK'],
#  ['Håkan', 'UNK'],
#  ['Samuelsson', 'UNK'],
#  ['은', 'UNK'],
#  ['볼보자동차는', 'UNK'],
#  ['오는', 'UNK'],
#  ['2030년까지', 'UNK'],
#  ['프리미엄', 'UNK'],
#  ['순수', 'UNK'],
#  ['전기차', '제품-B'],
#  ['기업으로', 'UNK'],
#  ['전환하기', 'UNK'],
#  ['위해', 'UNK'],
#  ['94년', 'UNK'],
#  ['역사상', '트렌드-B'],
#  ['가장', 'UNK'],
#  ['최고의', 'UNK'],
#  ['자동차를', 'UNK'],
#  ['만드는', 'UNK'],
#  ['데', 'UNK'],
#  ['전념하고', 'UNK'],
#  ['있다며', 'UNK'],
#  ['지금은', 'UNK'],
#  ['이러한', 'UNK'],
#  ['발전에', '이벤트-B'],
#  ['있어', 'UNK'],
#  ['흥미로운', 'UNK'],
#  ['시기로', 'UNK'],
#  ['원활한', 'UNK'],
#  ['연결성', 'UNK'],
#  ['업계', 'UNK'],
#  ['최고', 'UNK'],
#  ['수준의', 'UNK'],
#  ['안전표준', 'UNK'],
#  ['그리고', 'UNK'],
#  ['수준', 'UNK'],
#  ['높은', 'UNK'],
#  ['자율주행을', '제품-B'],
#  ['구현하는', '이벤트-B'],
#  ['순수', 'UNK'],
#  ['전기차에', 'UNK'],
#  ['대한', 'UNK'],
#  ['고객', 'UNK'],
#  ['요구를', 'UNK'],
#  ['만족시킬', 'UNK'],
#  ['것이라고', 'UNK'],
#  ['밝혔다고객', 'UNK'],
#  ['차량의', '제품-B'],
#  ['실시간', '스펙-B'],
#  ['데이터를', '기술-B'],
#  ['활용해', '스펙-B'],
#  ['새로운', 'UNK'],
#  ['안전', 'UNK'],
#  ['기준', 'UNK'],
#  ['설정볼보자동차는', 'UNK'],
#  ['그', 'UNK'],
#  ['동안', 'UNK'],
#  ['새로운', 'UNK'],
#  ['안전', 'UNK'],
#  ['기술을', '기술-B'],
#  ['개발하는데', '이벤트-B'],
#  ['있어', 'UNK'],
#  ['실제', 'UNK'],
#  ['도로', '서비스-B'],
#  ['차세대', 'UNK'],
#  ['볼보자동차는', '제품-B'],
#  ['여기서', 'UNK'],
#  ['나아가', 'UNK'],
#  ['고객이', 'UNK'],
#  ['동의한다면', '이벤트-B'],
#  ['더욱', 'UNK'],
#  ['안전한', 'UNK'],
#  ['기술을', '기술-B'],
#  ['개발하기', '이벤트-B'],
#  ['위해', 'UNK'],
#  ['고객의', 'UNK'],
#  ['자동차로부터', 'UNK'],
#  ['실시간', '스펙-B'],
#  ['데이터를', '기술-B'],
#  ['전송받아', '서비스-B'],
#  ['분석하는', '스펙-B'],
#  ['것을', 'UNK'],
#  ['고려하고', 'UNK'],
#  ['있다', 'UNK'],
#  ['M오토데일리', 'UNK'],
#  ['박상우', 'UNK'],
#  ['기자', 'UNK'],
#  ['볼보자동차가', '제품-B'],
#  ['자동차', 'UNK'],
#  ['디자인의', '이벤트-B'],
#  ['새로운', 'UNK'],
#  ['패러다임을', 'UNK'],
#  ['제시할', 'UNK'],
#  ['차세대', 'UNK'],
#  ['순수', 'UNK'],
#  ['전기차의', '제품-B'],
#  ['비전', 'UNK'],
#  ['볼보', 'UNK'],
#  ['컨셉트', 'UNK'],
#  ['리차지', 'UNK'],
#  ['Volvo', 'UNK'],
#  ['Concept', 'UNK'],
#  ['Recharge', 'UNK'],
#  ['를', 'UNK'],
#  ['공개했다', '이벤트-B'],
#  ['최소한의', 'UNK'],
#  ['그러나', 'UNK'],
#  ['더', 'UNK'],
#  ['나은', 'UNK'],
#  ['less', 'UNK'],
#  ['but', 'UNK'],
#  ['better', 'UNK'],
#  ['이라는', 'UNK'],
#  ['스칸디나비아', '스펙-B'],
#  ['디자인', '이벤트-B'],
#  ['유산을', 'UNK'],
#  ['기반으로', 'UNK'],
#  ['탄생한', 'UNK'],
#  ['컨셉트', 'UNK'],
#  ['리차지는', 'UNK'],
#  ['지속가능한', 'UNK'],
#  ['미래를', 'UNK'],
#  ['위한', 'UNK'],
#  ['패밀리', 'UNK'],
#  ['카의', 'UNK'],
#  ['새로운', 'UNK'],
#  ['방향성을', 'UNK'],
#  ['제시하는', 'UNK'],
#  ['모델이다', 'UNK'],
#  ['특히', 'UNK'],
#  ['순수', 'UNK'],
#  ['전기차를', '제품-B'],
#  ['위해', 'UNK'],
#  ['공기역학적', '트렌드-B'],
#  ['효율을', 'UNK'],
#  ['개선하고', '이벤트-B'],
#  ['배터리', '제품-B'],
#  ['팩을', '제품-B'],
#  ['수용하면서도', 'UNK'],
#  ['넓은', 'UNK'],
#  ['실내', '스펙-B'],
#  ['공간을', 'UNK'],
#  ['갖출', 'UNK'],
#  ['수', 'UNK'],
#  ['있도록', 'UNK'],
#  ['설계된', '이벤트-B'],
#  ['새로운', 'UNK'],
#  ['차체', 'UNK'],
#  ['비율을', 'UNK'],
#  ['선보인다', 'UNK'],
#  ['이를', 'UNK'],
#  ['위해', 'UNK'],
#  ['볼보의', '소재-B'],
#  ['디자이너들은', 'UNK'],
#  ['기존', 'UNK'],
#  ['내연기관의', '사건/사고-B'],
#  ['엔진을', '제품-B'],
#  ['제거한', 'UNK'],
#  ['차체', 'UNK'],
#  ['바닥', 'UNK'],
#  ['전체를', 'UNK'],
#  ['배터리', '제품-B'],
#  ['팩으로', '제품-B'],
#  ['배치해', 'UNK'],
#  ['휠', 'UNK'],
#  ['베이스', 'UNK'],
#  ['및', 'UNK'],
#  ['휠', 'UNK'],
#  ['크기를', '스펙-B'],
#  ['확대했다', 'UNK'],
#  ['그', 'UNK'],
#  ['결과', 'UNK'],
#  ['짧아진', 'UNK'],
#  ['오버행', 'UNK'],
#  ['차체', 'UNK'],
#  ['끝에서', 'UNK'],
#  ['바퀴', 'UNK'],
#  ['중심까지', 'UNK'],
#  ['거리', 'UNK'],
#  ['과', 'UNK'],
#  ['함께', 'UNK'],
#  ['운전석과', '제품-B'],
#  ['조수석', 'UNK'],
#  ['사이', 'UNK'],
#  ['넓은', 'UNK'],
#  ['수납공간을', 'UNK'],
#  ['비롯해', 'UNK'],
#  ['더욱', 'UNK'],
#  ['여유로운', 'UNK'],
#  ['실내', '스펙-B'],
#  ['공간을', 'UNK'],
#  ['만들었다', 'UNK'],
#  ['여기에', 'UNK'],
#  ['낮게', 'UNK'],
#  ['설계된', '이벤트-B'],
#  ['후드와', 'UNK'],
#  ['새로운', 'UNK'],
#  ['시트', '제품-B'],
#  ['포지션', 'UNK'],
#  ['최적화된', 'UNK'],
#  ['루프', '제품-B'],
#  ['형태', '스펙-B'],
#  ['등을', 'UNK'],
#  ['통해', '스펙-B'],
#  ['SUV', '제품-B'],
#  ['모델이', 'UNK'],
#  ['지닌', 'UNK'],
#  ['높은', 'UNK'],
#  ['시야를', 'UNK'],
#  ['유지하면서도', 'UNK'],
#  ['주행거리를', '스펙-B'],
#  ['향상시킬', '이벤트-B'],
#  ['수', 'UNK'],
#  ['있도록', 'UNK'],
#  ['공기역학', '트렌드-B'],
#  ['효율성을', 'UNK'],
#  ['개선했다', '이벤트-B'],
#  ['또한', 'UNK'],
#  ['컨셉트', 'UNK'],
#  ['리차지는', 'UNK'],
#  ['불필요한', 'UNK'],
#  ['요소를', 'UNK'],
#  ['모두', 'UNK'],
#  ['제거하고', 'UNK'],
#  ['남은', 'UNK'],
#  ['요소들', 'UNK'],
#  ['역시', 'UNK'],
#  ['보다', 'UNK'],
#  ['정밀하고', 'UNK'],
#  ['선명해진', 'UNK'],
#  ['형태의', '스펙-B'],
#  ['새로워진', 'UNK'],
#  ['볼보의', '소재-B'],
#  ['디자인', '이벤트-B'],
#  ['언어가', 'UNK'],
#  ['도입됐다', '이벤트-B'],
#  ['먼저', 'UNK'],
#  ['전면', 'UNK'],
#  ['그릴은', 'UNK'],
#  ['시그니처', 'UNK'],
#  ['토르의', 'UNK'],
#  ['망치', 'UNK'],
#  ['Thors', 'UNK'],
#  ['Hammer', 'UNK'],
#  ['를', 'UNK'],
#  ['재해석해', '트렌드-B'],
#  ['방패', 'UNK'],
#  ['모양과', 'UNK'],
#  ['같은', 'UNK'],
#  ['구조로', 'UNK'],
#  ['대체됐다', 'UNK'],
#  ['여기에는', 'UNK'],
#  ['야간이면', 'UNK'],
#  ['메인', 'UNK'],
#  ['램프', '제품-B'],
#  ['구성이', 'UNK'],
#  ['드러나는', 'UNK'],
#  ['형태의', '스펙-B'],
#  ['최신', 'UNK'],
#  ['HD', 'UNK'],
#  ['기술이', '기술-B'],
#  ['적용된', '이벤트-B'],
#  ['순수', 'UNK'],
#  ['그래픽이', 'UNK'],
#  ['포함된다', 'UNK'],
#  ['또', 'UNK'],
#  ['다른', 'UNK'],
#  ['볼보자동차의', '제품-B'],
#  ['상징인', 'UNK'],
#  ['수직형', '스펙-B'],
#  ['리어', '제품-B'],
#  ['램프는', '제품-B'],
#  ['빠른', 'UNK'],
#  ['크루징', 'UNK'],
#  ['속도로', '서비스-B'],
#  ['전개되는', 'UNK'],
#  ['날개', 'UNK'],
#  ['세트', 'UNK'],
#  ['형태로', 'UNK'],
#  ['재창조돼', 'UNK'],
#  ['전반적인', 'UNK'],
#  ['공기', '트렌드-B'],
#  ['역학을', 'UNK'],
#  ['더욱', 'UNK'],
#  ['향상시킨다', '이벤트-B'],
#  ['볼보자동차', '제품-B'],
#  ['디자인', '이벤트-B'],
#  ['총괄', 'UNK'],
#  ['Head', 'UNK'],
#  ['of', 'UNK'],
#  ['Design', 'UNK'],
#  ['로빈', 'UNK'],
#  ['페이지', 'UNK'],
#  ['Robin', 'UNK'],
#  ['Page', 'UNK'],
#  ['는', 'UNK'],
#  ['컨셉트', 'UNK'],
#  ['리차지는', 'UNK'],
#  ['볼보자동차의', 'UNK'],
#  ['미래뿐만', 'UNK'],
#  ['아니라', 'UNK'],
#  ['새로운', 'UNK'],
#  ['타입의', '스펙-B'],
#  ['자동차를', 'UNK'],
#  ['위한', 'UNK'],
#  ['선언이라며', 'UNK'],
#  ['더욱', 'UNK'],
#  ['다재다능해진', 'UNK'],
#  ['새롭고', 'UNK'],
#  ['현대적인', 'UNK'],
#  ['비율을', 'UNK'],
#  ['보여줄', 'UNK'],
#  ['뿐만', 'UNK'],
#  ['아니라', 'UNK'],
#  ['디자인', 'UNK'],
#  ['측면에서는', 'UNK'],
#  ['어떤', 'UNK'],
#  ['기술을', '기술-B'],
#  ['사용할', 'UNK'],
#  ['수', 'UNK'],
#  ['있는지', 'UNK'],
#  ['제시한다고', 'UNK'],
#  ['소개했다', 'UNK'],
#  ['이와', 'UNK'],
#  ['더불어', 'UNK'],
#  ['볼보자동차는', '제품-B'],
#  ['컨셉트', 'UNK'],
#  ['리차지를', 'UNK'],
#  ['통해', '스펙-B'],
#  ['디자인', '이벤트-B'],
#  ['언어의', 'UNK'],
#  ['새로운', 'UNK'],
#  ['형태를', '스펙-B'],
#  ['제시한다', 'UNK'],
#  ['먼저', 'UNK'],
#  ['평평한', 'UNK'],
#  ['차체', 'UNK'],
#  ['바닥은', 'UNK'],
#  ['모든', 'UNK'],
#  ['탑승자에게', 'UNK'],
#  ['더', 'UNK'],
#  ['많은', 'UNK'],
#  ['공간과', 'UNK'],
#  ['개선된', '이벤트-B'],
#  ['시트', '제품-B'],
#  ['포지션을', 'UNK'],
#  ['제공한다', '이벤트-B'],
#  ['새로운', 'UNK'],
#  ['사용자', 'UNK'],
#  ['경험의', 'UNK'],
#  ['중심인', 'UNK'],
#  ['중앙', 'UNK'],
#  ['터치스크린은', '제품-B'],
#  ['차세대', 'UNK'],
#  ['커넥티드', '기술-B'],
#  ['인포테인먼트', '기술-B'],
#  ['시스템을', 'UNK'],
#  ['위해', 'UNK'],
#  ['15인치', 'UNK'],
#  ['대형', '스펙-B'],
#  ['스크린으로', 'UNK'],
#  ['확대됐다', 'UNK'],
#  ['여기에', 'UNK'],
#  ['논리적이면서', 'UNK'],
#  ['직관적인', 'UNK'],
#  ['기술과', '기술-B'],
#  ['깨끗한', 'UNK'],
#  ['라인', 'UNK'],
#  ['지속가능한', 'UNK'],
#  ['천연', 'UNK'],
#  ['소재의', 'UNK'],
#  ['광범위한', 'UNK'],
#  ['사용', 'UNK'],
#  ['통해', '스펙-B'],
#  ['스칸디나비아', '스펙-B'],
#  ['디자인의', '이벤트-B'],
#  ['특징인', 'UNK'],
#  ['평온하면서도', 'UNK'],
#  ['차분한', 'UNK'],
#  ['실내', '스펙-B'],
#  ['경험을', 'UNK'],
#  ['제공한다', '이벤트-B'],
#  ['로빈', 'UNK'],
#  ['페이지는', 'UNK'],
#  ['컨셉트', 'UNK'],
#  ['리차지의', 'UNK'],
#  ['인테리어는', '제품-B'],
#  ['진정한', 'UNK'],
#  ['스칸디나비아', '스펙-B'],
#  ['거실의', '스펙-B'],
#  ['느낌을', 'UNK'],
#  ['선사한다며', 'UNK'],
#  ['이를', 'UNK'],
#  ['위해', 'UNK'],
#  ['우리는', 'UNK'],
#  ['최신의', 'UNK'],
#  ['사용자', 'UNK'],
#  ['경험', 'UNK'],
#  ['기술을', '기술-B'],
#  ['아름답고', 'UNK'],
#  ['지속', 'UNK'],
#  ['가능한', 'UNK'],
#  ['천연의', 'UNK'],
#  ['소재와', 'UNK'],
#  ['통합했다', '스펙-B'],
#  ['실내에', '스펙-B'],
#  ['각', 'UNK'],
#  ['파트는', 'UNK'],
#  ['마치', 'UNK'],
#  ['하나의', 'UNK'],
#  ['예술품과', 'UNK'],
#  ['같으며', 'UNK'],
#  ['방안에', 'UNK'],
#  ['자리한', 'UNK'],
#  ['가구와', 'UNK'],
#  ['같이', 'UNK'],
#  ['개별적인', 'UNK'],
#  ['역할을', 'UNK'],
#  ['할', 'UNK'],
#  ['수', 'UNK'],
#  ['있다', 'UNK'],
#  ['우리는', 'UNK'],
#  ['단지', 'UNK'],
#  ['기술을', '기술-B'],
#  ['강조하기', 'UNK'],
#  ['위해서가', 'UNK'],
#  ['아닌', 'UNK'],
#  ['기술이', 'UNK'],
#  ['가져올', 'UNK'],
#  ['수', 'UNK'],
#  ['있는', 'UNK'],
#  ['이점에', 'UNK'],
#  ['초점을', 'UNK'],
#  ['맞추고', 'UNK'],
#  ['있다고', 'UNK'],
#  ['덧붙였다', 'UNK'],
#  ['이', 'UNK'],
#  ['밖에도', 'UNK'],
#  ['컨셉트', 'UNK'],
#  ['리차지를', 'UNK'],
#  ['통해', '스펙-B'],
#  ['앞으로', 'UNK'],
#  ['수년', 'UNK'],
#  ['이내에', 'UNK'],
#  ['선보일', 'UNK'],
#  ['안전에', 'UNK'],
#  ['대한', 'UNK'],
#  ['볼보자동차의', '제품-B'],
#  ['새로운', 'UNK'],
#  ['야망을', 'UNK'],
#  ['엿볼', 'UNK'],
#  ['수', 'UNK'],
#  ['있다', 'UNK'],
#  ['특히', 'UNK'],
#  ['안전한', 'UNK'],
#  ['자율', 'UNK'],
#  ['주행', 'UNK'],
#  ['기술', '기술-B'],
#  ['구현을', '이벤트-B'],
#  ['위해', 'UNK'],
#  ['루미나', 'UNK'],
#  ['Luminar', 'UNK'],
#  ['가', 'UNK'],
#  ['개발한', '이벤트-B'],
#  ['라이다', 'UNK'],
#  ['LiDAR', '기술-B'],
#  ['센서를', '제품-B'],
#  ['루프에', '제품-B'],
#  ['탑재해', '트렌드-B'],
#  ['자동차', '제품-B'],
#  ['주변', 'UNK'],
#  ['환경에', 'UNK'],
#  ['대한', 'UNK'],
#  ['데이터를', '기술-B'],
#  ['수집한다', 'UNK'],
#  ['로빈', 'UNK'],
#  ['페이지는', 'UNK'],
#  ['끝으로', 'UNK'],
#  ['컨셉트', 'UNK'],
#  ['리차지를', 'UNK'],
#  ['통해', '스펙-B'],
#  ['우리는', 'UNK'],
#  ['완전히', 'UNK'],
#  ['전기적인', '트렌드-B'],
#  ['미래로', 'UNK'],
#  ['나아가면서', 'UNK'],
#  ['현대적이고', 'UNK'],
#  ['신선한', 'UNK'],
#  ['방식으로', '스펙-B'],
#  ['볼보', '소재-B'],
#  ['디자인', '이벤트-B'],
#  ['DNA의', 'UNK'],
#  ['뿌리를', 'UNK'],
#  ['지속적으로', 'UNK'],
#  ['이어갈', 'UNK'],
#  ['것이라며', 'UNK'],
#  ['이는', 'UNK'],
#  ['고객이', 'UNK'],
#  ['기대하는', 'UNK'],
#  ['볼보의', 'UNK'],
#  ['순수', 'UNK'],
#  ['전기차에', '제품-B'],
#  ['모든', 'UNK'],
#  ['것으로', 'UNK'],
#  ['이러한', 'UNK'],
#  ['철학을', 'UNK'],
#  ['선보이게', 'UNK'],
#  ['돼', 'UNK'],
#  ['기쁘다고', 'UNK'],
#  ['밝혔다', 'UNK'],
#  ['M오토데일리', 'UNK'],
#  ['박상우', 'UNK'],
#  ['기자', 'UNK'],
#  ['대한민국', 'UNK'],
#  ['최고의', 'UNK'],
#  ['정유화학', '서비스-B'],
#  ['기업으로', 'UNK'],
#  ['성장해', '이벤트-B'],
#  ['온', 'UNK'],
#  ['SK이노베이션이', 'UNK'],
#  ['탄소', '소재-B'],
#  ['사업에서', 'UNK'],
#  ['그린', 'UNK'],
#  ['중심', 'UNK'],
#  ['사업으로', 'UNK'],
#  ['회사의', 'UNK'],
#  ['정체성을', 'UNK'],
#  ['완전히', 'UNK'],
#  ['바꾼다', 'UNK'],
#  ['SK이노베이션은', 'UNK'],
#  ['1일', 'UNK'],
#  ['서울', 'UNK'],
#  ['여의도', 'UNK'],
#  ['콘래드', 'UNK'],
#  ['호텔에서', 'UNK'],
#  ['김준', 'UNK'],
#  ['총괄사장', 'UNK'],
#  ['김종훈', 'UNK'],
#  ['이사회', 'UNK'],
#  ['의장', 'UNK'],
#  ['등', 'UNK'],
#  ['전', 'UNK'],
#  ['경영진과', '이벤트-B'],
#  ['국내외', 'UNK'],
#  ['시장', 'UNK'],
#  ['및', 'UNK'],
#  ['언론', '트렌드-B'],
#  ['관계자', 'UNK'],
#  ['등', 'UNK'],
#  ['200여명이', 'UNK'],
#  ['온오프라인으로', '기술-B'],
#  ['참석한', '이벤트-B'],
#  ['가운데', 'UNK'],
#  ['SK이노베이션', 'UNK'],
#  ['스토리', 'UNK'],
#  ['데이', 'UNK'],
#  ['Story', 'UNK'],
#  ['Day', 'UNK'],
#  ['를', 'UNK'],
#  ['갖고', 'UNK'],
#  ['이같이', 'UNK'],
#  ['밝혔다', 'UNK'],
#  ['SK이노베이션', 'UNK'],
#  ['스토리', 'UNK'],
#  ['데이는', 'UNK'],
#  ['지난', 'UNK'],
#  ['2017년', 'UNK'],
#  ['혁신', '기술-B'],
#  ['방향', 'UNK'],
#  ['제시', 'UNK'],
#  ['2019년', 'UNK'],
#  ['혁신', 'UNK'],
#  ['실행', '스펙-B'],
#  ['전략', '이벤트-B'],
#  ['발표에', '이벤트-B'],
#  ['이은', 'UNK'],
#  ['세번째', 'UNK'],
#  ['행사로', '이벤트-B'],
#  ['이번엔', 'UNK'],
#  ['혁신', 'UNK'],
#  ['완성에', '이벤트-B'],
#  ['대한', 'UNK'],
#  ['구체적인', '스펙-B'],
#  ['방안을', 'UNK'],
#  ['제시한', 'UNK'],
#  ['것으로', 'UNK'],
#  ['SK이노베이션은', 'UNK'],
#  ['글로벌', 'UNK'],
#  ['친환경', '트렌드-B'],
#  ['산업', 'UNK'],
#  ['핵심인', 'UNK'],
#  ['배터리', '제품-B'],
#  ['사업', 'UNK'],
#  ['1테라와트', 'UNK'],
#  ['α', 'UNK'],
#  ['수주', '이벤트-B'],
#  ['역량에', 'UNK'],
#  ['기반해', 'UNK'],
#  ['그린', 'UNK'],
#  ['사업을', 'UNK'],
#  ['새', 'UNK'],
#  ['성장축으로', '이벤트-B'],
#  ['미래', 'UNK'],
#  ['전략을', 'UNK'],
#  ['만들어', 'UNK'],
#  ['가겠다는', 'UNK'],
#  ['것이', 'UNK'],
#  ['핵심이다', 'UNK'],
#  ['김준', 'UNK'],
#  ['총괄사장', 'UNK'],
#  ['등', 'UNK'],
#  ['SK이노베이션', 'UNK'],
#  ['경영진이', '이벤트-B'],
#  ['이날', 'UNK'],
#  ['밝힌', 'UNK'],
#  ['파이낸셜', 'UNK'],
#  ['스토리의', 'UNK'],
#  ['핵심은', 'UNK'],
#  ['한마디로', 'UNK'],
#  ['Carbon', 'UNK'],
#  ['to', 'UNK'],
#  ['Green', 'UNK'],
#  ['즉', 'UNK'],
#  ['탄소', '소재-B'],
#  ['중심의', 'UNK'],
#  ['사업', 'UNK'],
#  ['구조를', 'UNK'],
#  ['그린', 'UNK'],
#  ['중심의', 'UNK'],
#  ['사업을', 'UNK'],
#  ['영위하는', 'UNK'],
#  ['기업으로', 'UNK'],
#  ['탈바꿈', '이벤트-B'],
#  ['시키겠다는', 'UNK'],
#  ['것이다', 'UNK'],
#  ['올해', 'UNK'],
#  ['신년', 'UNK'],
#  ['경영방침을', '이벤트-B'],
#  ['통해', '스펙-B'],
#  ['회사의', 'UNK'],
#  ['새로운', 'UNK'],
#  ['아이덴티티를', 'UNK'],
#  ['친환경', '트렌드-B'],
#  ['에너지소재', '트렌드-B'],
#  ['회사', 'UNK'],
#  ['Green', 'UNK'],
#  ['Energy', 'UNK'],
#  ['Materials', 'UNK'],
#  ['Co', 'UNK'],
#  ['로', 'UNK'],
#  ['밝힌', 'UNK'],
#  ['바', 'UNK'],
#  ['있는', 'UNK'],
#  ['SK이노베이션은', 'UNK'],
#  ['이날', 'UNK'],
#  ['스토리데이를', 'UNK'],
#  ['통해', 'UNK'],
#  ['구체적인', '스펙-B'],
#  ['완성', '이벤트-B'],
#  ['전략을', '이벤트-B'],
#  ['공개했다', '이벤트-B'],
#  ['김준', 'UNK'],
#  ['총괄사장과', 'UNK'],
#  ['SK이노베이션', 'UNK'],
#  ['경영진이', '이벤트-B'],
#  ['밝힌', 'UNK'],
#  ['핵심', 'UNK'],
#  ['전략은', '이벤트-B'],
#  ['Green', 'UNK'],
#  ['Anchoring', 'UNK'],
#  ['배터리를', '제품-B'],
#  ['중심으로', 'UNK'],
#  ['분리막', '소재-B'],
#  ['폐배터리', '제품-B'],
#  ['리사이클', '스펙-B'],
#  ['등', 'UNK'],
#  ['그린', 'UNK'],
#  ['포트폴리오', '소재-B'],
#  ['강화', 'UNK'],
#  ['Green', 'UNK'],
#  ['Transformation', 'UNK'],
#  ['기존', 'UNK'],
#  ['사업을', 'UNK'],
#  ['플라스틱', 'UNK'],
#  ['리사이클', 'UNK'],
#  ['등', 'UNK'],
#  ['친환경', '트렌드-B'],
#  ['비즈니스', '스펙-B'],
#  ['모델로', 'UNK'],
#  ['전환', 'UNK'],
#  ['온실가스', '트렌드-B'],
#  ['배출', '이벤트-B'],
#  ['0', 'UNK'],
#  ['제로', 'UNK'],
#  ['인', 'UNK'],
#  ['넷', 'UNK'],
#  ['제로', 'UNK'],
#  ['Net', 'UNK'],
#  ['Zero', 'UNK'],
#  ['조기', 'UNK'],
#  ['달성', '이벤트-B'],
#  ['등', 'UNK'],
#  ['크게', 'UNK'],
#  ['3가지로', 'UNK'],
#  ['요약된다', 'UNK'],
#  ['SK이노베이션은', 'UNK'],
#  ['현재', 'UNK'],
#  ['배터리', '제품-B'],
#  ['수주', '이벤트-B'],
#  ['잔고가', 'UNK'],
#  ['1테라와트', 'UNK'],
#  ['α', 'UNK'],
#  ['에', 'UNK'],
#  ['달한다고', 'UNK'],
#  ['공개했다', '이벤트-B'],
#  ['그동안', 'UNK'],
#  ['1테라와트', 'UNK'],
#  ['이상을', 'UNK'],
#  ['수주한', '이벤트-B'],
#  ['곳은', 'UNK'],
#  ['글로벌', 'UNK'],
#  ['상위', 'UNK'],
#  ['두', 'UNK'],
#  ['개사', 'UNK'],
#  ['정도로', '서비스-B'],
#  ['알려져', 'UNK'],
#  ['있었는데', 'UNK'],
#  ['SK의', 'UNK'],
#  ['수주', 'UNK'],
#  ['잔고가', 'UNK'],
#  ['1테라와트', 'UNK'],
#  ['α의', 'UNK'],
#  ['규모라고', '이벤트-B'],
#  ['밝힘에', 'UNK'],
#  ['따라', 'UNK'],
#  ['3개사로', 'UNK'],
#  ['늘어난', 'UNK'],
#  ['것이다', 'UNK'],
#  ['따라서', 'UNK'],
#  ['SK', 'UNK'],
#  ['배터리', '제품-B'],
#  ['사업', 'UNK'],
#  ['목표는', 'UNK'],
#  ['글로벌', 'UNK'],
#  ['Top3에서', 'UNK'],
#  ['글로벌', 'UNK'],
#  ['Top을', 'UNK'],
#  ['향할', 'UNK'],
#  ['수', 'UNK'],
#  ['있게', 'UNK'],
#  ['된', 'UNK'],
#  ['것이다', 'UNK'],
#  ['1테라와트는', 'UNK'],
#  ['SK이노베이션이', 'UNK'],
#  ['배터리', '제품-B'],
#  ['사업을', 'UNK'],
#  ['새로운', 'UNK'],
#  ['성장축으로', '이벤트-B'],
#  ['키우겠다고', 'UNK'],
#  ['밝혔던', 'UNK'],
#  ['2017년', 'UNK'],
#  ['5월', 'UNK'],
#  ['당시의', 'UNK'],
#  ['60GWh', 'UNK'],
#  ['보다', 'UNK'],
#  ['약', 'UNK'],
#  ['17배', 'UNK'],
#  ['늘어난', 'UNK'],
#  ['것으로', 'UNK'],
#  ['한화', 'UNK'],
#  ['환산시', 'UNK'],
#  ['130조원', 'UNK'],
#  ['이상이다', 'UNK'],
#  ['또한', 'UNK'],
#  ['진행', 'UNK'],
#  ['중인', 'UNK'],
#  ['수주', '이벤트-B'],
#  ['프로그램이', 'UNK'],
#  ['완성되면', '이벤트-B'],
#  ['수주', 'UNK'],
#  ['잔고는', 'UNK'],
#  ['더욱', 'UNK'],
#  ['늘어날', 'UNK'],
#  ['것으로', 'UNK'],
#  ['보인다', 'UNK'],
#  ['SK', 'UNK'],
#  ['배터리', '제품-B'],
#  ['사업', 'UNK'],
#  ['지동섭', 'UNK'],
#  ['대표는', 'UNK'],
#  ['내년', 'UNK'],
#  ['말에는', 'UNK'],
#  ['월', 'UNK'],
#  ['판매량에서도', '이벤트-B'],
#  ['세계', 'UNK'],
#  ['3위로', 'UNK'],
#  ['올라설', 'UNK'],
#  ['것이라고', 'UNK'],
#  ['예상했다', 'UNK'],
#  ['이렇게', 'UNK'],
#  ['되면', 'UNK'],
#  ['수주와', '이벤트-B'],
#  ['매출이라는', '이벤트-B'],
#  ['양대', 'UNK'],
#  ['영역에서', 'UNK'],
#  ['글로벌', 'UNK'],
#  ['Top3를', 'UNK'],
#  ['실현하는', '스펙-B'],
#  ['셈이다', 'UNK'],
#  ['지동섭', 'UNK'],
#  ['대표는', 'UNK'],
#  ['SK는', 'UNK'],
#  ['가장', 'UNK'],
#  ['안전하고', 'UNK'],
#  ['가장', 'UNK'],
#  ['빠르게', 'UNK'],
#  ['충전하고', '스펙-B'],
#  ['가장', 'UNK'],
#  ['오래', 'UNK'],
#  ['쓸', 'UNK'],
#  ['수', 'UNK'],
#  ['있는', 'UNK'],
#  ['배터리를', '제품-B'],
#  ['추구하고', 'UNK'],
#  ['있으며', 'UNK'],
#  ['특히', 'UNK'],
#  ['안전은', 'UNK'],
#  ['그', 'UNK'],
#  ['무엇보다', 'UNK'],
#  ['중요한', 'UNK'],
#  ['가치라며', 'UNK'],
#  ['이것이', 'UNK'],
#  ['SK배터리를', 'UNK'],
#  ['탑재한', 'UNK'],
#  ['차량에서', '제품-B'],
#  ['화재사고가', '사건/사고-B'],
#  ['한번도', 'UNK'],
#  ['없었던', 'UNK'],
#  ['이유이자', 'UNK'],
#  ['수주가', '이벤트-B'],
#  ['급격히', 'UNK'],
#  ['증가한', 'UNK'],
#  ['배경이라고', 'UNK'],
#  ['강조했다', 'UNK'],
#  ['SK이노베이션의', 'UNK'],
#  ['생산', 'UNK'],
#  ['규모도', '이벤트-B'],
#  ['크게', 'UNK'],
#  ['늘어난다', 'UNK'],
#  ['지동섭', 'UNK'],
#  ['대표는', 'UNK'],
#  ['현재', 'UNK'],
#  ['40GWh', 'UNK'],
#  ['수준에서', 'UNK'],
#  ['2023년', 'UNK'],
#  ['85GWh', 'UNK'],
#  ['2025년에는', 'UNK'],
#  ['200GWh', 'UNK'],
#  ['2030년에는', 'UNK'],
#  ['500GWh', 'UNK'],
#  ['이상으로', 'UNK'],
#  ['예상하고', 'UNK'],
#  ['있으며', 'UNK'],
#  ['EBITDA', '기술-B'],
#  ['기준', 'UNK'],
#  ['올해', 'UNK'],
#  ['흑자를', '이벤트-B'],
#  ['달성하고', '이벤트-B'],
#  ['2023년', 'UNK'],
#  ['1조원', 'UNK'],
#  ['2025년', 'UNK'],
#  ['25조원까지', 'UNK'],
#  ['각각', 'UNK'],
#  ['창출할', 'UNK'],
#  ['수', 'UNK'],
#  ['있을', 'UNK'],
#  ['것이라고', 'UNK'],
#  ['밝혔다', 'UNK'],
#  ['또한', 'UNK'],
#  ['SK이노베이션은', 'UNK'],
#  ['배터리의', '제품-B'],
#  ['핵심', 'UNK'],
#  ['소재', 'UNK'],
#  ['LiBS', 'UNK'],
#  ['리튬이온전지분리막', '소재-B'],
#  ['사업', 'UNK'],
#  ['자회사', 'UNK'],
#  ['상장', '이벤트-B'],
#  ['성공을', '이벤트-B'],
#  ['계기로', 'UNK'],
#  ['현', 'UNK'],
#  ['14억㎡인', 'UNK'],
#  ['LiBS', 'UNK'],
#  ['생산', 'UNK'],
#  ['규모를', '이벤트-B'],
#  ['2023년', 'UNK'],
#  ['21억㎡로', 'UNK'],
#  ['키운', 'UNK'],
#  ['뒤', 'UNK'],
#  ['전기차', '제품-B'],
#  ['산업의', 'UNK'],
#  ['본격', 'UNK'],
#  ['성장이', '이벤트-B'],
#  ['예상되는', 'UNK'],
#  ['2025년에는', 'UNK'],
#  ['현재의', 'UNK'],
#  ['3배인', 'UNK'],
#  ...]

# %%
pd.DataFrame(rslt).to_csv('Test_Tagging_v210817.csv', encoding='utf-8-sig', index=False)
pd.DataFrame(rslt_word).to_csv('Test_word_Tagging_v210817.csv', encoding='utf-8-sig', index=False)
