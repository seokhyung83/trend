# %%
import sqlite3
import pandas as pd
import numpy as np
import pymysql
import re
from kss import kss
from konlpy.tag import Mecab
import pickle
import unicodedata

# %%
mecab = Mecab()
tmp_ref_dic = pd.read_csv('ref_dic.csv')#ref_dic.reset_index(drop=True)
tmp_pos_set = tmp_ref_dic['명칭'].values.tolist()
pos_sel_no = []
for i in range(0, len(tmp_pos_set)):
    try :
        if unicodedata.name(tmp_pos_set[i][0]).split(' ')[0] in ('HANGUL', 'LATIN'):
            if len(tmp_pos_set[i]) > 1 :
                pos_sel_no.append(i)
            elif unicodedata.name(tmp_pos_set[i][0]).split(' ')[0] in ('HANGUL'):
                pos_sel_no.append(i)
    except:
        pass #rint(i)

ref_dic = tmp_ref_dic.iloc[pos_sel_no, :].reset_index(drop=True).copy()
pos_set = [x.strip() for x in ref_dic['명칭'].values.tolist()]

# %%
pos_set
# Out:
# ['Cell to Pack',
#  '무선충전',
#  '빅데이터',
#  '인공지능',
#  '인포테인먼트',
#  '커넥티드',
#  '클라우드',
#  '텔레매틱스',
#  '컴퓨팅',
#  'IT',
#  '엔지니어링',
#  'ICT',
#  'ADAS',
#  '중성자',
#  'VR',
#  'MR',
#  '플렉시블',
#  'UHD',
#  '증폭기',
#  '원자로',
#  '자연어처리',
#  '플라스틱재활용',
#  '생물정보학',
#  '녹색수소',
#  '대체단백질',
#  '재료정보학',
#  '정밀농업',
#  '합성생물학',
#  '에지컴퓨팅',
#  '유전자교정',
#  '의료이미징',
#  '홀로그램',
#  'GPS',
#  'LTE',
#  'IT·NT·BT',
#  '자연모사기술',
#  '농식품신선도유지기술',
#  '디지털휴먼증강',
#  'DNA개량',
#  '대체에너지개발',
#  '안전포장기술',
#  '전기차충전기술',
#  '고속충전기술',
#  '오토파일럿',
#  '사물인터넷',
#  '크루즈컨트롤',
#  '운전자보조기능',
#  'AR',
#  '헬스케어',
#  '메타버스',
#  '양극재설계',
#  '양극재제조',
#  '첨가제제조',
#  '첨가제설계',
#  '흑연계설계',
#  '복합체설계',
#  '음극재설계',
#  '음극재제조',
#  '분리막설계',
#  '분리막제조',
#  'SRS설계',
#  'SRS제조',
#  '분리막공정',
#  '전해액설계',
#  '전해액제조',
#  '전해질설계',
#  '전해질제조',
#  '바인더설계',
#  '도전재설계',
#  '바인더제조',
#  '도전재제조',
#  'Pouch설계',
#  'Lead Assembly 제조',
#  '기타부품설계',
#  '젤리롤전극조립체',
#  '소형파우치형설계',
#  '중대형파우치형설계',
#  '소형원통형설계',
#  '중대형원통형설계',
#  '소형각형설계',
#  '중대형각형설계',
#  '차세대전지설계',
#  '신규구조셀설계',
#  'Mixing',
#  'Coating',
#  'RollPress',
#  'Slitting',
#  '전극건조',
#  'Notching',
#  'Lamination',
#  'Winding',
#  'Assembly',
#  'Folding',
#  'Stacking',
#  'Package',
#  'Formation',
#  'Degas',
#  'DSF',
#  'EOL',
#  '검사기술',
#  '제어기술',
#  'DE',
#  '포장기술',
#  'PFMEA',
#  '해석기술',
#  'Pre-lithiation',
#  '제련기술',
#  '신규소재공정기술',
#  '신규구조셀제조',
#  '신뢰성기술',
#  '환경분석',
#  '안전성분석',
#  '셀규격해석',
#  '셀설계분석',
#  '플라스틱성형',
#  '금속성형',
#  '후처리기술',
#  '접합',
#  '조립',
#  '인쇄기술',
#  '공차분석',
#  '구조물설계',
#  '전기연결설계',
#  '냉각구조설계',
#  '안전성설계',
#  '소재성형해석',
#  '해석기반셀등가',
#  '팩/모듈구조해석',
#  '팩/모듈열유동해석',
#  '공정해석',
#  '접합해석',
#  '입자기반해석',
#  '최적화해석',
#  '다중물리학해석',
#  '배터리수명시험분석',
#  '시험해석',
#  '신뢰성시험개발',
#  'AI기반최적설계',
#  '데이터기반모델링',
#  '시뮬레이션',
#  '전자회로부품설계',
#  '전원회로설계',
#  '제어회로설계',
#  '측정회로설계',
#  '통신회로설계',
#  'BMS회로공정',
#  'SW개발프로세스',
#  '네트워크',
#  '배터리진단',
#  '배터리신호처리',
#  '배터리신호제어',
#  'Cell Modeling',
#  'Numerical Optimization',
#  'BMS Sox 알고리즘구현',
#  'SoX알고리즘Design',
#  'AI알고리즘',
#  'AI엔진',
#  '부품유해물질분석',
#  '전기적특성평가',
#  '내구성평가',
#  'Visualinspection',
#  'SW검증',
#  '셀평가',
#  '전장부품설계',
#  '기능안전',
#  '배터리사용패턴분석',
#  '배터리잔존율모델링',
#  '배터리System설계',
#  'Augmentation운영설계',
#  '시스템전기적분석',
#  '운영기록분석',
#  'AI기반',
#  'P2P',
#  '가상세계',
#  '감시기술',
#  '개방형혁신',
#  '개인맞춤형의료기술',
#  '개인지능화',
#  '공공지능화',
#  '기술변혁',
#  '기술변화',
#  '기술융합',
#  '나노',
#  '나노기술',
#  '넥스트딥러닝',
#  '농업농촌첨단화',
#  '데이터접근성',
#  '도시인프라',
#  '디지털건설기술',
#  '디지털문화기술',
#  '디지털콘텐츠',
#  '디지털트윈',
#  '디지털화',
#  '로보틱스',
#  '로봇기술',
#  '모니터링기술',
#  '모빌리티진화',
#  '무인화',
#  '바이오기술',
#  '바이오컴퓨터',
#  '병충해치료',
#  '분자기술',
#  '블록체인',
#  '사이버물리시스템',
#  '사이버보안',
#  '사이버위협',
#  '산업지능화',
#  '기반기술',
#  '센싱기술',
#  '소재연구',
#  '스마트교통시스템',
#  '스마트기반시설물관리',
#  '스마트워크',
#  '알고리즘거버넌스',
#  '엣지컴퓨팅',
#  '오프라인',
#  '온라인',
#  '유전자교정기술',
#  '유전자기술',
#  '이미징기술',
#  '자동화',
#  '지능화',
#  '질병치료',
#  '차세대컴퓨팅',
#  '첨단신교통수단',
#  '초고속통신기술',
#  '초연결',
#  '퀀텀컴퓨터',
#  '클라우딩',
#  '화상회의',
#  '데이터',
#  '정보',
#  '기술',
#  '문화기술',
#  '사회기술',
#  '교통기술',
#  '국방기술',
#  '정보통신',
#  '혁신',
#  '첨단',
#  '크로스오버',
#  '현장단속',
#  '계약취소',
#  '자격정지',
#  '장벽규제',
#  '금지조치',
#  '행정처분',
#  '샌드박스',
#  '팬데믹',
#  '독과점',
#  '이익감소',
#  '경영악재',
#  '교착상태',
#  '반독점',
#  '조업중단',
#  '생존위기',
#  '화재',
#  '가동중단',
#  '파업',
#  '가처분신청',
#  '가치하락',
#  '각하결정',
#  '강경대응',
#  '강제매각',
#  '강제이주',
#  '강제인증',
#  '강제조치',
#  '거액소송',
#  '거짓공시',
#  '경기하락',
#  '경조치',
#  '경찰조사',
#  '계도조치',
#  '계약포기',
#  '공동소송',
#  '공장폐쇄',
#  '과잉대응',
#  '관세인상',
#  '기술탈취',
#  '긴급대응',
#  '긴급대출',
#  '긴급명령',
#  '긴급수입제한조치',
#  '긴급재난지원',
#  '긴급조치',
#  '긴급지원',
#  '긴급투입',
#  '뇌물공여',
#  '다중대표소송',
#  '대북제재',
#  '대표소송',
#  '덤핑조사',
#  '리콜명령',
#  '마이너스대출',
#  '매출하락',
#  '면허취소',
#  '명도소송',
#  '명소소송',
#  '무진행',
#  '무허가',
#  '무효소송',
#  '물가상승',
#  '물가상승률',
#  '민사소송',
#  '밀거래',
#  '밀수출',
#  '반독점조사',
#  '배제명령',
#  '법적조치',
#  '법정관리',
#  '법정소송',
#  '보복조치',
#  '보상협의',
#  '보완조사',
#  '보완조치',
#  '보전조치',
#  '보정명령',
#  '본소송',
#  '본안소송',
#  '봉쇄명령',
#  '봉쇄조치',
#  '부정거래',
#  '불공정거래',
#  '불공정경쟁',
#  '불법대출',
#  '불법합병',
#  '불성실공시',
#  '불승인',
#  '비상경제대응책',
#  '비상경제조치들',
#  '비상대응',
#  '비상승인',
#  '비상조치',
#  '비용상승',
#  '비용확대',
#  '사고대응',
#  '사전예방조치',
#  '상장폐지결정',
#  '상향조치',
#  '세무조사',
#  '소폭하락',
#  '소환조사',
#  '손상조사',
#  '손실보상협의',
#  '손실보전협상',
#  '손실확대',
#  '수급대란',
#  '수입제한조치',
#  '수직하락',
#  '수출규제조치',
#  '시장안정조치',
#  '시정명령',
#  '신뢰하락',
#  '신용하락',
#  '신주발행무효소송',
#  '실업대란',
#  '악재공시',
#  '안전조치',
#  '엄정조치',
#  '업무개시명령',
#  '여행조치',
#  '영장청구',
#  '외출금지명령',
#  '위기대응',
#  '위험대응',
#  '음성명령',
#  '응급조치',
#  '의료대란',
#  '의료대응조치',
#  '의료소송',
#  '의료조치',
#  '의류통제명령',
#  '이동제한조치',
#  '이면계약',
#  '이상거래',
#  '이상거래탐지',
#  '이상금융거래탐지',
#  '이익미실현',
#  '이중대표소송',
#  '인력대란',
#  '일시폐쇄',
#  '임상실패',
#  '임상중단',
#  '임시보호명령',
#  '임시폐쇄',
#  '입법조치',
#  '자본시장법위반',
#  '작업명령',
#  '재난대응',
#  '재택명령',
#  '재해대응',
#  '전세대란',
#  '정식보호명령',
#  '정언명령',
#  '정지명령',
#  '제한조치',
#  '조기폐쇄',
#  '주가하락',
#  '주가하락률',
#  '주가하락폭',
#  '주식하락',
#  '주주명부폐쇄',
#  '줄소송',
#  '줄취소',
#  '중도포기',
#  '지급명령',
#  '지수하락',
#  '지원조치',
#  '직장폐쇄',
#  '질병대응',
#  '집단소송',
#  '집합금지명령',
#  '집회금지명령',
#  '차단조치',
#  '청구소송',
#  '초과계약',
#  '추가조치',
#  '추가하락',
#  '추심명령',
#  '추징보전청구',
#  '출혈경쟁',
#  '취소소송',
#  '취소신청',
#  '탈포기',
#  '특단조치',
#  '특별조치법',
#  '특별행정조치',
#  '특허무효소송',
#  '특허소송',
#  '특허침해소송',
#  '파산보호신청',
#  '파산신청',
#  '판매대란',
#  '폐쇄명령',
#  '폐쇄조치',
#  '폐지대란',
#  '피해지원',
#  '하락국면',
#  '하락기',
#  '하락률',
#  '하락새',
#  '하락세',
#  '하락속도',
#  '하락요인',
#  '하락장',
#  '하락중',
#  '하락추세',
#  '하락폭',
#  '합병무효소송',
#  '행정명령',
#  '행정소송',
#  '행정조치',
#  '허가취소',
#  '현장검증',
#  '현장검출',
#  '혈세투입',
#  '협상결렬',
#  '협상중단',
#  '환경개선명령',
#  '환불조치',
#  '환수조치',
#  '회수명령',
#  '회수조치',
#  '회수폐기명령',
#  '후속조치',
#  '후속조치등',
#  '소송',
#  '축소',
#  '논란',
#  '중단',
#  '반대',
#  '위기',
#  '비상',
#  '차질',
#  '분쟁',
#  '연기',
#  '매각',
#  '갈등',
#  '노조',
#  '공격',
#  '반덤핑',
#  '휴업',
#  '이탈',
#  '우려',
#  '운휴',
#  '침해',
#  '철수',
#  '공방',
#  '겨냥',
#  '노사',
#  '불공정',
#  '리스크',
#  '장애물',
#  '위반',
#  '제동',
#  '반발',
#  '저조',
#  '제소',
#  '경고',
#  '진화',
#  '안간힘',
#  '폭등',
#  '급발진',
#  '오동작',
#  '인재',
#  '체불',
#  '감시',
#  '무기',
#  '난항',
#  '어려움',
#  '경보',
#  '쟁점',
#  '수수료',
#  '폭력',
#  '파산',
#  '직격탄',
#  '악재',
#  '무단',
#  '격화',
#  '무용지물',
#  '순찰',
#  '과열',
#  '전면전',
#  '손실',
#  '질병',
#  '철거',
#  '해임',
#  '항소',
#  '유찰',
#  '해체',
#  '퇴출',
#  '연루',
#  '곤혹',
#  '비난',
#  '침입',
#  '고비',
#  '타격',
#  '불똥',
#  '파열',
#  '장악',
#  '냉전',
#  '보복',
#  '경직',
#  '둔화',
#  '안개',
#  '비상제동',
#  'EMERGENCY',
#  '손절',
#  '억측',
#  '무산',
#  '노후',
#  '금품',
#  '영리',
#  '블랙리스트',
#  '기각',
#  '폐점',
#  '적발',
#  '폐허',
#  '추돌',
#  '긴장',
#  '거부',
#  '난관',
#  '해고',
#  '야기',
#  '특허분쟁',
#  '불화',
#  '감축',
#  '채무',
#  '보상',
#  '국제중재',
#  '부진',
#  '도용',
#  '부당',
#  '피해',
#  '혐의',
#  '무시',
#  '악의',
#  '응급',
#  '취약',
#  '순손실',
#  '법정',
#  '위협',
#  '상실',
#  '응징',
#  '허약',
#  '대가',
#  '유발',
#  '교통사고',
#  '특단',
#  '애로',
#  '적자',
#  '가중',
#  '바이러스',
#  '감염',
#  '가동정지',
#  '고객불만',
#  '대응',
#  '라인정지',
#  '무효가동',
#  '반품',
#  '변제',
#  '부적합보고서',
#  '부적합자재',
#  '불만',
#  '불용',
#  '불용재고',
#  '비상계획',
#  '사고',
#  '셧다운',
#  '시정조치',
#  '시정조치보고서',
#  '시정조치요구서',
#  '악화',
#  '에러',
#  '재발',
#  '재작업',
#  '저품질비용',
#  '전복',
#  '침수',
#  '침수라벨',
#  '클레임',
#  '트러블',
#  '홀딩',
#  '비엠',
#  '리콜',
#  'Mobility-as-a-Service',
#  '공유',
#  '구독',
#  '렌트',
#  '리사이클',
#  '리스',
#  '교통',
#  '배송',
#  '배터리교환',
#  '배터리재활용',
#  '주차',
#  '카쉐어링',
#  '플랫폼',
#  '인프라',
#  '도로',
#  '인터넷',
#  '전송',
#  '차선',
#  '트래픽',
#  '주차장',
#  '발렛',
#  '파킹',
#  '주유소',
#  '원격',
#  '항만',
#  'AS',
#  '택배',
#  '주유',
#  '기지국',
#  '통운',
#  '정유',
#  '정류장',
#  '승강장',
#  '터널',
#  '포털',
#  '고속도로',
#  '방재',
#  '방범',
#  '통신망',
#  '교통량',
#  '운행량',
#  '정거장',
#  '휴게소',
#  '메신저',
#  '매크로',
#  '틱톡',
#  '통신회의',
#  '시큐리티',
#  '급속',
#  '티맵',
#  '디지털판매플랫폼',
#  '국토시설물안전망',
#  '국가자원통합관리',
#  '생물정화',
#  '예측대비',
#  '기후예측',
#  '사막녹지화',
#  '배출권거래',
#  '공기정화',
#  '공기판매',
#  '전주기탄소배출관리',
#  '온라인대선투표',
#  '홀로그램화상회의',
#  '도심주거지소음차단',
#  '개인건강관리',
#  '언어문화배움',
#  '우주관광',
#  '해저관광',
#  '도시관리',
#  '프라이버시보호',
#  '지식큐레이션',
#  '지식공유',
#  '질병예측진단치료',
#  'AI튜터',
#  '친환경축사관리',
#  '신재생에너지거래',
#  '교통흐름최적화',
#  '비상전원발전',
#  '교통사고예방',
#  'Business to Consumer',
#  'business-to-business',
#  '배터리교체',
#  '배터리재사용',
#  '쾌속배송',
#  '돌봄',
#  '스마트도로망',
#  '지능형교통체계',
#  '스마트횡단보도',
#  '스마트교차로',
#  '긴급상황우선신호',
#  '데이터비즈니스',
#  '구리',
#  '구리포일',
#  '그래핀',
#  '나트륨',
#  '니켈',
#  '니켈도금철',
#  '니켈코발트망간옥사이드',
#  '도전재',
#  '도펀트',
#  '러버',
#  '리튬',
#  '리튬금속',
#  '리튬니켈옥사이드',
#  '리튬망간산화물',
#  '리튬산소',
#  '리튬이온',
#  '리튬인산철',
#  '리튬카보네이트',
#  '리튬코발트옥사이드',
#  '리튬황',
#  '멀티콥터',
#  '메탈',
#  '바인더',
#  '솔벤트',
#  '실리콘',
#  '아연',
#  '알루미나',
#  '알루미늄',
#  '알루미늄포일',
#  '에스비알',
#  '인조흑연',
#  '일산화규소',
#  '전고체',
#  '전구체',
#  '천연흑연',
#  '촉매',
#  '코발트',
#  '탄소나노튜브',
#  '탄소섬유',
#  '탄화수소',
#  '프리프 레그',
#  '환형카보네이트',
#  '활물질',
#  '활성탄소',
#  '황화물계',
#  '흑연',
#  '가공소재',
#  '가교제',
#  '가교폴리에틸렌',
#  '가르시니아추출물',
#  '가소제',
#  '가시광촉매',
#  '갈락토',
#  '갈락토오스',
#  '갈락토올리고당',
#  '갈륨나이트라이드',
#  '감나무잎추출물',
#  '감태추출물',
#  '강화플라스틱',
#  '개량균주',
#  '개발물질',
#  '개선물질',
#  '개질수소',
#  '건강소재',
#  '건강식품원료',
#  '건축소재',
#  '게르마늄',
#  '결합단백질',
#  '결합물질',
#  '경량복합소재',
#  '경쟁물질',
#  '고단백질',
#  '고무및플라스틱',
#  '고무플라스틱',
#  '고밀도폴리에틸렌',
#  '고부가합성수지',
#  '고분자화합물',
#  '고정화효소',
#  '고품위탄산칼슘',
#  '고흡수성수지',
#  '고흡습성수지',
#  '곡류혼합효소분말',
#  '곡물발효효소소',
#  '골형성단백질',
#  '골형성촉진제',
#  '공액리놀레산',
#  '과산화수소',
#  '과황산화합물',
#  '광경화성수지',
#  '광물질',
#  '광소재',
#  '광전소재',
#  '광학부품소재',
#  '광학소재',
#  '구리화합물',
#  '구연산',
#  '구절초추출물',
#  '균원료',
#  '그람음성균',
#  '그레이수소',
#  '그린소재',
#  '그린수소',
#  '글루카곤',
#  '글루칸',
#  '글루코사민',
#  '글루코스',
#  '글루타르산',
#  '글루타미쿰',
#  '글루타민산나트륨',
#  '글루타치온',
#  '글루텐',
#  '글리세롤',
#  '글리세린',
#  '글리알세포',
#  '글리콜',
#  '글리콜라이드',
#  '글리틴',
#  '금나노입자',
#  '금속물질',
#  '금속세라믹플라스틱',
#  '금속소재',
#  '금속플라스틱',
#  '금잔화추출물',
#  '기계소재',
#  '기능소재',
#  '기본소재',
#  '기술장벽',
#  '기초소재',
#  '기초화학원료',
#  '기타물질',
#  '나노겔',
#  '나노섬유',
#  '나노섬유시트',
#  '나노섬유필름',
#  '나노세라믹입자',
#  '나노셀룰로오스',
#  '나노소재',
#  '나노실리카',
#  '나노에멀전',
#  '나노와이어',
#  '나노융합소재',
#  '나노이산화티타늄',
#  '나노이온소자',
#  '나노입자',
#  '나노잉크',
#  '나노자성',
#  '나노재료',
#  '나노전달체',
#  '나노젤',
#  '나노칼슘',
#  '나노탄소',
#  '나노탄소입자',
#  '나노튜브',
#  '나노파이버',
#  '나노파티클',
#  '나노플라스틱',
#  '나노흡착제',
#  '나이벡펩타이드',
#  '나일론',
#  '난연제',
#  '난연폴리카보네이트',
#  '내성억제물질',
#  '냉감소재',
#  '노카벤즈옥사졸',
#  '녹차추출물',
#  '다이옥사논',
#  '다이카르복시산',
#  '다중단백질',
#  '다탄소',
#  '다탄소화합물',
#  '단당류',
#  '단량체',
#  '단량체들',
#  '단백분해효소',
#  '단백질',
#  '단백질결합수용체',
#  '단백질구조',
#  '단백질분해효소',
#  '단백질원',
#  '단백질제',
#  '단분자',
#  '단소재',
#  '단위세포',
#  '단일소재',
#  '단일클론항체',
#  '담팥수추출물',
#  '당근추출물',
#  '당단백질',
#  '대마추출물',
#  '대보추출물',
#  '대사물질',
#  '대사질환치료물질',
#  '대체소재',
#  '대표소재',
#  '돌기단백질',
#  '동물원료',
#  '동박소재',
#  '동백추출물',
#  '디메틸카보네이트',
#  '디메틸포름아미드',
#  '디부틸프탈레이트',
#  '디옥시리보핵산',
#  '디이소시아네이트',
#  '디젤원료',
#  '라디칼고분자',
#  '라세라타균주',
#  '라우릭산',
#  '라탄소재',
#  '락트산',
#  '레티놀결합단백질',
#  '렉틴단백질',
#  '리그닌',
#  '리보핵산',
#  '리튬화합물',
#  '마늘추출물',
#  '마약원료',
#  '마이크로겔',
#  '마이크로리보핵산',
#  '마이크로반',
#  '마이크로입자',
#  '마이크로칩',
#  '마이크로캐리어',
#  '마이크로캡슐',
#  '막단백질',
#  '말론산',
#  '망고스틴추출물',
#  '메셀로스',
#  '메신저리보핵산',
#  '메타물질',
#  '메타크릴레이트',
#  '메틸렌디',
#  '메틸셀룰로스',
#  '면역관문물질',
#  '면역단백질',
#  '면역단백질들',
#  '면역물질',
#  '면역소재',
#  '면역신호물질',
#  '면역조절물질',
#  '모노에틸렌글리콜',
#  '목화소재',
#  '몽당잎모자반추출물',
#  '무기나노소재',
#  '무기소재',
#  '무기화합물',
#  '무수프탈산',
#  '무스프탈산',
#  '무탄소',
#  '무형광물질',
#  '무효소',
#  '미강발효추출물',
#  '미래소재',
#  '미래혁신소재',
#  '미메틱펩타이드',
#  '미백글리시진산',
#  '미생물',
#  '미생물들',
#  '미생물발효액',
#  '미세물질',
#  '밀도폴리에틸렌',
#  '밀추출물',
#  '바닷말',
#  '바닷말추출물',
#  '바오밥나무씨추출물',
#  '바이닐플라스틱',
#  '바이러스억제물질',
#  '바이오 기반 나일론',
#  '바이오기능소재',
#  '바이오기반',
#  '바이오디젤',
#  '바이오매스',
#  '바이오물질',
#  '바이오석탄',
#  '바이오셀룰로오스',
#  '바이오소재',
#  '바이오수소',
#  '바이오식의약소재',
#  '바이오연료',
#  '바이오원료',
#  '바이오유산균',
#  '바이오유해물질',
#  '바이오의약소재',
#  '바이오폴리머',
#  '바이오폴리에스터',
#  ...]

# %%
con1 = sqlite3.connect('ensol_news_db.sqlite')
cur1 = con1.cursor()
cur1.execute("select * from mobility")
db_tab = pd.DataFrame(cur1.fetchall())
db_tab = db_tab.iloc[:,[1,2,4,5]].drop_duplicates(4) #여기에 wn

# %%
db_tab
# Out:
#                 1       2                                                  4  \
# 0      2021-07-16    서울경제  2년 넘게 벌여온 배터리 전쟁의 종지부를 찍은 LG와 SK가 이번엔 습식 분리막 시...
# 1      2021-07-16    서울경제  우리나라 경제 성장기에 수출 역군으로 활약했던 종합상사가 환골탈태에 나서고 있다. ...
# 2      2021-07-16    한국경제  정의선 현대자동차그룹 회장(사진)이 한 달 만에 다시 미국 출장에 나섰다. 미국 시...
# 3      2021-07-16    매일경제  세계 전기차 배터리 제조 업체들이 전기차용 배터리 주요 재료인 코발트 가격 상승에 ...
# 4      2021-07-16    한국경제  르노삼성자동차가 소형 스포츠유틸리티차량(SUV) XM3 2022년형에 탑재된 '인카...
# ...           ...     ...                                                ...
# 28496  2020-07-16    동아일보  “경찰 예산 삭감하라.” “정의 없이 평화도 없다.” \n \n 미국 독립기념일이던...
# 28497  2020-07-16    중앙일보  “내 절친이 신종 코로나바이러스 감염증(코로나19)으로 세상을 떠났다. 놀라고 슬프...
# 28498  2020-07-16  파이낸셜뉴스  21일께 현대차 남양연구소 방문 \n\n \n\n \n이재용 삼성전자 부회장이 다음...
# 28499  2020-07-16  파이낸셜뉴스  경북도, GS건설 등 55개 기업과 \n투자양해각서 작년比 22건 늘어 \n\n \...
# 28500  2020-07-16   헤럴드경제  [헤럴드경제=이진용 기자]와이앤지(대표 송호영)는 지난 4월 일본 최대 조명기기 전...
#
#                                                        5
# 0      viewer 신학철 LG화학 부회장이 14일 열린 온라인 기자 간담회에서 3대 신성...
# 1      < 저작권자 ⓒ 서울경제, 무단 전재 및 재배포 금지 >\n\n우리나라 경제 성장기...
# 2      귀국길 日들러 양궁대표팀 응원\n\n정의선 현대자동차그룹 회장(사진)이 한 달 만에...
# 3      \n\n\n\n세계 전기차·배터리 제조 업체들이 전기차용 배터리 주요 재료인 코발트...
# 4      전국 1000여개 CU편의점서 이용 가능\n\n르노삼성 "제휴 업체, 범위 늘릴 것...
# ...                                                  ...
# 28496  지난달 9일 미네소타주 미니애폴리스 시민들이 ‘경찰 예산을 삭감하라’라고 적힌 대형...
# 28497  친했던 여성 화가 코로나로 숨져\n\n노래에 그리움과 희망 담고 싶어\n\n참여한 ...
# 28498  21일께 현대차 남양연구소 방문\n\n\n\n이재용 삼성전자 부회장이 다음 주 현대...
# 28499  경북도, GS건설 등 55개 기업과\n\n투자양해각서… 작년比 22건 늘어\n\n\...
# 28500  스탠리전기서 개발 광학소재 탑재 자동차 헤드램프 상용화 예정\n\n와이앤지, 스탠리...
#
# [28168 rows x 4 columns]

# %%
def _call_db_info():
    return pymysql.connect(
        host = 'trend.cb7jqghocrtb.ap-northeast-2.rds.amazonaws.com',
        port= 3306,
        user = 'root',
        password='ensol2020!',
        db = 'trend',
        charset = 'utf8')


conn = _call_db_info()
curs = conn.cursor()
tmp_insert_sql = "select * from content where date >= 20210701"
curs.execute(tmp_insert_sql)        
tmp_rslt = pd.DataFrame(curs.fetchall())
conn.commit()
conn.close()

news_tab = tmp_rslt.iloc[:,1:].drop_duplicates()

# %%
# Train
#print(db_tab.shape, news_tab.shape)
#tmp_article= pd.concat((db_tab.iloc[:,3], news_tab.iloc[:,3]))
# Test
print(news_tab.shape)
tmp_article= news_tab.iloc[:,3]

tmp_article = tmp_article.drop_duplicates()
tmp_article = tmp_article.reset_index(drop=True)
print(tmp_article.shape)
# Out:
# (210, 4)
# (161,)

# %%
def extract_parenthese(str):
    items_lst = re.findall('\(([^)]+)', str) #extracts string in () 
    newList = [x for x in items_lst if len(x)>=2] # more than 2
    return newList

def extract_quotes(str):
    items_lst = re.findall('"([^"]*)"', str)
    return items_lst

def parentheses_(tmp_input_sent):    
    tmp_input_sent = re.sub(pattern='\(+', repl=' ', string=tmp_input_sent)#tmp_input_sent = re.sub(pattern='\(\(', repl='\(', string=tmp_input_sent)
    tmp_input_sent = re.sub(pattern='\)+', repl=' ', string=tmp_input_sent)#tmp_input_sent = re.sub(pattern='\)\)', repl='\)', string=tmp_input_sent)
    tmp_input_sent = re.sub(pattern=' +', repl=' ', string=tmp_input_sent)
    input_sent = re.sub(pattern='\\\\',   repl='', string=tmp_input_sent)
    return input_sent
    '''
    tmp_sent1, tmp_sent2 = [], []    
    s_re = re.compile('\(')#tmp_sentence[25])#.match('\(')
    e_re = re.compile('\)')
    s_m = [(m.start(0), m.end(0)) for m in s_re.finditer(input_sent)]#tmp_sentence[25])]
    e_m = [(m.start(0), m.end(0)) for m in e_re.finditer(input_sent)]#tmp_sentence[25])]
    m = []
    for i in range(0, len(s_m)):
        if s_m[i][1] < e_m[i][0]:
            m.append((s_m[i], e_m[i]))
        else:
            for j in range(i+1, len(e_m)):
                if s_m[i][1] < e_m[j][0]:
                    m.append((s_m[i], e_m[j]))
                    break;                   

    if len(m) > 0:
        for i in range(0, len(m)):
            if i == 0:
                tmp_sent1.append(input_sent[:m[i][0][0]])
            else :
                tmp_sent1.append(input_sent[m[(i-1)][1][1]:m[i][0][0]])                        
            tmp_sent2.append(input_sent[m[i][0][1]:m[i][1][0]])
        tmp_sent1.append(input_sent[m[-1][1][1]:])    
        return ' '.join(tmp_sent1 + tmp_sent2)
    else:
        return input_sent
    '''
    
def pos_select(input_sent, p_set):
    tmp_ = []
    tmp_s_pt = []
    for i,x in enumerate(p_set):
        try :            
            #tmp_s_pt.append(input_sent.index(x))
            tmp_.append([i, input_sent.index(x), len(p_set[i]), 0 if p_set[i].find(' ')== -1 else 1])            
        except:
            pass        
    return tmp_#, tmp_s_pt

# %%
step0_ptn= '[\'\‘\’]'
step1_ptn= '[\u00a0\u3000①②③④⑤⑥⑦⑧⑨⑩』◦※→®↑↓‣★▶■△◇◆▲○●\{\}\[\]\/?,+;:‧·ᆞ…》ⓒ|*~`\""“”!^_<>@\#&\\\=\'\n]'     
step2_ptn= '[\.]' 
article_sent = []

article_ner_l1, article_ner_l2 = [], []

for a in range(0, tmp_article.shape[0]):
    tmp_a = re.sub(pattern=step0_ptn, repl='\"', string=tmp_article.iloc[a])#.replace('\'‘’', '\"')
    tmp_a = re.sub(pattern=step1_ptn, repl='', string=tmp_a)
    tmp_sentence = kss.split_sentences(tmp_a)
    tmp_sentence = [re.sub(pattern=step2_ptn, repl='', string=s) for s in tmp_sentence]
    tmp_sentence = [parentheses_(s) for s in tmp_sentence] 

    ner_sent, ner_tag_l1, ner_tag_l2 = [], [], []

    for sent in range(0, len(tmp_sentence)):
        
        tmp_ner = []
        tmp_sent = re.sub(pattern=' +', repl=' ', string=tmp_sentence[sent])
        sent_split = tmp_sent.split(' ')
        tmp_ner_l1 = ['O'] * len(sent_split)
        tmp_ner_l2 = ['O'] * len(sent_split)
        
        if len(pos_select(tmp_sent, pos_set)) == 0:
            #print(a, sent)
            break
        tmp_pos_info = pd.DataFrame(pos_select(tmp_sent, pos_set)).sort_values(by=1).reset_index(drop=True)        

        for i in range(0, tmp_pos_info.shape[0]):
            if tmp_pos_info[3].loc[i] == 0:        
                tmp_ner_pos = len(tmp_sent[:tmp_pos_info[1].loc[i] + tmp_pos_info[2].loc[i] ].split())-1
                tmp_ner_l1[tmp_ner_pos] = ref_dic['대분류'].loc[tmp_pos_info[0].loc[i]]
            else:
                tmp_ner_pos1 = len(tmp_sent[:tmp_pos_info[1].loc[i]]) 
                tmp_ner_pos2 = len(tmp_sent[:tmp_pos_info[1].loc[i] + tmp_pos_info[2].loc[i] ].split())
                for p in range(tmp_ner_pos1, tmp_ner_pos2):
                    tmp_ner_l1[p] = ref_dic['대분류'].loc[tmp_pos_info[0].loc[i]]
                    tmp_ner_l2[p] = ref_dic['중분류'].loc[tmp_pos_info[0].loc[i]]
        ner_sent.append((' ').join(sent_split))
        ner_tag_l1.append((' ').join(tmp_ner_l1))
        ner_tag_l2.append((' ').join(tmp_ner_l2))
    article_sent.extend(ner_sent)
    article_ner_l1.extend(ner_tag_l1)
    article_ner_l2.extend(ner_tag_l2)

# %% [raw]
# step0_ptn= '[\'\‘\’]'
# step1_ptn= '[\u00a0\u3000①②③④⑤⑥⑦⑧⑨⑩』◦※→®↑↓‣★▶■△◇◆▲○●\{\}\[\]\/?,+;:‧·ᆞ…》ⓒ|*~`\""“”!^_<>@\#&\\\=\'\n]'
# step2_ptn= '[\.]'
# article_sent = []
# article_ner_l1, article_ner_l2 = [], []
#
# for a in range(0, tmp_article.shape[0]):
#     tmp_a = re.sub(pattern=step0_ptn, repl='\"', string=tmp_article.iloc[a])#.replace('\'‘’', '\"')
#     tmp_a = re.sub(pattern=step1_ptn, repl='', string=tmp_a)
#     tmp_sentence = kss.split_sentences(tmp_a)
#     tmp_sentence = [re.sub(pattern=step2_ptn, repl='', string=s) for s in tmp_sentence]
#     tmp_sentence = [parentheses_(s) for s in tmp_sentence]
#
#     ner_sent, ner_tag_l1, ner_tag_l2 = [], [], []
#     pos_set = ref_dic['명칭'].values.tolist()
#
#     for sent in range(0, len(tmp_sentence)):
#         tmp_ner = []
#         tmp_sent = re.sub(pattern=' +', repl=' ', string=tmp_sentence[sent])
#         sent_split = tmp_sent.split(' ')
#         tmp_sent_n, tmp_sent_a = divmod(len(sent_split), 30)
#         tmp_mecab_pos = [mecab.pos(w) for w in sent_split]
#         #tmp_ner = tmp_ner = [t for t in tmp_ner.split(' ') if len(t) >0]#tmp_ner.split(' ')
#         tmp_ner_l1 = ['O'] * len(sent_split)#len(tmp_ner)
#         tmp_ner_l2 = ['O'] * len(sent_split)#len(tmp_ner)
#
#         for k in range(0 ,len(sent_split)):
#             m_pos = [i for i, tmp_me in enumerate(tmp_mecab_pos[k]) if tmp_me[1] in ['NNP','NNG','SL']]
#             if len(m_pos) > 0:
#                 for l in range(0, len(m_pos)):#tmp_mecab_pos[4][m_pos[0]][0]
#                     if tmp_mecab_pos[k][m_pos[l]][0] in pos_set:
#                         ner_ind = pos_set.index(tmp_mecab_pos[k][m_pos[l]][0])
#                         tmp_ner_l1[k] = ref_dic['대분류'].loc[ner_ind]
#                         tmp_ner_l2[k] = ref_dic['중분류'].loc[ner_ind]
#         ner_sent.append((' ').join(sent_split))
#         ner_tag_l1.append((' ').join(tmp_ner_l1))
#         ner_tag_l2.append((' ').join(tmp_ner_l2))
#     article_sent.extend(ner_sent)
#     article_ner_l1.extend(ner_tag_l1)
#     article_ner_l2.extend(ner_tag_l2)

# %%
label_ner_l1_ = [x for a_ner in article_ner_l1 for x in a_ner.split(' ') if x != 'O' and len(x) > 0 ]
label_ner_l2_ = [x for a_ner in article_ner_l2 for x in a_ner.split(' ') if x != 'O' and len(x) > 0]
tmp_label_ner_l1 = list(set(label_ner_l1_))
tmp_label_ner_l2 = list(set(label_ner_l2_))
tmp_label_ner_l1.sort()
tmp_label_ner_l2.sort()

# %%
label_ner_l1 = ['UNK']# + tmp_label_ner_l1
label_ner_l2 = ['UNK']# + tmp_label_ner_l2
for i in tmp_label_ner_l1:
    label_ner_l1.extend([i+'-B', i+'-I'])
for i in tmp_label_ner_l2:
    label_ner_l2.extend([i+'-B', i+'-I'])

# %%
article_ner_l1
# Out:
# ['O O O O 제품 O O O O 이벤트 O O O O O O 스펙 스펙 O O 제품 O O O O 기술 이벤트 이벤트',
#  'O 이벤트 O 제품 O O O O O 제품 O 기술 이벤트 O O O O O O O O O O O O 이벤트 O 이벤트 O O O',
#  'O 스펙 제품 O 제품 O O O 제품 O O O 제품 이벤트 O O O 기술 O O O O 기술 O O O O O O O 이벤트',
#  '제품 이벤트 O O O O O O O O O O 제품 O O O O 트렌드 O O O O O O O O O 이벤트 O O O O O O O O O O O O 제품 이벤트 O O O O O O O O 제품 스펙 기술 스펙 O O O O O O O O 기술 이벤트 O O 서비스 O O O 스펙 O',
#  'O 제품 O O O 이벤트 O O 기술 이벤트 O O O 스펙 기술 서비스 스펙 O O O',
#  'O O O 제품 O 이벤트 O O O O O 제품 O O O O O O O O 이벤트',
#  'O O O O O O O O 스펙 이벤트 O O O O O O O O O O O O O O',
#  'O O 제품 O 트렌드 O 이벤트 제품 제품 O O 스펙 O O O O 이벤트 O O O O',
#  'O O 소재 O O 사건/사고 제품 O O O O 제품 제품 O O O O O 스펙 O',
#  'O O O O O O O O O O O 제품 O O O O O O O 스펙 O O O',
#  'O O 이벤트 O O 제품 O O 제품 스펙 O 스펙 제품 O O O O O 스펙 이벤트 O O 트렌드 O 이벤트',
#  'O O O O O O O O O O O O O 스펙 O 소재 이벤트 O 이벤트',
#  'O O O O O O O O O 트렌드 O O O O O',
#  'O O O 제품 O O 스펙 O O 기술 이벤트 O O O',
#  'O O 제품 O 스펙 제품 제품 O O 서비스 O O O O O O 트렌드 O O 이벤트',
#  '제품 이벤트 O O O O O O O O O O O O O O O 스펙 O O O O O O O O O O O O O O 기술 O O O O O',
#  'O O 제품 O O 스펙 이벤트 O O 스펙 O',
#  'O O O O O O O O O 이벤트 제품 O 이벤트',
#  'O O O O O 제품 O 기술 기술 O O O 스펙 O O O',
#  'O O O 기술 O O O O O O O 스펙 스펙 이벤트 O O O 스펙 O 이벤트',
#  'O O O O 제품 O 스펙 스펙 O O O O O O O O 기술 O O O O O 스펙',
#  '스펙 O O O O O O O O O O O O O O O',
#  'O O 기술 O O O O O O O O O O O O',
#  'O O O O 스펙 O O O O O O 제품 O O O O O',
#  'O O O O 기술 이벤트 O O O O 이벤트 O',
#  '기술 제품 제품 트렌드 제품 O O O 기술 O O',
#  'O O O O O 스펙 O O 트렌드 O O O O 스펙 소재 이벤트 O O O O O O O O O O 제품 O O O O O O O O',
#  'O O O O O 서비스 O 이벤트 O O 소재 O O O O O O O O',
#  'O O O O O O O O O O O O O 이벤트 O O O 트렌드 O O O 기술 이벤트 O O O O O O O O O O',
#  'O O O O O 기술 O O O O 스펙 이벤트 이벤트 O O 이벤트 O O 이벤트 O 스펙 O O O O O 트렌드 O O 제품 O O O 이벤트 O O O O O 이벤트 O O O O O O',
#  'O O O O 이벤트 O O O O O O O O O O 소재 O O O O O O O O 이벤트 O O',
#  'O O 이벤트 스펙 O O O 트렌드 트렌드 O O O O O O O O O O O O O 스펙 이벤트 이벤트 이벤트',
#  'O O O 이벤트 O O 이벤트 O O 제품 O 소재 제품 스펙 O O 소재 O O O O O O O O 트렌드 스펙 O O 트렌드 이벤트 O O O O O O O O 이벤트 O O O O',
#  'O O 제품 이벤트 O O O O O 이벤트',
#  'O O O 이벤트 O O O O O 서비스 O O O O O O O 이벤트 O O O O O',
#  'O O 제품 O O O O O O O O O O O',
#  'O O 제품 O O 이벤트 O O O O O O O O O O O O O O O',
#  'O O O 이벤트 O 이벤트 O O O O O O',
#  'O 제품 O O O O O O 이벤트 O O O O O',
#  'O O 이벤트 이벤트 O O O O 스펙 O',
#  'O O O O O O O 스펙 O O O O O 제품 O O O O O O O O O O O 제품 사건/사고 O O O 트렌드 O O O O',
#  'O O 이벤트 O O',
#  'O O O O O O O O O O O O O O 기술 O O 이벤트 이벤트 O O O O O O O O O O',
#  'O O 제품 O O O 소재 O O 이벤트 이벤트 O O O O O 이벤트 O O O O 제품 O O 이벤트 O O O O O O O O O O O O O O O O',
#  'O O O O O O 소재 O 기술 O O O O O O O O O O O 스펙 O O O O O',
#  '제품 O 기술 O O O O O O O O O O 서비스 이벤트 기술 O 스펙 소재 O O O 이벤트 O 이벤트 이벤트 O O',
#  'O O 이벤트 소재 O 이벤트 소재 O O O O O O',
#  'O O O 이벤트 O O O 이벤트 O O O O O O O 제품 스펙 O O O O 기술 O O O O O',
#  'O O 제품 O 스펙 제품 O O O O 제품 O 제품 이벤트 O 이벤트 O O O O O 이벤트 O O O',
#  '제품 O 이벤트 O O O O O O O O O O O O 서비스 O O',
#  'O O O O 이벤트 O O O 트렌드 O O O O O O O O O O O O O O O O O O O 트렌드 O 이벤트 O O O O',
#  'O O O O O O O O O 소재 O O O O O 이벤트 O',
#  'O O O O O O O 스펙 O O O O O O 이벤트 O',
#  'O O O O 제품 O O O O O 트렌드 스펙 O O O 사건/사고 O O O O O 사건/사고 O 이벤트 제품 O O O O',
#  'O O O O O 이벤트 기술 O O O O O O O O O O O O O O O 스펙 O O O O 트렌드 이벤트 O O 이벤트 O 이벤트 O O O',
#  'O O O O O 기술 O O O O O 이벤트 O O O O O O O O O O O',
#  'O O 소재 O O O O 이벤트 O O O 이벤트 O O 이벤트 O O 이벤트 O',
#  'O O O 소재 O O 이벤트 O O O O O 사건/사고 O 소재 이벤트 O O O 스펙 기술 이벤트 O 트렌드 트렌드 O O O 스펙 O 이벤트 O 이벤트',
#  'O 소재 O O 서비스 O O 서비스 O O 트렌드 트렌드 소재 O 이벤트 트렌드 소재 O 제품 O 서비스 O 이벤트 O 이벤트 O',
#  'O O O 트렌드 O O O O O O O 이벤트 O O',
#  'O 이벤트 O O O O O O 트렌드 이벤트 O O O O O O O O O 이벤트 O O O 이벤트 O',
#  'O O O O O O O 이벤트 O O O O O 소재 이벤트 O O O 이벤트 O O 이벤트 O O 사건/사고 O 스펙 O O 이벤트 O 이벤트 O O O O O O O O O O 이벤트 O O O O O O O O 이벤트 O O O',
#  'O O O 소재 사건/사고 스펙 O 스펙 트렌드 이벤트 스펙 O O 이벤트 O',
#  'O O 트렌드 O 이벤트 소재 이벤트 O O O O O 사건/사고 기술 이벤트 O 스펙 O O',
#  'O O O O O 이벤트 스펙 스펙 O O 트렌드 사건/사고 이벤트 O O O 사건/사고 O O O O O O O O O O O O O',
#  'O O O 이벤트 O O O O 이벤트 O 이벤트',
#  'O O O 사건/사고 O O 이벤트 O O O O O 이벤트 서비스 O O O O O O O O O O O O O O',
#  'O O O 이벤트 이벤트 O 이벤트 O O O 이벤트 제품 O O O O O O O 서비스 O O O O',
#  'O O 이벤트 O O O 이벤트 O 이벤트 O 이벤트 스펙 O O O 이벤트 이벤트 O O O',
#  'O O O O O O O 서비스 O O O O O O O',
#  'O O O O O 스펙 O O O O O O O O',
#  'O 이벤트 O O O O O 이벤트 O O O 이벤트 스펙 이벤트 이벤트 O O O 트렌드 이벤트 O O O O O O 이벤트 O O O O O O O 스펙 이벤트 O O O O O O O O O O O O O O O',
#  'O O O O 소재 이벤트 O O O O O O O O O O O O O 이벤트 O O O 이벤트 O O O 스펙 O O 제품 소재 O O 이벤트 O O O',
#  'O O O 스펙 제품 O 이벤트 O O O O O O O 소재 O O O O O O O O O O O O',
#  'O O O 이벤트 스펙 O O O O 기술 O 이벤트 이벤트 O O O O O 이벤트 O O O O O O O O O O 이벤트 O O O O 이벤트 O O O O O O 이벤트 O O O O O O O O O O O O',
#  'O O O O O O O 서비스 O 제품 O O O O O O O O 스펙 O 이벤트',
#  'O O O O O 이벤트 O O O O O O O O O O O 이벤트 O O 서비스 O O O O O O O O O O O O O O 스펙 O O O 제품 이벤트 O O O O O O O 트렌드 O 사건/사고 제품 O 스펙 O O O O O O O O O O O O O O O O O O 스펙 O O 이벤트 O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O 이벤트 O O O O O O O O O',
#  'O O O O 제품 O O O O 스펙 O 이벤트 O O',
#  'O O O 제품 O O O O O O O O O O O O',
#  'O 트렌드 이벤트 O O O',
#  '기술 O O O O O O O 이벤트 O O O O 이벤트 O O',
#  'O 트렌드 O O O O O O',
#  'O O 트렌드 O 이벤트 O 이벤트 O O O O O O',
#  '트렌드 이벤트 O O 기술 이벤트 O O 이벤트 O',
#  'O O O 트렌드 트렌드 O 트렌드 기술 이벤트 O 이벤트 이벤트',
#  '이벤트 이벤트 이벤트 O O',
#  '트렌드 O O 이벤트 O O 이벤트 O',
#  'O O 제품 O 이벤트 O 이벤트 O',
#  'O O O O O 이벤트 O O O O 이벤트 스펙 기술 이벤트 O 트렌드 이벤트 이벤트 O O O',
#  'O 이벤트 O O O O O O O O O 기술 기술 이벤트 O O O O',
#  'O O O O O 기술 O 이벤트 O',
#  'O O O O O O O O 스펙 O O O 트렌드 O O O O 소재 O 이벤트 O 트렌드 소재 O O 트렌드 O O O O O O O 이벤트 O O O O 소재 O O',
#  'O O O 트렌드 소재 O O',
#  'O O O 스펙 트렌드 트렌드 트렌드 O 기술 이벤트 O O',
#  'O 트렌드 O O 트렌드 O 소재 O O O O O O O 기술 O 기술 기술 트렌드 O O O O O O O O O O O O',
#  'O O 트렌드 O O 이벤트 O 트렌드 이벤트 O',
#  'O 이벤트 이벤트 O O O O O O O O O O O O O O O 트렌드 이벤트 O O O',
#  '제품 이벤트 O O 서비스 제품 O 이벤트 O O',
#  'O O O O 스펙 O O O O O 이벤트 이벤트 O',
#  'O O 트렌드 O 이벤트',
#  'O O O 제품 이벤트 O O',
#  'O O O O O O O O O O 이벤트 O 이벤트 이벤트',
#  'O O O O O 서비스 O O O O O 이벤트 O',
#  'O 소재 제품 O 기술 O O O O 제품 스펙 O O 이벤트 O O O 이벤트 O O O O 이벤트 이벤트 O O',
#  '소재 제품 O O O O O O O O O O O O O O 이벤트 O',
#  'O 제품 제품 O O O O O O 스펙 O O O O O O O O O O O O O O O O O O O',
#  'O O O O O 제품 O O O 제품 O O 이벤트 O O O O 스펙 이벤트 O O 이벤트 O O O O O O O O O O O O O O',
#  'O O 제품 O 소재 소재 소재 O O O 이벤트 O O O O O O O 제품 O O O O O O O O O',
#  '소재 O O O 이벤트 O O O O O 이벤트 이벤트 O 제품 O O O O',
#  'O O O 제품 스펙 O 제품 서비스 O O O O O 스펙 소재 이벤트 O O O O',
#  'O O 이벤트 이벤트 이벤트 O O O 이벤트 O 이벤트 O 제품 O O O 서비스 O 스펙 이벤트 O O 이벤트 O O',
#  'O O O O 이벤트 O O O',
#  'O O O 이벤트 이벤트 이벤트 O O 이벤트 스펙 소재 제품 O 기술 O O O O O 제품 스펙 O O O 이벤트 O O O 이벤트 O O O 이벤트 O O O O',
#  'O O O O O O 이벤트 O O 서비스 O O',
#  '트렌드 제품 이벤트 O 기술 스펙 이벤트 O O O 서비스 O O O',
#  '소재 제품 제품 O O O O O O O O O O O O O O O O O O O O O O 스펙 O 제품 서비스 O O O O O 스펙 O 이벤트 O O O O',
#  'O O 이벤트 이벤트 이벤트 O O O 이벤트 O 이벤트 O',
#  'O O 제품 O 제품 O O O 서비스 O 스펙 이벤트 O O 이벤트 O O',
#  'O O O 이벤트 스펙 O 서비스 스펙 O O O O O 스펙 이벤트 O O 이벤트 O O O O',
#  '스펙 서비스 서비스 이벤트 O O',
#  'O O O 이벤트 기술 사건/사고 O O',
#  'O O 스펙 O O 이벤트 O O',
#  'O O O 이벤트 O O O 사건/사고 O',
#  '트렌드 O O O 서비스 서비스 이벤트 O 기술 스펙 O 이벤트 O',
#  'O O 이벤트 O O O O 사건/사고',
#  'O O O 이벤트 O O O',
#  'O 서비스 O 이벤트 O O O O O O O 이벤트 O O O O O O O O 이벤트 사건/사고 O',
#  '서비스 O 이벤트 O O 스펙 O O O O O O O O',
#  '서비스 O O O O 스펙 O O O O O 스펙 O 서비스 O 스펙 이벤트 O',
#  '제품 서비스 O 기술 O 서비스 O O',
#  '서비스 제품 사건/사고 O O O 스펙 기술 O O 사건/사고 O',
#  'O 서비스 제품 O O O O O 스펙 서비스 O',
#  '서비스 이벤트 O O O 스펙 O',
#  '스펙 스펙 O O 제품 O 스펙',
#  '스펙 스펙 스펙 스펙 O',
#  '스펙 O 스펙 이벤트',
#  'O O O O O O O O O 이벤트 O O 이벤트 O O O 이벤트 O O O',
#  'O O O O O O O O O 이벤트 O O 이벤트 O O O',
#  'O 이벤트 O O O O O O O O O O O O',
#  'O O O 소재 O O',
#  'O O O O 소재 O O O',
#  'O 스펙 O O O O O O O O O O O 이벤트 O O O 이벤트 O O',
#  'O O O 이벤트 O O O O O O O O O O O O O O O O 이벤트 O O 이벤트 O O 소재 O O O O O O O O O O O O O O O O 소재 O O O O O O O',
#  'O O O 소재 O O O O O 스펙 O O',
#  'O O 트렌드 O O O 트렌드 O O',
#  'O O O O O O O O 이벤트 O O O O',
#  'O O O 이벤트 O O O O O',
#  'O 스펙 O O O O O O O O O 이벤트',
#  'O O O O O O 이벤트 O',
#  'O O O 사건/사고 트렌드 O O O O O O O 제품 O O O O O O O 소재 O',
#  'O O 제품 O O O O',
#  'O O O O O 스펙 O O 이벤트 O',
#  'O O O O 제품 O O O O O O O O O O O O O O',
#  '스펙 O O O O O 이벤트 O',
#  '기술 O O O O O O O O O O O O O O O O O O O',
#  '제품 O O O O 이벤트 O O',
#  'O O 사건/사고 스펙 제품 O O O O O O O 제품 O O O O O O O',
#  'O O O O O O O 기술 스펙 O O O O O O',
#  'O 스펙 O 제품 제품 이벤트 O O O O O 서비스 O O O O',
#  'O O O 스펙 제품 제품 O 이벤트',
#  '스펙 제품 제품 스펙 이벤트 O O O O O O O',
#  'O O 제품 스펙 O O O O',
#  '제품 O O O O O O O O O O O O O O',
#  'O 기술 이벤트 스펙 O O 제품 제품 이벤트',
#  'O O O 이벤트 O O O O O O O O O O O',
#  '제품 O 제품 O 제품 O O O 스펙 O O',
#  'O O O 서비스 스펙 O O O',
#  'O 제품 O O O O O O O O',
#  '스펙 기술 O O O O O 서비스 스펙 O 이벤트 O O O',
#  'O O 이벤트 O O O 서비스 O O',
#  'O O 이벤트 O O O O 제품 O O 이벤트 O O O',
#  'O O 제품 이벤트 O O 이벤트 O O 트렌드 O O O O 이벤트 O O O O',
#  'O O O O O 스펙 O O 제품 O O O O 기술 서비스 기술 이벤트 O O O O O O O 서비스 기술 O O O O O O 이벤트 O O O O O O O O O 이벤트 O O',
#  'O O O O O 이벤트 O O O O O O O',
#  'O 제품 제품 O O O O O O O O 이벤트 O O O',
#  'O O O O O 트렌드 O O O O O O 이벤트 제품 O 스펙 O 스펙 O O 제품 O O O O O O O O O O 이벤트 O O',
#  '제품 O O O 이벤트 기술 O 이벤트 O 이벤트 O O 이벤트 O O',
#  '제품 O O 트렌드 O O O O O O O 스펙 O O O 이벤트',
#  'O O 기술 이벤트 스펙 O O O 제품 O O 이벤트 O',
#  'O 이벤트 O O O O O 이벤트 O O 스펙 O O 트렌드 O O O 스펙 O 사건/사고 O O O',
#  'O 스펙 스펙 O 이벤트 O 제품 O O',
#  '제품 이벤트 O',
#  'O O O 이벤트 O O 제품 O 스펙 O O O',
#  'O O O O O O O O 스펙 O O O O O O O O 이벤트 O 제품 이벤트 O',
#  'O 제품 이벤트 O O O O O 이벤트 이벤트 이벤트 이벤트 이벤트 O O',
#  'O O 스펙 O 서비스 O O 스펙 O O O O O O O 이벤트',
#  'O O O 스펙 O 이벤트 O O O O 스펙 O O O O 이벤트 O O O O O O O O O O 이벤트 O O O O O O O 트렌드 O O O 이벤트',
#  'O O O O O 이벤트 O 이벤트 이벤트 O O O O O O O O O 이벤트 이벤트',
#  'O O O O O O O 이벤트 서비스 이벤트 O O 스펙 제품 O O O O O O O',
#  'O O O 이벤트 O O O O O O O 이벤트 이벤트 O O O O 이벤트 O 이벤트 이벤트 O 이벤트 O O 이벤트 O 이벤트 O',
#  'O O O O O O O O O O 이벤트 O O',
#  'O O O 이벤트 O O O O O O O O O 이벤트',
#  'O O O O O O 이벤트 O O O 이벤트 O 서비스 O 스펙 O 이벤트 O 이벤트 O O O O 이벤트 O 이벤트',
#  'O O 트렌드 스펙 O O O O O O O O O O O',
#  'O O O O O O 이벤트 O O O O 이벤트 O O O O O',
#  '제품 기술 O O O O O O 이벤트 O',
#  'O 기술 O 사건/사고 이벤트 O O O O O O O O O 사건/사고 사건/사고 O O O 기술 O O 기술 O 기술 O O O O 기술 O O O O 트렌드 O O O O O O O O',
#  '이벤트 O O O O O O O 스펙 이벤트 O O O 사건/사고 기술 이벤트 사건/사고 O O O O O O O',
#  '이벤트 O O O O O O O O O O O O O O 이벤트 O 스펙 O O O',
#  'O O O 기술 O O O O O O O O O O 기술 O 제품 O 기술 O O 제품 O O O O O 사건/사고 O 이벤트 O O O',
#  'O O O O 스펙 O O O',
#  'O O O O O O O 이벤트 O O O O O 소재 트렌드 이벤트 O O O O 제품 O 서비스 O O 제품 O O O O O O 트렌드 O 스펙 O O O O 제품 O O 트렌드 제품 소재 O O 서비스 O 이벤트 O O 트렌드 이벤트 O O O O O O O O O O O O O O 소재 O O 제품 O 이벤트 이벤트 이벤트 O O O 기술 사건/사고 O O O O O O 제품 O O 이벤트 이벤트 O O O 이벤트 O O O O O 서비스 O O O O O 이벤트 O O O O O O O 서비스 O O O O O 이벤트 O O O O O O O 사건/사고 이벤트 O O 트렌드 O 소재 O O O 이벤트 O 이벤트 O O O O O O O O O O O O O O O O O O O 제품 O 사건/사고 O 제품 이벤트 O O O O 소재 이벤트 O O O',
#  'O O O 제품 O O O O 이벤트 O 제품 O O 소재 O 기술 O O 사건/사고 O 트렌드 O 스펙 제품 O O O 이벤트 O O O O 제품 O O O O',
#  'O O O O 이벤트 O O O 제품 O O O O 이벤트 O O O O O O 이벤트 O O O O O O O O O O O O 이벤트 O O 소재 O O O O 이벤트 O O O O 스펙 이벤트 O 이벤트 제품 O O 트렌드 O 이벤트 O 소재 O O O 이벤트 트렌드 O O O O O 트렌드 O O O O O O O 기술 O 이벤트 O 이벤트 O O O 서비스 이벤트 이벤트 이벤트 O O O O O O O O O O O O O 제품 이벤트 O 이벤트 O O O 이벤트 O O O O 이벤트 O O O O 소재 이벤트 이벤트 O O 사건/사고 O O 기술 이벤트 이벤트 이벤트 이벤트 O O O O O O O O O O 이벤트 O 트렌드 O O 사건/사고 O O O O O O O O O O 스펙 O O O O O O 이벤트 O O O O 제품 소재 소재 O 이벤트 제품 O O O O O O O O O O O O O O O O 이벤트 O O 이벤트 O 이벤트 이벤트 O O O O 사건/사고 O O O O 이벤트 O 제품 이벤트 O O O 이벤트 제품 기술 O O',
#  'O O O O O O 트렌드 사건/사고 O 소재 O O 이벤트 이벤트 O O O 스펙 O 트렌드 O O O O O O O 소재 O O',
#  '제품 O O 제품 O O O O 제품 O O O 이벤트 O O O 이벤트 스펙 O 이벤트 트렌드 이벤트 O O O O O O',
#  '트렌드 O 이벤트 트렌드 O O O O O O O O O O O O O O O O O O O O O O O O O 소재 이벤트 O O O O 제품 이벤트 제품 이벤트 이벤트 이벤트 O O O O 기술 O 이벤트 O O 이벤트 O O O 기술 O 이벤트 O O O O O O O 이벤트 O 기술 O O O O O O 이벤트 O 이벤트 이벤트 O O 이벤트 O 이벤트 O O O O O O O O O O O 이벤트 O O O 제품 O O O O O O 트렌드 O O O O O O 트렌드 O O O 트렌드 O O 스펙 제품 이벤트 O O 소재 O 스펙 O 소재 O 사건/사고 O O',
#  '이벤트 O 스펙 O O O O O 이벤트 제품 O 제품 O O O 사건/사고 O O O O O O O O O O O O O 이벤트 O O 트렌드 스펙 이벤트 이벤트 O O 제품 O O O O 기술 이벤트 O O',
#  'O O O O 이벤트 O O 이벤트 O 이벤트 O O O 사건/사고 O 트렌드 O O',
#  'O O 기술 O O 소재 O O O O O O O 제품 사건/사고 사건/사고 O O O 제품 O 제품 O O 스펙 O O O O 이벤트 O O 이벤트 O O O 이벤트 O O O O O O',
#  'O O O O O O 이벤트 이벤트 O O O O O O O 이벤트 O O O O O O O 이벤트 O',
#  '이벤트 O O O 제품 서비스 O 이벤트 O O O O O 트렌드 O O O O O O O O O 스펙 이벤트 O O O O O O O O 이벤트 O O O 서비스 O O 사건/사고 이벤트 O 사건/사고 O O O O O 소재 O O O 이벤트 O O 트렌드 제품 O O 이벤트 O O 이벤트 스펙 O O O',
#  'O 사건/사고 O O O 사건/사고 이벤트 사건/사고 제품 O O O O O 트렌드 O O 이벤트 O O O O 사건/사고 O O O O 제품 O O O O O O O 제품 O O 트렌드 O 소재 O O 이벤트 O O 이벤트 O O O O O 스펙 제품 이벤트 O O O O O O 이벤트 이벤트 O O O O O 트렌드 이벤트 O O O 트렌드 O O O O O',
#  'O O 트렌드 O 이벤트 이벤트 O 제품 O O 제품 O 이벤트 스펙 O O O O O 이벤트 O O 제품 O O O 이벤트 O 트렌드 O O O O O 이벤트 O O 이벤트 O O O O O 소재 O O O O O O 트렌드 이벤트 이벤트 O O O O O O 트렌드 사건/사고 이벤트 O 제품 O O 이벤트 O O O 이벤트 O O O O 제품 O 이벤트 O O O O 트렌드 제품 O O 이벤트 O O O O O O O O O 스펙 O O O O 제품 이벤트 O O O 이벤트 O O 기술 소재 O O 이벤트 O',
#  'O O O O O O O O 이벤트 O 트렌드 O O O 스펙 O O 이벤트 서비스 스펙 O O O O O 이벤트 이벤트 O 트렌드 O O 소재 이벤트 O 이벤트 O O O O O 이벤트 O 이벤트 트렌드 O O O O O O O 트렌드 이벤트 이벤트 기술 O O O O O O 트렌드 이벤트 O O O O O 이벤트 O O O 이벤트 O O O O 제품 제품 O 이벤트 O 이벤트 O 소재 O O O O 제품 제품 O O O O O O O O O O O 스펙 이벤트 O 트렌드 O O O O 이벤트 O O O O O 이벤트 사건/사고 O O 이벤트 O O O O 스펙 O O O O O O 사건/사고 O O O 이벤트 O O 이벤트 O 사건/사고 사건/사고 O 소재 제품 이벤트 O O O 이벤트 O',
#  'O 제품 O O O 이벤트 이벤트 O O O O O O O O O 이벤트 이벤트 사건/사고 O 이벤트 O O O O 트렌드 이벤트 O O O O 제품 O O O O O O O O O 이벤트 트렌드 O O O 이벤트 O O O O',
#  '기술 O O O O O O O O 이벤트 O O O 소재 이벤트 이벤트 O O 트렌드 O O O 트렌드 이벤트 스펙 O O 제품 O 이벤트 O O O O O 기술 O O 이벤트 이벤트 제품 O O O O O O O O',
#  'O O O 이벤트 제품 이벤트 O O O 서비스 O O O 소재 O 이벤트 사건/사고 O 이벤트 O O 스펙 O O 기술 트렌드 O O O',
#  '사건/사고 O 이벤트 O O O 이벤트 이벤트 스펙 O O O O O 사건/사고 O O O O 스펙 O O O O O O O 트렌드 제품 소재 소재 O O O O O 기술 O O 소재 O O 기술 O O 소재 제품 이벤트 O 이벤트 제품 O O O O O O O 이벤트 O O O O 이벤트 O 사건/사고 트렌드 O O O O O O O O O',
#  'O O O O O 이벤트 서비스 O 제품 O O O O O O 이벤트 이벤트 O O O',
#  'O 제품 O O O O O O O O O O O O 이벤트 O 이벤트 이벤트 O 기술 기술 이벤트 O O O O 이벤트 O',
#  'O O O O O 이벤트 O O O O O O O O O O O O O O O 기술 이벤트 O 이벤트 O O O',
#  'O O 제품 O 기술 스펙 트렌드 소재 O O 기술 O O 기술 소재 O 기술 스펙 O 소재 O 스펙 제품 이벤트 제품 O 스펙 O O O O O O 기술 O O O O O O O 이벤트 이벤트 O',
#  '이벤트 O 트렌드 이벤트 O O O O O 이벤트 O O O O O O 제품 이벤트 O 스펙 O O O',
#  'O O O O O O O O O O 이벤트',
#  'O O O 이벤트 O 이벤트 이벤트 이벤트 O O 제품 O 이벤트 O O O',
#  'O O O O 제품 O O O O O O O O O O O O O O O 이벤트 O O O O O 이벤트 O O 이벤트 O',
#  'O O O O O 이벤트 O O 기술 이벤트 O 사건/사고 O',
#  '이벤트 이벤트 이벤트 이벤트 제품 O O 사건/사고 O 사건/사고 O O',
#  'O O O O O O O O O 기술 이벤트 이벤트 제품 O O O O 기술 이벤트 O O 사건/사고 O 이벤트 O O',
#  'O 기술 이벤트 O 기술 이벤트 O O O 사건/사고 O O 트렌드 O O O O O O O',
#  '기술 O O 이벤트 O O O 제품 제품 소재 이벤트',
#  '제품 O 기술 서비스 O O O O O 기술 O O',
#  '기술 제품 기술 O O O O O O O O',
#  'O O O O 제품 O 기술 이벤트 O O O O O 제품 기술 O 스펙 O O O O',
#  'O O O 제품 O O O O O O',
#  'O O 스펙 이벤트 O 기술 이벤트 O O O O O O O O',
#  '이벤트 O O 이벤트 이벤트 O 이벤트 O 이벤트 O O O',
#  '기술 제품 O O 스펙 O 이벤트 O 기술 O',
#  '기술 O 기술 O O O O 이벤트 이벤트 트렌드 O',
#  '스펙 이벤트 이벤트 O O O',
#  '기술 O O O O O 기술 기술 O O O O O O O 이벤트 O 이벤트 O',
#  'O O O O O O O 이벤트 O 기술 O O 제품 제품 O 이벤트 O O O O O O O O O O O O O O 이벤트 이벤트',
#  'O O 트렌드 O 트렌드 이벤트 O O O O O O O O 서비스 이벤트 O O',
#  '제품 제품 스펙 O O O O 이벤트 O O 기술 트렌드 이벤트 O O O O',
#  'O O O O 스펙 O O O O O 트렌드 O 서비스 이벤트 O O',
#  'O O 스펙 O O O O O 제품 O 기술 트렌드 이벤트 O O',
#  'O 제품 O O O O 스펙 O 서비스 기술 O 기술 O',
#  'O O 서비스 O O 사건/사고 O O 스펙 이벤트 스펙 O 이벤트 O O O O 이벤트 O',
#  'O 제품 이벤트 스펙 O O O O O O O',
#  '스펙 O 서비스 스펙 스펙 O 이벤트 O O O 기술 이벤트 O 스펙 사건/사고 이벤트 O O O O O O O',
#  '트렌드 O 서비스 이벤트 O O O O O O',
#  '제품 O 이벤트 O O 이벤트 O O 기술 제품 O 이벤트 O',
#  'O O O O O O O O 스펙 O O O O O 서비스 O',
#  'O O 제품 O O 스펙 스펙 서비스 기술 O O O',
#  'O O O O O O O O O 트렌드 O O O 이벤트',
#  'O O O O O 기술 트렌드 이벤트 O 이벤트 O',
#  'O O O 기술 O 이벤트 O O',
#  'O O O 제품 사건/사고 O O O O O O O 기술 O O O O O O O 기술 이벤트 트렌드 O 스펙 O O O O O',
#  'O O O 기술 O O O O O O O O O 이벤트 제품 O 이벤트 이벤트 O O 이벤트 O O O',
#  'O O 이벤트 O 사건/사고 제품 O 이벤트 O O O 이벤트 O',
#  'O O O O 제품 이벤트 O 이벤트 O O O',
#  '이벤트 O O O O O O O',
#  '스펙 O 제품 이벤트 O O O O O O O O 제품 O 이벤트 O 기술 O O O O O 스펙 O 이벤트 O O O 제품 O O O O O O 기술 O O O O O O O O O',
#  'O 서비스 O O 기술 기술 이벤트 O O O O O O O O 기술 O O 이벤트 O O',
#  'O O O 이벤트 소재 O 이벤트 O O O O O O O O O O O O O O O O O',
#  'O 이벤트 O O 제품 O 이벤트 이벤트',
#  'O O 제품 이벤트 이벤트 O 스펙 O O O O',
#  'O 이벤트 제품 O O O',
#  '기술 스펙 O 트렌드 O O 이벤트 O O O O O 트렌드 사건/사고 이벤트 O O O 이벤트 O O O O 이벤트 O O',
#  'O O O O O O O 스펙 이벤트 O O O O O O O O O O O 이벤트 O 이벤트 이벤트',
#  'O 이벤트 O O O O O O 이벤트 O 이벤트 이벤트 O O O O O O O O 이벤트 O O O 기술 O O 이벤트 O O O',
#  'O O 이벤트 O O O O O O O 이벤트 O O O O O O 이벤트 O O',
#  '제품 소재 제품 O O 제품 O 제품 제품 O O O O O 트렌드 이벤트 이벤트 O O O O O 이벤트 이벤트 O O O O O O O 이벤트 O O O O',
#  'O O 이벤트 이벤트 O O O O O O O O O 이벤트 O O O 트렌드 O O 스펙 O O 이벤트 O O O O O O 이벤트 기술 O O O O',
#  'O O 이벤트 O O O 이벤트 O O 이벤트',
#  'O O O 이벤트 O 트렌드 O 이벤트 이벤트',
#  'O O 이벤트 O O O O 이벤트 O O O O O O O O 이벤트 O',
#  'O 이벤트 O O O O 트렌드 O O O 이벤트 O O O O O O O O O O O O',
#  '이벤트 O O O O O O 트렌드 O O 이벤트 O O O O O 트렌드 O O O O O O O',
#  '트렌드 이벤트 이벤트 O O O 스펙 O O O O O O O O',
#  'O O O O 소재 이벤트 스펙 트렌드 사건/사고 소재 O O O O',
#  '이벤트 O 이벤트 O 트렌드 O O O O O O 이벤트 O O O O O',
#  'O O O O O O O 이벤트 서비스 O 이벤트 이벤트 O O O',
#  'O 이벤트 이벤트 트렌드 O O O O O 스펙 O O O 기술 O O O O O O O O',
#  'O 트렌드 이벤트 이벤트 O O 이벤트 O O O O O O O 스펙',
#  'O O O O O O 이벤트 O O 이벤트',
#  'O O O O O O O O 이벤트 O O O O 이벤트 O 이벤트 O 이벤트 O O 이벤트 O O',
#  'O O O 제품 O 이벤트 O 제품 O O O O O O 스펙 O O O 이벤트 이벤트',
#  'O O 이벤트 O O O O O O O O O O O 서비스 이벤트 O O O 스펙 트렌드 O O O O',
#  'O O O O O O O O O O O O O 이벤트',
#  'O O O O 이벤트 O O',
#  'O O O O O O O O 이벤트 O 스펙 O 스펙 O O 제품 O O O O O O 트렌드 O O O O O O 이벤트 O O O O',
#  'O O 스펙 O O O 스펙 O O O O O 스펙 소재 O O O O O O O O 이벤트 O',
#  'O O O 제품 소재 제품 이벤트 O O 제품 O O 이벤트 O O O 제품 기술 O O O O O 이벤트 O',
#  'O 이벤트 O O O O O O 이벤트 O O',
#  'O O O O 스펙 O O 이벤트 O O O O O O 이벤트 O O',
#  'O O O O O O O 제품 스펙 O 스펙 O',
#  'O O 제품 트렌드 O O O O O O O 기술 O O O O O O O',
#  'O 스펙 O 이벤트 O 소재 O O O O 이벤트 O O 스펙',
#  '트렌드 O 스펙 O O 이벤트 O O 스펙 이벤트 O O O O',
#  '제품 O O O O O O O',
#  'O O 트렌드 O 스펙 O',
#  'O O O O 소재 O O O 이벤트 O',
#  'O 스펙 O O O O O O O O O O 이벤트',
#  'O O O O O O O O O O O 이벤트',
#  'O O O O 제품 O O O O O O O O 기술 O O O',
#  'O O O O 소재 O O 이벤트 O O O 이벤트 이벤트 이벤트 O O O 기술 O O O O O O 이벤트 O O O O',
#  'O O 소재 스펙 스펙 O O O O 서비스 O O O 제품 스펙 O O O O O 이벤트 O 이벤트 O 이벤트 O O 이벤트 O O O O O O O O 스펙 O 기술 O O O O',
#  'O O 트렌드 O O O O O O 제품 이벤트 O O',
#  'O O O O 트렌드 O 이벤트 O O 사건/사고 O 이벤트',
#  'O O O 기술 기술 O O O O 트렌드 O 이벤트 트렌드 소재 O',
#  'O O O O O 스펙 O 스펙 이벤트 O O O',
#  'O O O O 제품 트렌드 O O O 기술 O O 이벤트 이벤트 O O 이벤트 O O',
#  'O 이벤트 O 기술 O 기술 O 기술 스펙 소재 이벤트 O',
#  'O 기술 트렌드 O O O O 서비스 트렌드 O O O O O 기술 스펙 소재 이벤트',
#  'O 트렌드 기술 O O O O 이벤트 O O O O',
#  'O 제품 스펙 O 이벤트 O O 이벤트',
#  'O O O O 이벤트 O O',
#  '이벤트 O 기술 기술 O 제품 O 이벤트 스펙 기술 사건/사고 O O O',
#  'O O 기술 스펙 O 기술 O O 소재 O O O',
#  'O O O O 기술 O O O O O',
#  'O O O O O 트렌드 기술 O O 기술 소재 이벤트 O O O O O O O O O O O 제품 O O 이벤트 O O O 이벤트 O O O O O 이벤트 스펙 트렌드 이벤트 이벤트 O',
#  'O O O 스펙 이벤트 O O O O O O O O O O O O',
#  '제품 O O O 스펙 제품 O O O O O 이벤트 이벤트 O O',
#  'O O O O O O O O 이벤트 O O 이벤트 O O O',
#  '제품 스펙 이벤트 서비스 O 이벤트 O 제품 O 제품 O 스펙 제품 소재 이벤트 O O O',
#  '제품 O 제품 제품 스펙 O 스펙 O 스펙 O O O 제품 O 제품 이벤트',
#  'O 제품 O O O O O O O O O',
#  'O 제품 제품 O O 사건/사고 이벤트 이벤트 O 트렌드 이벤트 O 이벤트 O O O O O',
#  '서비스 제품 이벤트 제품 O 제품 이벤트 O O O O O O O O O 이벤트 O',
#  'O 기술 O O 서비스 O 제품 제품 O 이벤트 O O',
#  '서비스 O O 제품 제품 O O 제품 제품 O O O 사건/사고 O O 이벤트 O O O O 이벤트 O 이벤트 제품 O O O O O 이벤트 O O O O O O O O O',
#  'O O 제품 O O 이벤트 O O O O O O O O 이벤트 O 이벤트 O O 서비스 제품 O 이벤트 O O O O O 이벤트 O O 제품 O O O O O O O 이벤트',
#  'O O O 이벤트 O O O 이벤트 O',
#  'O O O O O 이벤트 O 제품 O O O O 이벤트 O O O O',
#  'O 제품 O O O O O O O O O O O 이벤트 O O O O O O O O O 이벤트 이벤트',
#  '이벤트 O O O 이벤트 O O O O O O O O O O O O O O',
#  'O O O O O O O O 사건/사고 O O O O O',
#  'O 이벤트 O O O O O O O O O 사건/사고 O O O O O',
#  'O 스펙 O 이벤트 O O O O O O O O O O 제품 이벤트 O 이벤트 O',
#  'O O 이벤트 O O O O O O O O O O 이벤트 O O O O O O O O O O O',
#  '제품 O 이벤트 O 이벤트 O 이벤트 제품 O 기술 이벤트 O',
#  'O O O O O O O O O O O O O O O 이벤트 O O O O O O O O O',
#  'O O O 이벤트 O O O O O O 이벤트 O O O O O O O O',
#  'O O O O O 사건/사고 이벤트 O O O 이벤트 스펙 O',
#  'O O O 이벤트 O 사건/사고 O O',
#  'O O O O 사건/사고 이벤트 O O 이벤트 O 이벤트 O O',
#  'O O O 이벤트 O 이벤트 이벤트 O O O O 이벤트 기술 스펙 O O O O O O O 이벤트 O O',
#  'O O O O 제품 이벤트 O O O O O O O O O O O O O O O O O O O O',
#  'O O O 트렌드 O O O 이벤트 제품 이벤트 O O O O O 이벤트 O 이벤트 O O O O O O O O O O O O O',
#  'O O O O O 제품 O O 이벤트 O O 사건/사고 O O 기술 O O O O O O O O',
#  'O O 제품 이벤트 O O',
#  '제품 제품 O O O O 기술 O O O O 이벤트 O O O O O O O O O O 이벤트 O O',
#  'O O O O 기술 이벤트 O O O 이벤트 O 기술 O O 제품 O 소재 O 이벤트 O O O O O',
#  'O O O O O O 이벤트 스펙 O O O O O 기술 이벤트 사건/사고 O 제품 O O O O O O O O O',
#  'O O O O 기술 이벤트 O O O O O 스펙 O O O O',
#  'O 이벤트 기술 이벤트 O O O 이벤트 O O O O 스펙 O O O 이벤트 O 트렌드 O O O',
#  'O O O O 이벤트 O O 이벤트 O O 이벤트 O O O 트렌드 O O 트렌드 O 이벤트 이벤트 O O O O',
#  'O O 제품 제품 O O O O O O',
#  'O O 스펙 O O O O O O O O',
#  'O O O O 제품 O O 스펙 O O O O O O O O O O O O O O O O O O O O',
#  '스펙 O O 이벤트 제품 O O O 이벤트',
#  'O 제품 O O O O O O O O O O',
#  'O O O 이벤트 O O O 트렌드 스펙 이벤트 O O 이벤트 O',
#  '사건/사고 O O O 제품 O O O 이벤트 O O O O O O',
#  'O 트렌드 이벤트 O O O O O 이벤트 O O 스펙 O',
#  'O O O O O 트렌드 O O 이벤트',
#  'O 이벤트 O O O O O O O',
#  'O O 이벤트 이벤트 O O 스펙 O 기술 이벤트 O',
#  'O O O 제품 O 이벤트 O O',
#  'O 사건/사고 O O O O 사건/사고 O O O 제품 O O O O',
#  'O O O O 서비스 O 스펙 O O 기술 O O O O O O O O 트렌드 O O 이벤트 O O 이벤트 O',
#  '이벤트 제품 이벤트 기술 O O O O O O 스펙 O O O 이벤트 O',
#  '기술 O O O 트렌드 O O 스펙 O O 스펙 O O O 이벤트 O O O O 이벤트 제품 O O 소재 O O O O O O 이벤트 O 이벤트 O O O O',
#  '기술 O O 이벤트 제품 O O',
#  '기술 O O O O O O O O O O',
#  '제품 O O 제품 O O O O 기술 O O O O O',
#  'O O O O 스펙 O O O',
#  '사건/사고 O 트렌드 O 이벤트 스펙 O O O O O O 이벤트 O 제품 O O O O 트렌드 제품 제품 O 제품 O O O 기술 이벤트 기술 이벤트 O O 스펙 O O O O O O O 트렌드 O O O O 이벤트 O O O O O O 이벤트 이벤트 O 소재 O O O O O O O 이벤트 O O O O O 이벤트 사건/사고 O O 이벤트 O O 트렌드 이벤트 이벤트 이벤트 O O 제품 O O',
#  'O O 스펙 O 이벤트 스펙 O O O O O 이벤트 O O 제품 O O 트렌드 이벤트 O O O O O O 제품 O O O O O O 이벤트 이벤트 O O O',
#  '제품 제품 O O 이벤트 O O O O O 트렌드 제품 소재 O O O O O O 이벤트 이벤트 O O 트렌드 O O O 이벤트 O O',
#  'O O 이벤트 이벤트 O O 이벤트 이벤트 O O 제품 O O O O 이벤트 O O O O 트렌드 사건/사고 O O O O O 소재 이벤트 이벤트 이벤트 O O O O O O O O O O O O O 제품 O 스펙 O 서비스 제품 O O O O 제품 O O O O 사건/사고 O',
#  'O O 제품 O O O 기술 이벤트 O O O 제품 스펙 서비스 O 스펙 O O O O O O 스펙 O 이벤트 O',
#  'O O O 이벤트 O O 제품 O 트렌드 트렌드 O O O O O O',
#  'O O O O 기술 O O 스펙 O 제품 스펙 O O O O 스펙 O O O O 기술 O',
#  '스펙 제품 제품 트렌드 O O O 서비스 O O O O O 기술 O',
#  'O 제품 O 이벤트 O 제품 O 기술 기술 O 스펙 O O O O O O O O O 스펙 스펙 O O O O O',
#  'O O O 제품 O O O O 사건/사고 O O O O 사건/사고 O O 이벤트 O O O O O 제품 사건/사고 O 서비스 기술 O 이벤트 O O O O O O O 이벤트 O O O 기술 O O',
#  'O O 제품 O 제품 기술 제품 O',
#  '스펙 제품 O O 제품 O O O 사건/사고 O O O O O O',
#  'O 스펙 O O O O O O 제품 O O O 기술 이벤트 O O',
#  'O O O O 스펙 O',
#  '스펙 기술 O O O O 스펙 O 이벤트 O O',
#  'O O O O O O 서비스 O 스펙 제품 O O 기술 스펙 O O O 소재 O O O',
#  'O 서비스 O O O 기술 스펙 스펙 서비스 O 이벤트 O O O',
#  'O O O O O O 이벤트 제품 O 이벤트 O 스펙 O O 이벤트 이벤트 O O 이벤트 O O O O O O O O O 스펙 이벤트 O 제품 O 트렌드 이벤트 O O 서비스 O O O O O 이벤트 O O O',
#  'O 스펙 O 이벤트 O O 이벤트 O O 제품 O 트렌드 트렌드 O O O O O O O O 서비스 O O O 기술 O O O O 이벤트 O O O O',
#  'O 제품 O O O O 이벤트 이벤트 O O O 이벤트 O',
#  'O O 트렌드 이벤트 이벤트 O O O O O O O O O O 트렌드 O O 제품 O O 소재 O O O O O O',
#  'O O O O O O O O O O O O O O O 트렌드 O O 제품 O O O O O O O O O O 제품 O O O O O O',
#  'O O O 이벤트 O O O 이벤트 O 제품 O O O 이벤트 O O O O O O O O O O O O',
#  'O O 제품 O O 이벤트 O 제품 소재 O O 서비스 이벤트 트렌드 O O 제품 트렌드 제품 제품 O O O O O O O O O',
#  'O O 제품 이벤트 O O O O O O O O O O O O 이벤트 제품 O O O',
#  'O O 스펙 제품 제품 O 이벤트 O O 이벤트',
#  'O O O O O O O O O O 스펙 O 트렌드 O O O O O 사건/사고 O O O 이벤트 이벤트',
#  'O 스펙 O O O O 제품 O 트렌드 O O O O O O O O O O O O O O',
#  'O 이벤트 O O 이벤트 O 사건/사고 O O O O 사건/사고 O',
#  'O O 이벤트 이벤트 O 트렌드 O O O O O O O O O O O O O O O O O O',
#  'O O O 트렌드 O O O O O O',
#  'O 스펙 O 이벤트 O O O 사건/사고 이벤트 제품 O 이벤트 O O O O',
#  'O 제품 이벤트 O O O O O O O O O 제품 O O O 사건/사고 O O O O',
#  'O O O O O 이벤트 O O 제품 O O O O O O 이벤트 이벤트 O O 스펙 트렌드 O 이벤트 O',
#  '이벤트 O O O O O O O 제품 O O O O O O O O O O O O O O',
#  'O O O 이벤트 O O O O O O',
#  'O O O O 제품 O 트렌드 O O 소재 O O O O O O 이벤트 O O O',
#  'O O 트렌드 O O 이벤트 O',
#  'O O 소재 O 제품 이벤트 이벤트 이벤트 O O 사건/사고 O O 이벤트 트렌드 이벤트 O O O 서비스 O O O O O O O O O 이벤트 O O O O O O 이벤트',
#  'O 제품 이벤트 이벤트 O O 이벤트 O O O O O O O O O O O O O O O O O O',
#  'O 이벤트 이벤트 O 스펙 제품 O O O O O O O 이벤트 O O O O 스펙 O O O O O O O O O O O O O O 사건/사고 O O O',
#  'O O 스펙 O 제품 O O O 이벤트 O O O O O 이벤트 O O O O O O O O O 이벤트 이벤트 O O O O 이벤트 O O',
#  'O 이벤트 O O O O O 제품 이벤트 O O 소재 O O 소재 O 소재 O O O O',
#  '제품 소재 소재 제품 O O O 사건/사고 O O 트렌드 스펙 O O 스펙 O O O O O O O O 소재 O O O',
#  'O O O O 소재 제품 O O 이벤트 O O O O O',
#  '제품 O O O O O 소재 소재 O O 스펙 트렌드 스펙 O O O',
#  '제품 O 트렌드 스펙 이벤트 O O O O 소재 O O O O O',
#  '제품 소재 O O O O O O 소재 소재 O 소재 O 소재 O 소재 스펙 스펙 스펙 O 트렌드 스펙 O O O O O O O O',
#  'O 소재 제품 O O O 소재 O O 이벤트 O O O',
#  'O O 제품 이벤트 O O O O 제품 O O 제품 O 기술 이벤트 O O O O 이벤트 스펙 이벤트 O O 이벤트 O',
#  'O 제품 O O O 이벤트 제품 O O 이벤트 제품 스펙 O 이벤트 O 이벤트 O O O O O O',
#  'O O O O 제품 스펙 O O 이벤트 기술 O O 소재 소재 소재 소재 O O 이벤트 스펙 제품 O O 이벤트 트렌드 O 기술 O O',
#  '제품 O O O 이벤트 O O 스펙 O O O O O O O',
#  'O O O O 소재 이벤트 이벤트 O 이벤트 트렌드 이벤트 O O 이벤트 O O 제품 O 스펙 소재 O 스펙 O O O O O 기술 이벤트 O 이벤트',
#  '제품 O O O O O 이벤트 스펙 O 트렌드 이벤트',
#  'O O 제품 O O O O O 이벤트 기술 스펙 기술 O 스펙 트렌드 트렌드 O O 이벤트',
#  '스펙 O O O 사건/사고 소재 트렌드 O 스펙 제품 O O O O O O O O O 스펙 O O O O 트렌드 O O',
#  '제품 O O O O O O 이벤트 O O O 사건/사고 이벤트 O O 이벤트 O O O O O O O O O O O O O O 스펙 제품 O O O O O 이벤트 O 이벤트',
#  '제품 O 제품 O 이벤트 O 이벤트 O O 이벤트 O O 이벤트 O O O 스펙 O O O O O 이벤트 이벤트',
#  'O O O O O 이벤트 O 제품 O 기술 소재 이벤트 O O 이벤트 스펙 O O O O O 이벤트 이벤트 O O O O O O O 이벤트',
#  '스펙 소재 O 제품 기술 이벤트 O 제품 이벤트 O O O O O 이벤트 O O 이벤트',
#  'O O 제품 O 기술 O 기술 이벤트 O 소재 O O O 이벤트 O',
#  '이벤트 이벤트 O O 제품 이벤트 O O 기술 스펙 O O O O O O O O 이벤트 이벤트',
#  'O 스펙 이벤트 O 소재 이벤트 O O',
#  'O O 이벤트 이벤트 O O O O 제품 O O',
#  'O O 스펙 O O 제품 이벤트 O O O O 제품 O O O O O O O O',
#  'O O O O O 이벤트 O',
#  '이벤트 이벤트 O O O O O 이벤트 O',
#  'O O O O O O O 트렌드 O',
#  'O O O O O O 이벤트 O O O O O O O O O 이벤트 O O O O 이벤트 이벤트 O',
#  'O 제품 이벤트 이벤트 이벤트',
#  'O 이벤트 O 기술 스펙 이벤트 O 이벤트 O 이벤트 O O O O O O O O',
#  'O O 소재 O O O O 이벤트',
#  'O O 이벤트 O 제품 이벤트 O O',
#  'O 이벤트 소재 O O O 제품 O O O O O O 이벤트',
#  '스펙 제품 O O 제품 O 이벤트 O 이벤트 O',
#  'O O O 제품 O 기술 이벤트',
#  'O 제품 O 이벤트 O O O 이벤트 이벤트',
#  'O O 트렌드 스펙 O O O',
#  'O 스펙 O 이벤트 트렌드 O 이벤트 O O',
#  '제품 스펙 소재 O 스펙 O O O O 이벤트 O',
#  'O 소재 O O O 이벤트 기술 스펙',
#  '제품 O O 이벤트 O',
#  'O O O 제품 O O O 이벤트 O',
#  '제품 O O O O O',
#  'O O O O O O 제품 O O O O',
#  'O 제품 트렌드 이벤트',
#  'O 제품 O 이벤트',
#  '이벤트 O 제품 O O O O O',
#  'O O O O O O 스펙',
#  '제품 O O 제품 O O',
#  'O 이벤트 O O 제품 스펙 O O O O O O O O 이벤트',
#  'O O O O 제품 O 기술 O O O',
#  '기술 O O 이벤트 O 트렌드',
#  'O O O 제품 O O O 제품 O O 이벤트 O O O 이벤트 O O O O',
#  'O O O O O O O O O O O O O 제품 O O O O O O O O O O O 이벤트 O 이벤트 O O O 제품 O 이벤트 이벤트',
#  'O O O O O O O O O O O 제품 O O O O O O O O 이벤트 O 소재 이벤트 O O O 이벤트 O O 이벤트 제품 O O O O',
#  'O O 제품 O O 이벤트 O O O O 제품 스펙 O 이벤트 스펙 O O O 이벤트 O O O 스펙 O O O O O O',
#  'O O O 이벤트 이벤트 O O O O O O',
#  'O O 이벤트 O 제품 O O O O O O O O O O 이벤트 O 제품 O O O O O O O O 이벤트 이벤트',
#  'O O 이벤트 O O O O O O O O O 스펙 O',
#  'O O O O 이벤트 이벤트 이벤트',
#  'O O O O O O 이벤트 O 이벤트 O O',
#  'O O O 이벤트 O 이벤트 O O',
#  'O O O O O O O O O O O 제품 소재 O O O O 이벤트 O O O O O O',
#  'O O 이벤트 스펙 O 이벤트 O O O',
#  'O O O O O O 스펙 O 이벤트 스펙 이벤트 이벤트',
#  'O O O 이벤트 이벤트 O O O',
#  'O 기술 기술 기술 O O O O 제품 O 서비스 이벤트 O',
#  'O O 이벤트 제품 O O O O O',
#  'O 서비스 제품 제품 O 스펙 이벤트 제품 이벤트 O O',
#  'O O 제품 O O O O O 이벤트 O O O 기술 O O O O O O O O 제품 O O 스펙 O O O 이벤트 O 제품 O O O O O O O',
#  'O O 제품 제품 O O 제품 제품 O O 제품 O O O 트렌드 O O 이벤트 O O O O O O O',
#  'O O O 이벤트 이벤트 O O 이벤트 O O O',
#  'O O 이벤트 O O O 스펙 O O 이벤트 O O O',
#  'O 제품 기술 제품 기술 O O O 제품 사건/사고 O 이벤트 O O O O O 이벤트 이벤트 O 제품 이벤트 O O 이벤트 O O O O O O O 이벤트',
#  'O O 이벤트 O O 이벤트 이벤트 O O O 이벤트 O O O O O O',
#  'O O O O 이벤트 O O O 이벤트 트렌드 O O O 소재 O O 이벤트 이벤트',
#  '이벤트 O O 스펙 이벤트 이벤트 이벤트 O O',
#  'O 이벤트 O O O O O O 스펙 제품 기술 O O 이벤트 O',
#  'O O O 트렌드 O O O O 이벤트 소재 O O 제품 O 이벤트 O',
#  'O O O O O O O 이벤트 O O O O O O O 트렌드 O O O 트렌드 O O 이벤트 O',
#  '이벤트 O O O O 이벤트',
#  'O O O 이벤트 O O 제품 O 사건/사고',
#  'O O O O 사건/사고 O O O',
#  'O 트렌드 O O O 제품 O O O O O 이벤트 O O 이벤트 이벤트 O O 이벤트 O',
#  '제품 O O O O O O 이벤트 O O O O O 이벤트 O O O O O O O',
#  'O O O O 사건/사고 O O O O O O O O O O',
#  '제품 O O O 이벤트 O',
#  'O 이벤트 O O O O O O O 이벤트 스펙 트렌드 O O O O O O O O 이벤트 O O O',
#  'O 이벤트 O 제품 O O O 이벤트 O O 이벤트 O O 이벤트 O O O O O 이벤트 O O O O O O',
#  'O O 제품 O O 사건/사고 O O O O O O 스펙 O O O O 이벤트 O O O O',
#  'O O O 사건/사고 O 이벤트 O O O 사건/사고 O O O 이벤트 O O O O',
#  'O O O O O O O 이벤트 O 트렌드 제품 O O 기술 제품 O 이벤트 O O',
#  'O O O O 이벤트 이벤트 O 이벤트 O O O O 스펙 O 이벤트 O O',
#  'O O O O O 소재 O O O O 사건/사고 O O 제품 O 스펙 O O O 이벤트 O 이벤트 O O O O O O O O O',
#  'O O O O 스펙 O O O',
#  'O O 스펙 O O O 제품 O O O O O O O O O O 이벤트 O O O 소재 이벤트 이벤트 O 사건/사고 사건/사고 O O O 이벤트 O O O 제품 O O O O O 이벤트 O O O 사건/사고 O O O O 트렌드 O 제품 O O O O O 사건/사고 O',
#  '제품 O O O O O O O O O O O O O O 트렌드 O 트렌드 O O O O O 이벤트 O O O O O O O O O 트렌드 이벤트 O O O O 제품 O 이벤트 O 이벤트 O 트렌드 O O 스펙 O O O 이벤트 O O O O 스펙 O O O O O O O',
#  'O O 스펙 이벤트 O O O O O O O O O O 스펙 제품 O O 이벤트 O O O O O O 이벤트 이벤트 O O O 트렌드 이벤트 O 트렌드 이벤트 O O O O O 이벤트 이벤트 O O 제품 이벤트 이벤트 기술 스펙 O 스펙 O 사건/사고 O O 이벤트 O O O 트렌드 이벤트 이벤트 O O O O 이벤트 O 서비스 트렌드 O O O O O O O 트렌드 O O O O O O O O 제품 O 제품 트렌드 O O O O O O O O O 트렌드 제품 O O O 이벤트 O O O O O O O O O O O O O O 소재 O 제품 O 기술 O 이벤트 소재 O O O 제품 이벤트 O O O O 이벤트 트렌드 O O O O 사건/사고 트렌드 O 사건/사고 O O O O O O O O O O O O O O 이벤트 O O 사건/사고 스펙 O O O O O O O O O 트렌드 이벤트 O O O O O O',
#  'O O O O O 이벤트 이벤트 트렌드 O O O O 서비스 이벤트 O 기술 트렌드 O O O O O O O 스펙 O O O O O O 소재 O O 이벤트 O O O O O O O O O 사건/사고 O O O O O 서비스 O 이벤트 사건/사고 O O O O 제품 O O O 이벤트 O 소재 O O O O O O 제품 이벤트 O O O O O 소재 이벤트 O O O',
#  'O O O 이벤트 O O O 이벤트 O O',
#  '소재 O O O O O O O O 기술 O O 이벤트 이벤트',
#  '스펙 이벤트 O',
#  'O 소재 O O 이벤트 O',
#  'O O 제품 O O O O O 기술 O 이벤트 이벤트',
#  'O O 소재 이벤트 O O O 이벤트 이벤트 O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O 스펙 O 기술 O 이벤트 O 이벤트',
#  'O O O 제품 O O O O O O O O O 제품 O O O O',
#  '제품 O 스펙 O O O O',
#  'O O O O O O 기술 기술 O 제품 O O 이벤트',
#  'O O O O O O O O 제품 O O O',
#  'O O O 제품 제품 O O O 제품 기술 이벤트 O',
#  '이벤트 O O 제품 O 이벤트 O 이벤트 이벤트',
#  'O O 기술 제품 기술 O O 이벤트 O',
#  'O O 스펙 O O O O O 제품 이벤트',
#  'O O 서비스 O O O 이벤트 O 스펙 O O O',
#  'O O O O O 제품 O O O 제품 O O O O',
#  'O O O 이벤트 O O O O O O O O O O',
#  'O O 서비스 스펙 O 이벤트 제품 이벤트 O',
#  'O 이벤트 O O',
#  '제품 O 이벤트 O O',
#  'O O O 제품 O O',
#  'O O O 트렌드 O O 이벤트 O O O',
#  'O O 이벤트 제품 이벤트 O O 스펙 스펙 O 기술 이벤트 O O O O O',
#  'O O O O O 스펙 O O O 이벤트 이벤트 O',
#  'O O O O O O O 트렌드 O 스펙 O O 스펙 O 서비스 서비스 스펙 O O 이벤트',
#  'O O O O O 스펙 O O 제품 이벤트 O 기술 이벤트 이벤트',
#  'O O O 스펙 O 서비스 이벤트 O',
#  'O 이벤트 O 스펙 O',
#  'O O O 스펙 O 이벤트 O 스펙 O 스펙 O 서비스 O O 기술 O O O O O O',
#  'O O O O O O 스펙 기술 O 제품 이벤트 O 스펙 O O O O O O O 스펙 O O O O O O O 이벤트 O O O O',
#  'O 스펙 O 이벤트 이벤트 O O 사건/사고 O',
#  'O 이벤트 O 스펙 O 서비스 서비스 스펙 O 이벤트 O 스펙 O O O 이벤트 O',
#  'O O O O O O O O 서비스 O O O O O 사건/사고 O O',
#  'O 이벤트 O O 스펙 O 서비스 O O O O O O O',
#  'O O O O O O O O O 서비스 O O 서비스 이벤트 O O 사건/사고 O O O O 스펙 O O O 서비스 스펙 O 이벤트 O O 사건/사고 O O',
#  '스펙 O O O 제품 O 스펙 O O 제품 O O O O 제품 이벤트 O O 기술 서비스 O O O O O O',
#  '스펙 O 이벤트 O O 스펙 O O O 이벤트 소재 O O O O',
#  'O 기술 O O O 기술 서비스 트렌드 O O 이벤트 O',
#  'O O 기술 O O O O O 제품 이벤트 O O O 서비스 기술 서비스 O',
#  'O O 스펙 O O 제품 이벤트 트렌드 O O 서비스 기술 서비스 O O O',
#  'O O O O O 스펙 O O 트렌드 O',
#  'O O O O O 기술 서비스 O O O O O',
#  'O O 기술 스펙 O O O 서비스 O O 이벤트',
#  'O 스펙 O O O O O O O O O 이벤트',
#  'O 사건/사고 O O O O 이벤트 O 제품 O O O 제품 O 스펙 O O O',
#  'O O O O O O 서비스 O O O O O',
#  'O O O O O O O 서비스 O O 스펙 O O O O O O O 이벤트 O O O O O 제품 이벤트 O O 스펙 O O O O O O O',
#  'O 트렌드 O O O O O O O O 이벤트 O',
#  'O O O O 제품 O O O O 이벤트 O 이벤트 이벤트 이벤트 O O',
#  'O 이벤트 O O O O O O 이벤트 스펙 트렌드 O O O O O',
#  'O O 사건/사고 O 트렌드 제품 O O O 이벤트 O O O',
#  'O O O O O 이벤트 O 제품 O 트렌드 O 사건/사고 O O O O O 이벤트 O 제품 O O O 이벤트 O O 이벤트 O O 이벤트 O O O O O 이벤트 O O O O O O',
#  'O O O 제품 O O 사건/사고 O O O O O O 스펙 O O O O 이벤트 O O O O O O O 사건/사고 O O 스펙 O 사건/사고 이벤트 트렌드 O 이벤트 이벤트 O',
#  '이벤트 이벤트 O O O O O 스펙 O O O 이벤트 O O',
#  'O O O O 제품 기술 제품 기술 이벤트 스펙 O O 이벤트 O O',
#  'O O O O O O O O O O 트렌드 O O 이벤트 이벤트 O',
#  'O 제품 O O O O O O O O O 제품 제품 기술 O O O',
#  'O O 이벤트 O 이벤트 O 스펙 O O O O O 스펙 제품 제품 O O 이벤트 O',
#  'O O O 이벤트 O O O 기술 O 이벤트',
#  'O O O 기술 이벤트 O 제품 O O O O O O O O O O O O 이벤트 사건/사고 O O O O O',
#  'O 이벤트 O O O O 스펙 제품 O O 이벤트 O O 이벤트 이벤트 O O O O O O 이벤트 O O 이벤트 O',
#  'O O O O 이벤트 O 스펙 O O O O 이벤트 O O O',
#  'O O 기술 기술 O 트렌드 O O 스펙 O O O 이벤트 O O O O O O O O 스펙 O 제품 이벤트 스펙 O O O O O O O O O O O',
#  'O O O O O O 스펙 O O O O 이벤트 O 이벤트 O',
#  'O O O O O O O O O O 서비스',
#  'O 트렌드 O O O O',
#  '이벤트 O O O 스펙 O 서비스 제품 이벤트 O 기술 O O O O O O O O O O O 스펙 O O O O O O O O O O O O O O O O O O O O O O',
#  'O 이벤트 O O 기술 기술 O O O O O O O O O O O O O 제품 서비스 O O O O O O O O O O O O O 트렌드 이벤트 O 트렌드 O O O O O O 이벤트 이벤트',
#  'O O O O O O O O O O 이벤트 O O O',
#  'O O O O O O 트렌드 서비스 이벤트 O O O 이벤트 O O O 이벤트 이벤트 O O 제품 이벤트 O 이벤트 O 스펙 O O O 제품 O O 이벤트 O O',
#  'O O O 트렌드 O 이벤트 O O 제품 O O 제품 O O O O',
#  'O O O 트렌드 O O 이벤트 이벤트 O O O O 제품 O 이벤트 O 이벤트 O O O O',
#  '트렌드 제품 O O O 제품 O O O 이벤트 O O 이벤트 이벤트 O',
#  'O O O 제품 O O',
#  'O 소재 O O 제품 O O O',
#  'O O O O O O 제품 O 이벤트',
#  'O O 소재 트렌드 O O',
#  '제품 O O 스펙 O O O O O O O O O',
#  'O O O 이벤트 서비스 O O O 이벤트',
#  'O 제품 O 제품 O O',
#  'O O 제품 O O O O O O O O O O O O 이벤트',
#  'O 제품 O O O O O O O O O O O O O O O O O O O O',
#  '제품 O O O O O O O O O O O O O O O O',
#  '제품 O O O O O O O O O O O O O O O O',
#  '스펙 O O O O',
#  'O O O O O 제품 O',
#  '제품 O O O O',
#  'O O O O O 제품 O O O 제품 제품 제품 이벤트 O O O O O O O O O O 제품 O O O 서비스 O O O O 제품 O O',
#  'O O 이벤트 O O O O O O O O O O O O O O',
#  'O O O O O 이벤트 O 제품 O O O O O O O O',
#  'O 제품 O O O O 이벤트',
#  'O O O O O O O O O O 이벤트',
#  'O O 제품 O O O O O 소재',
#  'O O 소재 O 이벤트 O O O',
#  'O 이벤트 O 제품 O O 스펙 제품 O O O O O',
#  'O O O O O O O O O O 이벤트 O O O O 제품 O O',
#  'O O O O 스펙 O O O',
#  'O O O O O O 이벤트 O O O O O O O O O O O O O O 스펙 O O O 소재 O 이벤트 소재 O O 사건/사고 이벤트 O O O O O O 서비스 O 이벤트 이벤트 O O O O O 이벤트 소재 O O O O 제품 스펙 소재 이벤트 O O O O 이벤트 O O O O O O O 이벤트 트렌드 O O 이벤트 O O O O O O O O O O O O O 제품 O O 이벤트 O O O O O O O O 이벤트 O O O O O 트렌드 O O O O O 이벤트 O O O O 서비스 이벤트 O O O O O O O O O O O O O O O 기술 O O O O O 제품 이벤트 O 이벤트 이벤트 O O 이벤트 O O 이벤트 O O O O O 기술 O 기술 O O 스펙 O O',
#  'O O O 이벤트 이벤트 O 기술 트렌드 이벤트 제품 O 제품 이벤트 O 이벤트 O O O O 이벤트 이벤트 O O 이벤트 O O 제품 O O O O O O O O O O O O O 이벤트 O O 사건/사고 O O O O O',
#  'O 이벤트 O O O O 이벤트 O O O 소재 이벤트 O O O 기술 이벤트 이벤트 O O O O O 이벤트 사건/사고 O 기술 O O O 제품 이벤트 제품 O O O O O 제품 O O O O O 스펙 트렌드 O O 트렌드 O 이벤트 O O O',
#  'O O O 이벤트 제품 이벤트 O O 이벤트 O O O 소재 O 이벤트 이벤트 O O 제품 O O O O O O 이벤트',
#  'O O O 이벤트 제품 O 이벤트 O O O O 제품 O O O 이벤트 O',
#  'O O O O O O 이벤트 O O',
#  'O O O O O O O O 제품 이벤트 O O O O O O O',
#  'O O 사건/사고 O O O O O 사건/사고 O',
#  'O 제품 이벤트 O O O O O O O O O O O O O',
#  'O 제품 O O O O O 트렌드 O O O O O 사건/사고 O 스펙 O O O O O O',
#  'O 사건/사고 이벤트 사건/사고 O O O 트렌드 사건/사고 O O O 이벤트 O O',
#  'O 이벤트 O O O O O',
#  'O O O O 소재 소재 제품 O O O 이벤트 이벤트 O O O O O O O O',
#  'O O O 제품 스펙 이벤트 O O O O O O O O O 제품 제품 O O O',
#  'O O O O O O O O 이벤트 O O O',
#  'O O 이벤트 O 제품 이벤트 O O O O O O O O O O O O O O O',
#  'O O O O O O 제품 O 제품 O 이벤트 O O O O O O O O O O',
#  'O O 제품 O 이벤트 이벤트 O 이벤트 이벤트 O 제품 O 이벤트 O O O O',
#  'O O O O O O O 제품 O O O O O 스펙 O O O 이벤트 O 이벤트 O O O 스펙 O',
#  'O O O 제품 O O 이벤트 사건/사고 O O 이벤트 O 이벤트 O O O O',
#  'O O O O O O O 이벤트 이벤트 O O O',
#  'O O O 이벤트 소재 소재 O 제품 O O',
#  'O O O 이벤트 제품 서비스 O O O O O O',
#  'O O O O 이벤트 O O O',
#  'O O 트렌드 O 이벤트 제품 이벤트 제품 O',
#  'O 이벤트 스펙 O 트렌드 O O',
#  'O 이벤트 O 트렌드 이벤트 스펙 O 이벤트 O',
#  'O O O 트렌드 O O O 제품 O 제품 이벤트 O',
#  '이벤트 이벤트 O O',
#  'O O O 스펙 O 제품 제품 O O O',
#  'O O 이벤트 O 제품 제품 이벤트 사건/사고 O O O 이벤트 O O',
#  'O O O O O 스펙 O O 제품 제품 O O',
#  'O O O 제품 O 기술 서비스 O O O O',
#  'O O 이벤트 O O',
#  'O 기술 O O O O 스펙 이벤트 O 트렌드 O O 이벤트',
#  '제품 제품 트렌드 스펙 O 제품 기술 O O O O O 이벤트 O 이벤트 O O O O O O',
#  '스펙 O O O O O O O O 제품 제품 O 사건/사고 O O',
#  'O 제품 O O O 스펙 이벤트 O',
#  '기술 O O O 이벤트 O O 제품 O O O',
#  'O O 기술 O O O O O O 사건/사고 스펙 O O O O O O O',
#  'O O 스펙 O O',
#  '제품 제품 O O 제품 스펙 O O',
#  '스펙 O O O 소재 O 기술 스펙 소재 제품 트렌드 O 스펙 이벤트 O O',
#  'O 제품 이벤트 O O 기술 O O O 기술 O O 제품 기술 O O 제품 O 이벤트 O',
#  'O O O 스펙 이벤트 O 사건/사고 O',
#  '스펙 제품 제품 O O O 소재 O O O O',
#  'O 사건/사고 트렌드 O O O O O O O',
#  'O O O O O O O O O 이벤트 이벤트',
#  '기술 O O O O 제품 O O O 이벤트',
#  'O 이벤트 이벤트 O O 이벤트 O',
#  'O O O 제품 제품 이벤트 O O O O 기술 O 이벤트',
#  '스펙 서비스 O O 제품 O O 이벤트 O O O',
#  'O O O O O 제품 제품 O O O O O 기술 O O',
#  '스펙 O O O O O O O 이벤트 O O O O O',
#  'O 기술 O 스펙 스펙 O O O O 이벤트 O 제품 O O O O 이벤트 사건/사고 O O 사건/사고 O O O O O O O O 제품 제품 서비스 O O O 이벤트 이벤트 이벤트 O O 이벤트 O 이벤트 O O O O O O O 서비스 O O O',
#  'O O O 스펙 제품 O O O O O O 이벤트 O 스펙 이벤트 이벤트',
#  'O O 트렌드 O O 이벤트 O O O O O O 이벤트 O',
#  'O O O O 제품 O O O O O O O O O O O O O O O O O O O O O O O',
#  '제품 O O O O O O O O O 스펙 제품 제품 제품 O O 이벤트 O O O O O',
#  'O 제품 O O 트렌드 O 이벤트 제품 제품 이벤트 O 이벤트 O O O O O O O O 이벤트 O 이벤트',
#  'O 이벤트 O O O 이벤트 O O O O O O 기술 O 제품 O 소재 O O 이벤트 O',
#  'O O 트렌드 O O 트렌드 이벤트 O O 이벤트 O 제품 제품 이벤트 O O O',
#  'O O O 제품 O O O O O',
#  'O O O O O O 제품 제품 이벤트 O O',
#  'O O O O O O 트렌드 O O 제품 제품 이벤트 O 이벤트 이벤트 O O O O O 이벤트 O O O 이벤트 O',
#  'O O 이벤트 O',
#  'O O O O O O 제품 O O O O',
#  'O 제품 제품 O O O O',
#  '제품 이벤트 사건/사고 제품 제품 O 이벤트 O O',
#  'O O O 제품 O',
#  'O O 제품 제품 제품 O O 이벤트 O O O',
#  '제품 O O O 제품 O 제품 O 트렌드 O 스펙 O 이벤트 O 이벤트',
#  'O O O O O O O O O 스펙 O',
#  'O O 제품 사건/사고 소재 O O O O O O O O 이벤트 기술 스펙 O O O 스펙 스펙 O O O O O O',
#  '제품 O O 이벤트 제품 O O O O O',
#  'O 스펙 제품 O O O 서비스 기술 O O O O O O O O',
#  'O 제품 O O O O O O O O 제품 제품 O O O O',
#  'O 제품 O O O O O 제품 O 이벤트 O 이벤트 O',
#  'O O 소재 O 제품 O O O O O 제품 기술 제품 기술 O 이벤트 이벤트 O 제품 O 제품 O O O O O O O O O O O O 스펙 O O O O O',
#  '제품 O O O O 제품 O O O 이벤트 O 이벤트 O O 제품 제품 O 이벤트 O O O O O O O O 이벤트',
#  'O O 트렌드 O O 이벤트 O O',
#  '스펙 O O O O O O 이벤트 O O 제품 O O',
#  'O 이벤트 O O O O O O O 이벤트 O O',
#  'O O O 트렌드 O 이벤트 O O',
#  'O O O O O O O O O O 이벤트 O O 이벤트 O O',
#  'O O O 트렌드 O O O O O O 이벤트',
#  'O O O 이벤트 O O O O O 이벤트 O O O O 이벤트 O O',
#  'O O O O 트렌드 O O O O',
#  'O O O O 이벤트 O O',
#  'O O O O O 제품 O O O O O O O 스펙 O O 제품 O O O O O O O O',
#  '트렌드 O O 제품 제품 O 트렌드 O O O O 이벤트 O O O',
#  'O O O 이벤트 O 이벤트 O O O O O O 제품 O O O O 트렌드 O 이벤트 이벤트',
#  'O O O O O O O 이벤트 O O',
#  'O O 트렌드 스펙 O O O O O 이벤트 O O O O O 트렌드 O O O 트렌드 O 이벤트 O O O O O O O O O O O O O O O 기술 O O O',
#  '제품 트렌드 O 이벤트 O O O O O O 제품 O',
#  'O O 제품 O 이벤트 O O O O O O O O',
#  'O 트렌드 O O 제품 이벤트 O O O O O O O O 이벤트 이벤트 이벤트 O O',
#  'O O O O O O O O O 기술 O 트렌드 이벤트 이벤트 O 이벤트',
#  '이벤트 O O 이벤트 O 이벤트 O O O 이벤트 O O O',
#  'O O O 제품 이벤트 O 이벤트 O O O O',
#  '이벤트',
#  '제품 O O O 스펙 O O O O O O O',
#  'O O O 제품 O O O O O O O O O O O O 스펙 O 스펙 O O O',
#  'O O 제품 제품 제품 제품 O 기술 O O O O O 기술 스펙 O O 이벤트',
#  '제품 O O O O O O 이벤트 O',
#  'O O O O 스펙 O O O O O',
#  '이벤트 O O 이벤트 O O O O O O O',
#  '트렌드 O O 이벤트 O O O 이벤트 O 제품 O 이벤트',
#  'O O O 이벤트 O',
#  'O O O O 제품 이벤트 O O O O O O O O O O O O O O O 이벤트 O O O',
#  'O O O O O O O O 이벤트 O O O O 제품 O O O 스펙 제품 O O O',
#  'O O 제품 O O 제품 이벤트 O O O O 이벤트 O',
#  'O O O O O O 제품 O O O 스펙 O O O O',
#  'O O 제품 제품 O 제품 O 기술 O 제품 O 이벤트 트렌드 O O 이벤트 O O',
#  'O O 제품 트렌드 O 이벤트 O O O O O 제품 O',
#  'O 제품 이벤트 O O O O O O O O',
#  'O O O O 트렌드 O 제품 이벤트 O',
#  'O O O O O 트렌드 O 이벤트 이벤트 이벤트 O O',
#  'O O O O O O O O O 기술 O 트렌드 이벤트 이벤트 O 이벤트',
#  '이벤트 O O 이벤트 O 이벤트 O O O 이벤트 O O',
#  'O O O 제품 이벤트 O 이벤트 O O O O',
#  '이벤트',
#  '제품 O O O 스펙 O O O O O O O',
#  'O O O 제품 O O O O O O O O O 스펙 O 스펙 O O O',
#  '제품 O O O O O O 이벤트',
#  'O O 제품 제품 제품 제품 O 기술 O O O O O 기술 O 스펙 O O 이벤트 O',
#  'O O O O 스펙 O O O 이벤트 O O 이벤트 O O O O O O O O O',
#  '트렌드 O 이벤트 O O O 이벤트',
#  'O 제품 O 이벤트 O',
#  'O O O 이벤트 O',
#  'O O O 제품 이벤트 O O O O O O',
#  'O O O O O O O 제품 이벤트 O O O',
#  'O O O O O O O 이벤트 O O O O 제품 O O 스펙 제품 O O O',
#  'O 제품 O 제품 이벤트 O O O O 이벤트 O',
#  'O O O O O O O 제품 O O O 스펙 O O O',
#  'O 제품 제품 O 제품 O 기술 O 제품 O 이벤트 트렌드 O O 이벤트 O',
#  'O O O 스펙 O O O O 기술 O O O 이벤트 O',
#  '제품 제품 이벤트 사건/사고 O 이벤트 O O',
#  'O O O 스펙 O O O O O 기술 O 이벤트 O O',
#  'O O O O 이벤트 O O O O O O O 이벤트 O',
#  '스펙 O O O O O O 기술 O O O O',
#  'O O O O O 이벤트 O O O 제품 O O O O O O',
#  'O O O O 스펙 O O O',
#  'O O O 이벤트 기술 O O O 이벤트 O O O O O O O O O 기술 O O 소재 스펙 이벤트 이벤트 O O O 트렌드 이벤트 O O O O O O O O O O',
#  '스펙 O O O O 제품 O O O O',
#  'O O O O O 서비스 O 제품 이벤트 O 트렌드 O 이벤트 O O O 이벤트 O O 이벤트 이벤트 O O O O O O O 이벤트 이벤트 O O O O O O 트렌드 이벤트 O O O O 스펙 O O O O O O O 제품 O 이벤트 O O O O O O O O O O O O 소재 O O O 이벤트 O O O O O 이벤트 이벤트 O O O 기술 제품 소재 O O 기술 기술 O O O O 소재 제품 O 이벤트 O O O O O O O O 이벤트 O 트렌드 이벤트 O O O O O O O 제품 이벤트 O O O O O 이벤트 기술 트렌드 서비스 O O 이벤트 O O O 서비스 O 이벤트 사건/사고 O O O O O 이벤트 이벤트 O 이벤트 제품 O O O O O 제품 O O O O O O O 이벤트 O O O 스펙 이벤트 O O O O O O O O O 제품 O O O O O O 이벤트 O 제품 O O O O 제품 O O 스펙 O O O 이벤트 O O O O 스펙 O O 서비스 O 트렌드 이벤트 O O 트렌드 O O O O O 트렌드 사건/사고 제품 O O O O 사건/사고 O O O O O O O O O 트렌드 O O O 소재 O 이벤트 O O 트렌드 O O 기술 트렌드 기술 O 이벤트 O O O 제품 O 제품 O 스펙 O O O O O O O O O O O',
#  '트렌드 O O O 사건/사고 O O O O 서비스 O 소재 이벤트 소재 O O O O O O',
#  'O O O O O O 제품 스펙 O 스펙 O 이벤트',
#  'O O O O O O O O O O O O O O 제품 기술 O 서비스 O O O 이벤트 O',
#  '서비스 O O O O O O O 서비스 O O O 스펙 O O O O 이벤트 O',
#  '서비스 O O O O 기술 O 기술 O 기술 제품 O O 서비스 제품 O',
#  'O 제품 서비스 O O O 기술 O O O O O 제품 O O',
#  'O O 서비스 O O O O 제품 스펙 O O 스펙 O O O O 기술 O O O',
#  '스펙 제품 O 이벤트 O 제품 트렌드 O O O 기술 O O 기술 O 서비스 기술',
#  '제품 스펙 O 기술 이벤트 서비스 O O O O O',
#  'O O O O O O 제품 O O O O 사건/사고 O O O 서비스 사건/사고 O O O O 이벤트 O O 제품 사건/사고 O 서비스 O O O O O',
#  'O O O 제품 O O O 기술 이벤트 O O O O O O 스펙 O',
#  'O O O O 스펙 이벤트 O O O O O O 이벤트 O O 이벤트 O O 제품 O 트렌드 트렌드 O O O O O O O 이벤트 O O O O O O O O 트렌드 O O 소재 O 이벤트 O O',
#  'O O O 서비스 O O O O O 이벤트 이벤트 O 트렌드 O O O O O',
#  'O O O O O 이벤트 이벤트 O O O O O O O O O O O O O O O O O O O O 이벤트 O O O O O O O O O',
#  'O O O 이벤트 O O O O O O O 이벤트 O O 제품 O O 서비스 O O O 이벤트 O',
#  'O 이벤트 O 스펙 이벤트 O O O O',
#  'O O 이벤트 O O O O O 서비스 이벤트 O O O O 이벤트 O O O O O O O O O O O O O 이벤트 O 이벤트 O O O O O 이벤트',
#  'O O O O O 스펙 이벤트 O O O O 이벤트',
#  'O O O O O 이벤트 O O',
#  'O O O O O O O O O O 이벤트 O O 이벤트 이벤트 O O O',
#  'O O O O O O 제품 이벤트 O O O O O O O O',
#  'O O O 스펙 O O 이벤트 스펙 O O O O O O O O O 사건/사고 기술 O O',
#  'O O O O O 제품 O O O 이벤트 O 기술 O O O O O O O O O O O O O O O O O O O O 이벤트 O O O O O O O O O',
#  '기술 O O 이벤트 O 서비스 O 스펙 O O O O 이벤트 O O O O O 트렌드 O O O',
#  '기술 서비스 O 트렌드 O O O 기술 O O O',
#  'O O O O 트렌드 이벤트 O O O O O 스펙 O O O',
#  'O O O 스펙 O O O O O 사건/사고 O O 기술 이벤트',
#  'O O 이벤트 이벤트 O 기술 이벤트 O O O',
#  'O O O O O O O 이벤트 O 이벤트 스펙 O O O O O O O',
#  'O O O O O O O O O 이벤트 O O 제품 O O O O O 이벤트 O O O O',
#  'O O O 이벤트 O 기술 O O O 기술 O O O 이벤트 O O',
#  'O O 기술 O 기술 O 이벤트 O O 제품 제품 O O 서비스 O 이벤트 O O O O',
#  'O O O 이벤트 제품 O O 기술 O O 제품 O O 제품 O O',
#  'O O O O 제품 O 이벤트 기술 O O O O',
#  'O O O 기술 O O O O O 제품 제품 O 이벤트 O',
#  'O O O O O 기술 O O O O 이벤트 스펙 O O O O',
#  '기술 O 제품 O 이벤트 O O O O O O O O O O O',
#  '제품 이벤트 스펙 O 기술 O',
#  '기술 이벤트 O O',
#  '제품 이벤트 O 기술 기술 기술 O O O O 기술 이벤트 O O',
#  'O 기술 O O O 제품 O 이벤트 O O',
#  '스펙 O 제품 O O O 제품 기술 O O O O 제품 O O O',
#  'O O 기술 트렌드 이벤트 트렌드 제품 이벤트 O O O O O O 제품 이벤트 이벤트 O O',
#  'O O O O O O O O O O 제품 제품 O O O O O O O O',
#  '기술 O O O 이벤트 O O O O O O O O O',
#  '스펙 O 제품 제품 제품 O 제품 O O O O O O',
#  'O O O O O 제품 O 이벤트 O O O',
#  '기술 O O O O O O 이벤트 O',
#  'O O O O O O O O O O O 제품 이벤트 이벤트 O O O O O O O O O O O 스펙 O 이벤트 이벤트 O',
#  'O O O 스펙 O O 제품 이벤트 O O O 이벤트 O O O',
#  'O O 트렌드 소재 O 이벤트 O O 이벤트 이벤트 제품 O O 소재 O O O',
#  'O O O O O 스펙 이벤트 O O O 이벤트 O O O 제품 O O O O O O O O O O O O O',
#  'O O 제품 이벤트 O 제품 O O O O 이벤트 제품 스펙 O 이벤트 O O O O O O 이벤트 스펙 스펙 이벤트 이벤트',
#  '제품 O O O O O O 스펙 O 이벤트 스펙 이벤트 O',
#  'O O 스펙 이벤트 O O O O O O O O',
#  'O O 이벤트 O O O O O O O O O O',
#  'O O O 트렌드 O O O 이벤트 이벤트 O O 소재 제품 O 이벤트 O O O O',
#  'O O 이벤트 O O 제품 기술 O 서비스 O O O O 이벤트 O O O O O O O O 이벤트 O O O O O O O O O O O O O O',
#  'O 제품 O 제품 소재 이벤트 O O O O O 제품 O 기술 O 기술 O O 기술 O O O O O O O O O O O O',
#  'O O O O 기술 제품 스펙 O O O O O 서비스 사건/사고 O O O O O O O 기술 O 제품 O O O O O O O O',
#  'O O 기술 서비스 제품 O O O O O O',
#  'O 서비스 O O O O O 이벤트 스펙 O 제품 제품 O O 기술 O O 이벤트 O O O O',
#  '스펙 O 이벤트 O O O 이벤트 이벤트 O O O O O O 제품 O O O O O O 트렌드 기술 서비스 O O O 서비스 이벤트 이벤트',
#  'O 기술 이벤트 O O O O O O O O O O O O 이벤트 O O O O O',
#  'O O O 제품 제품 O 이벤트 O O O O',
#  'O O O O O O 사건/사고 O O 제품 제품 O O 이벤트 O 제품 기술 O 이벤트 이벤트',
#  'O 이벤트 O O O O O 제품 O O O O 이벤트 O O O O O O O O O O O',
#  'O O O O O O 이벤트 이벤트 O 제품 O O 기술 O 이벤트 O O',
#  'O O O O 제품 O O 트렌드 스펙 O O O O O O O 이벤트 O O O O O O 이벤트 O O',
#  '제품 이벤트 O O O O 이벤트 O',
#  '제품 O 이벤트 O O O O O O O O O 제품 기술 O 서비스 O 제품 O O O O O',
#  'O O O 이벤트 O O O O 이벤트 이벤트 O',
#  '이벤트 O 제품 O O O O O 이벤트 O O O O 이벤트 이벤트 O O',
#  'O 제품 O O O O O O O 기술 O 서비스 이벤트 O O O O O O O',
#  '제품 O 이벤트 제품 이벤트 O O 제품 O 제품 제품 O O 이벤트 O 서비스 O O 이벤트 제품 O O O O O O O O O O O',
#  'O O O 제품 서비스 이벤트 O 제품 O O O O 제품 O O O O O O O O',
#  'O 제품 O O O O O O 이벤트 이벤트 O',
#  '이벤트 기술 이벤트 O 트렌드 O O O 이벤트 O',
#  'O O 스펙 O O O O O O O O O',
#  'O 제품 서비스 기술 O 제품 O O O 이벤트 O O O 이벤트 O',
#  'O O O 제품 O O O O O O O O O O O',
#  'O 제품 제품 사건/사고 O 제품 O 제품 O O O 스펙 O 스펙 O O 서비스 이벤트 O O',
#  'O 제품 O O O 기술 O 이벤트',
#  'O 이벤트 O 서비스 O O O O O 제품 O 제품 O O O O',
#  '스펙 제품 O O O',
#  'O 서비스 O O O',
#  'O O O O O O O O O O O O 이벤트 O',
#  'O O O O O O O O O 제품 O 트렌드 이벤트 이벤트 O O',
#  'O 이벤트 O 제품 O O O O',
#  'O O O O 트렌드 이벤트 이벤트',
#  '트렌드 이벤트 제품 O 이벤트 스펙 이벤트 O O O O O O O O',
#  '스펙 이벤트 O O O',
#  'O O O 트렌드 이벤트 스펙 이벤트 O O O O 이벤트 O O O O',
#  'O O O O 이벤트 O O 이벤트 O O',
#  '트렌드 제품 O O O O 이벤트 이벤트 이벤트 트렌드 이벤트 O O',
#  '이벤트 O O O O O O O O O O 이벤트 O',
#  'O O 이벤트 트렌드 O O 기술 이벤트 O O 이벤트',
#  'O O O O 스펙 O O O',
#  '사건/사고 O O O O O 이벤트 스펙 O O O 이벤트 트렌드 O O O O O 소재 서비스 O 사건/사고 O O O O O O O O O 이벤트 O O 트렌드 O 이벤트 스펙 O O 이벤트 O O O 트렌드 O 이벤트 이벤트 O O O O O O O 이벤트 O 트렌드 O O 이벤트 O 스펙 O O O O 이벤트 O O 이벤트 O O O 이벤트 기술 O O 이벤트 O O 제품 O O O O O O 이벤트 O O O O O O 서비스 트렌드 O O O O 제품 이벤트 O O O',
#  'O 서비스 O O O O O O 이벤트 O O 이벤트 O O O O O O 트렌드 O O O O O O O O O 이벤트 사건/사고 O O O O O O O 이벤트 사건/사고 이벤트 제품 O O 제품 O 제품 O O O 제품 O O O 제품 제품 O O O O O 제품 O O O O O 기술 이벤트 O O O O O O 사건/사고 O O O O O 이벤트 O 이벤트 이벤트 O O O O O O 서비스 O 제품 이벤트 사건/사고 O O O O 이벤트 이벤트 O O O O O 이벤트 O O 트렌드 O O O O O O O O O O O O O O O O O O 이벤트 O O 트렌드 O O 트렌드 O 스펙 O O O O O O O 트렌드 이벤트 O 트렌드 O O 이벤트 이벤트 사건/사고 O O O 이벤트 O O O O O O O 제품 기술 O O 사건/사고 O 이벤트 O O O O O O O O',
#  'O O O 스펙 소재 이벤트 제품 O O O O 제품 이벤트',
#  'O O O 기술 O O O 사건/사고 제품 O O O O 제품 O O 이벤트 O O',
#  'O O O 트렌드 O O O O 제품 O 이벤트 O 이벤트 O O O O O 이벤트 O O O O O O O O O O O O O O O O O',
#  'O O 제품 O O O O O O O O O O',
#  'O O 트렌드 O O O O O 제품 O O O O',
#  'O O O 제품 O 트렌드 O O O 이벤트 O O O O O O O O O O O O',
#  'O O 제품 O O O O O O O O 스펙 제품 O 기술 O 기술 이벤트 O 이벤트 O 기술 O O O O O O O O O O O O 이벤트 이벤트 O O O O O O O',
#  'O O O 제품 O O 이벤트 O 스펙 제품 이벤트 O 스펙 O O O O 사건/사고 O O O 소재 O O O O O O 제품 O O O O O',
#  'O O O 스펙 이벤트 O O 트렌드 O O 서비스 O O O O O O O 이벤트 이벤트 O O',
#  '트렌드 제품 O O O O O O 이벤트 O O O O O O O O 서비스 O O O O O O O 스펙 O O O 이벤트 O',
#  '서비스 O O 스펙 O 이벤트 O O O 제품 O O O 이벤트 O O',
#  'O O O 제품 O O 서비스 스펙 O 소재 이벤트',
#  'O O O O O O O O O O O O 제품 O 서비스 O O 이벤트 O',
#  '이벤트 O O O O O O O O O O O O O O O O O O O 제품 O',
#  'O 스펙 제품 O O O O O O O O O 제품 O 이벤트 O O O 이벤트 O O',
#  'O O O O 스펙 O O O O O O O O O O O',
#  '제품 O O O O O O O 이벤트 O O O 스펙 O O',
#  'O O O O O O O O O 스펙 O 이벤트 O',
#  'O O O O O O O O O O 이벤트 O O O O O O O O O O 이벤트 O 제품 이벤트 이벤트 O O O O',
#  'O O O 서비스 서비스 O 스펙 O 소재 이벤트 O O O',
#  '이벤트 O O 제품 O O O O 스펙 O 기술 스펙 O O O O O 스펙 스펙 O O O O O O O O O O O O O 서비스 O 이벤트 O O O O',
#  'O O 이벤트 O 이벤트 제품 O 스펙 O O O O O O O O O O 이벤트 이벤트 O O O O 서비스 스펙 O O 서비스 O O O',
#  'O O 스펙 O 이벤트 O O O 서비스 O O O 이벤트 O O O O O O O 제품 O O O O O O O O O O O O',
#  'O O O O O O 이벤트 O',
#  'O O O O O O O O O 이벤트 이벤트 O O 서비스 O O O 이벤트 O O',
#  'O O 트렌드 이벤트 이벤트 O O 이벤트 O O O',
#  'O O 트렌드 이벤트 O O O 이벤트 스펙 이벤트 O O O 이벤트 O O O O O O O O O 스펙 이벤트',
#  'O O 제품 제품 제품 O O O 소재 O O 제품 O 제품 O 제품 O O O 기술 이벤트 O O O',
#  'O O O O O 이벤트 O O',
#  'O O 이벤트 O O O O O O O O 이벤트',
#  '트렌드 O O 이벤트 O 이벤트 O 이벤트 O O O',
#  'O 이벤트 O O O 트렌드 O O O 스펙 O 트렌드 O 스펙 O 이벤트',
#  'O O O O 제품 O 이벤트 O O O O O 이벤트 O',
#  'O O O 트렌드 O 트렌드 O O O O',
#  'O O O O 이벤트 O O O O O O O 트렌드 O O O O O O 트렌드 O O O 스펙 O O O 이벤트 이벤트',
#  'O 스펙 O O O O O O O O O 트렌드 O O 이벤트 O',
#  'O O O O O 이벤트 O 이벤트 O O O 기술 이벤트 이벤트 O O O O O O O',
#  'O 트렌드 이벤트 O O O O',
#  'O O O O O O 이벤트 이벤트 O O O O O O O O',
#  'O 이벤트 이벤트 O 서비스 O O O O O O',
#  '이벤트 이벤트 이벤트 O 스펙 O 트렌드 O 이벤트 O 이벤트 O O 트렌드 O O O O',
#  'O 이벤트 이벤트 이벤트 O O O O O O 서비스 이벤트 O O',
#  'O O O 제품 O O O',
#  'O O 제품 O O O O O O 이벤트 이벤트',
#  'O O 제품 O O O 기술 O O O O O',
#  'O O O O O O O O O O O 이벤트 O O O O O O O 이벤트 이벤트 O O',
#  'O O O O 제품 O O 제품 O O O O O O O O 기술 기술 이벤트 O',
#  '기술 이벤트 O O O 스펙 O 스펙 기술 이벤트 O O 제품 이벤트 O O O O 이벤트 O O O O',
#  'O O 이벤트 O O O O O O O 트렌드 O 이벤트',
#  '스펙 O O O O 기술 O O O O 트렌드 서비스 O 이벤트 O 이벤트 O O',
#  'O O 이벤트 O O O O 이벤트 제품 O O O O',
#  'O O O O O 기술 이벤트 O O O',
#  'O O 스펙 O O O O O O',
#  'O 제품 O O O 제품 O O O O',
#  'O O 스펙 O O 제품 제품 O O O O O O O 이벤트 O 제품 O O O',
#  'O O O O 스펙 O O O',
#  'O O 사건/사고 O O 제품 O O O O O',
#  'O O O O O O O O O O O 이벤트 기술 O O O 트렌드 O O 제품 이벤트 O O 소재 O O O O O O O O 스펙 O O 이벤트 O O O O O 이벤트 O O 제품 O O 제품 O 소재 O O 이벤트 O O O 제품 O O O O O 제품 O 트렌드 O O O O O O O O O O O O O O 스펙 O O 트렌드 O O O O O O O 이벤트 서비스 O O O O 소재 O O O 이벤트 O O 서비스 O O O O O O O O 소재 스펙 O 이벤트 O O O 트렌드 이벤트 O O O O O 소재 O O 이벤트 O O O O 트렌드 O 이벤트 O 기술 O O O 서비스 이벤트 O O O 제품 O O O 이벤트 이벤트 이벤트 O O O O O O 이벤트 O O O O O O O O O O O O O 이벤트 O 이벤트 O 제품 O O O O 스펙 O O O O 트렌드 O O 트렌드 O O O O 소재 트렌드 이벤트 O O O 제품 O O O O O O 서비스 O O 사건/사고 O O O O O 트렌드 O 제품 O O 이벤트 이벤트 O O O O O O 기술 O 스펙 O O 사건/사고 트렌드 O O 트렌드 이벤트 O O O 이벤트 O O O O 제품 O O O 이벤트 O O O O O 제품 O O O O O O O O O O O O O O O O O O O O O O 이벤트 O 이벤트 O O 제품 O 소재 O O O O O O 이벤트 O 사건/사고 이벤트 소재 O O 스펙 소재 O 이벤트 O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O 이벤트 소재 O O 사건/사고 이벤트 O O O O O O 서비스 O 이벤트 O O O O O O O 소재 O O O O 제품 이벤트 O 이벤트 O O O O O O O O O O O O 이벤트 O O O 이벤트 O O O O O O O O O O O O O 제품 O O O O O O O O O O O 이벤트 O O O O O O O O O O O 이벤트 O O O O 서비스 O O O O O O O O O O O O O O O O 기술 O O O O O O 이벤트 O O O O O 이벤트 O O O O O O O O 기술 O O O O 스펙 O O',
#  'O O O 이벤트 이벤트 O 기술 트렌드 이벤트 제품 O 제품 이벤트 O 이벤트 O O O O 이벤트 이벤트 O O 이벤트 O O 제품 O O O O O O O O O O O O O 이벤트 O O 사건/사고 O O O O O',
#  'O 이벤트 O O O O 이벤트 O O O 소재 이벤트 O O O 기술 이벤트 이벤트 O O O O O 이벤트 사건/사고 O 기술 O O O 제품 이벤트 제품 O O O O O 제품 O O O O O 스펙 트렌드 O O 트렌드 O 이벤트 O O O',
#  'O O O 이벤트 제품 이벤트 O O 이벤트 O O O 소재 O 이벤트 이벤트 O O 제품 O O O O O O 이벤트 O O O O O O 기술 O O O 이벤트 O O O O O O O O O 기술 O O 소재 스펙 이벤트 이벤트 O O O 트렌드 이벤트 O O O O O O O O O O',
#  '스펙 O O O O 제품 O O O O',
#  'O O O O O 서비스 O 제품 이벤트 O 트렌드 O 이벤트 O O O 이벤트 O O 이벤트 이벤트 O O O O O O O 이벤트 이벤트 O O O O O O 트렌드 이벤트 O O O O 스펙 O O O O O O O 제품 O 이벤트 O O O O O O O O O O O O 소재 O O O 이벤트 O O O O O 이벤트 이벤트 O O O 기술 제품 소재 O O 기술 기술 O O O O 소재 제품 O 이벤트 O O O O O O O O 이벤트 O 트렌드 이벤트 O O O O O O O 제품 이벤트 O O O O O 이벤트 기술 트렌드 서비스 O O 이벤트 O O O 서비스 O 이벤트 사건/사고 O O O O O 이벤트 이벤트 O 이벤트 제품 O O O O O 제품 O O O O O O O 이벤트 O O O 스펙 이벤트 O O O O O O O O O 제품 O O O O O O 이벤트 O 제품 O O O O 제품 O O 스펙 O O O 이벤트 O O O O 스펙 O O 서비스 O 트렌드 이벤트 O O 트렌드 O O O O O 트렌드 사건/사고 제품 O O O O 사건/사고 O O O O O O O O O 트렌드 O O O 소재 O 이벤트 O O 트렌드 O O 기술 트렌드 기술 O 이벤트 O O O 제품 O 제품 O 스펙 O O O O O O O O O O O',
#  '트렌드 O O O 사건/사고 O O O O 서비스 O 소재 이벤트 소재 O O O O O O O O 사건/사고 O O O O O O O O O 제품 O O O 이벤트 이벤트 O 제품 O O O 제품 O O 스펙 O 기술 스펙 이벤트 이벤트 이벤트 O O O O 제품 O O O 이벤트 O O O 기술 O 제품 이벤트 O 이벤트 O 트렌드 스펙 O O O O 이벤트 O O 트렌드 O O 이벤트 O O O O O O 이벤트 O O O O O O O O 소재 O O 제품 이벤트 O O O 소재 O O 이벤트 스펙 O O O O O O O O O O O O O O O O O 스펙 O O O O 기술 O O 서비스 O O O O O O O O O 소재 제품 O O O O O O 트렌드 사건/사고 이벤트 이벤트 O O O O O 이벤트 O O O O O O O O 스펙 O O 사건/사고 제품 스펙 O O O O O O O O O O O O O O O O O O O 이벤트 O O O O O 제품 제품 O O O O 트렌드 O O O 이벤트 O O O O O O O O O O O O 트렌드 O O O O O O O O O 이벤트 O 이벤트 O O 기술 O 사건/사고 O O O O 제품 O O O O 트렌드 O O 트렌드 O 이벤트 O O O 제품 O O O O O O O O O O O O O O O O O O O O 이벤트 O O O O O 제품 사건/사고 O O 이벤트 O O O O O 소재 O O 사건/사고 O O O O O O O O O O 이벤트 스펙 O O O 이벤트 트렌드 O O O O O O 서비스 O 사건/사고 O O O O O O O O O O O O O O 이벤트 스펙 O O 이벤트 O O O 트렌드 O 이벤트 이벤트 O O O O O O O 이벤트 O O O O 이벤트 O 스펙 O O O O O O O 이벤트 O O O 이벤트 O O O 이벤트 O O 제품 O O O O O O 이벤트 O O O O O O 서비스 O O O O O 제품 O O O O',
#  'O 서비스 O O O O O O 이벤트 O O 이벤트 O O O O O O 트렌드 O O O O O O O O O 이벤트 사건/사고 O O O O O O O 이벤트 사건/사고 이벤트 제품 O O 제품 O 제품 O O O 제품 O O O 제품 제품 O O O O O 제품 O O O O O 기술 이벤트 O O O O O O 사건/사고 O O O O O 이벤트 O 이벤트 이벤트 O O O O O O 서비스 O 제품 이벤트 사건/사고 O O O O 이벤트 이벤트 O O O O O 이벤트 O O 트렌드 O O O O O O O O O O O O O O O O O O 이벤트 O O 트렌드 O O 트렌드 O 스펙 O O O O O O O 트렌드 이벤트 O 트렌드 O O 이벤트 이벤트 사건/사고 O O O 이벤트 O O O O O O O 제품 기술 O O 사건/사고 O 이벤트 O O O O O O O O',
#  'O O O 스펙 소재 이벤트 제품 O O O O 제품 이벤트 O',
#  'O O O O O O O O 서비스 O O O O O O O O O 트렌드 O O O O O 이벤트 제품 O O O O O O O 이벤트 트렌드 O O 소재 O 이벤트 제품 O O O 서비스 O O 이벤트 O O O O 이벤트 O 이벤트 O O O O O O 사건/사고 O O 트렌드 O O O O O 사건/사고 O 제품 O 제품 O O O O O 이벤트 소재 O 이벤트 O 스펙 O O O O O 기술 스펙 O O 제품 사건/사고 O O O O O O 이벤트 O O O O O O O O O O O 스펙 O O 트렌드 O O O O 스펙 O O 이벤트 이벤트 O O O O O 이벤트 이벤트 트렌드 O O O O 스펙 이벤트 O 이벤트 O O O 제품 이벤트 O O O O O O O O O O O 이벤트 트렌드 O O O O O O O 트렌드 O O O O 이벤트 O O O O O O 사건/사고 O O O O O O 사건/사고 O O O O O O O O 이벤트 O O 서비스 스펙 O O 제품 이벤트 O O O O 트렌드 O O 트렌드 O O 트렌드 O 이벤트 O O O',
#  'O O O O 스펙 이벤트 O 이벤트 O O O O O O',
#  'O O O 이벤트 이벤트 O O O O O O 이벤트 O O O O O O O O O O O O 기술 O 기술 서비스 이벤트',
#  'O 소재 O O O O 이벤트 이벤트 O O O 서비스 O O 기술 기술 O O O 스펙 서비스 O O 이벤트 O O O O O O O',
#  'O 이벤트 소재 O O O O 스펙 O 이벤트 O O O O 기술 O O O O O O 제품 O O O O 이벤트 O 소재',
#  'O O O 이벤트 O O O O O 이벤트 O O O',
#  'O O O 이벤트 서비스 O O O 서비스 O O O 스펙 기술 이벤트 O O O O O O O O O O O O O O O O O O',
#  'O O 스펙 소재 O 기술 스펙 제품 O O 서비스 O 스펙 O 스펙 이벤트 O 서비스 O O O 이벤트 O 서비스 O O O O O 기술 기술 O O O',
#  'O O O O O 제품 소재 이벤트 O O',
#  'O O O 이벤트 O O O O 소재 O 트렌드 O 이벤트 O',
#  '소재 O O O O',
#  '이벤트 O 제품 이벤트 O O O 제품 제품 O 스펙 O O O O O O O O O O O O O O',
#  'O O 소재 O O 스펙 제품 O O O O O O',
#  'O O 스펙 O',
#  '스펙 제품 O 스펙 O O O O O O O O O O O O O O O O',
#  '스펙 O O 제품 스펙 O 제품 이벤트',
#  'O 제품 O O O O O O 제품 O 기술 O O O 스펙 O O O',
#  'O O O 스펙 제품 O O O O O O O O O O 스펙 O 제품 O O O O O O 이벤트',
#  '제품 O O O O O O O 이벤트 O O O O O O O O O',
#  'O 사건/사고 사건/사고 O 스펙 사건/사고 서비스 스펙 O O O O 이벤트 O O O O O O O 스펙 O O 제품 O 이벤트',
#  'O 소재 O 제품 O O O O O O 스펙 O',
#  'O O O O O 서비스 O 트렌드 스펙 O O O',
#  'O O O O O O O 이벤트 소재 이벤트 O O O',
#  '제품 O 소재 이벤트 O O O O O O O O O O 스펙 O',
#  'O O 제품 스펙 O O',
#  '제품 스펙 O O O O O 사건/사고 O O O O',
#  'O O 스펙 제품 O O O 스펙 O O O O O O O O O O O O O',
#  'O 서비스 스펙 O 이벤트 제품 O O O O O O O O O O O O O O O O O O O O O O',
#  'O O 이벤트 O O O 제품 트렌드 O O O O O O 이벤트 O',
#  'O O O O 스펙 O O O',
#  'O O 제품 O 트렌드 서비스 기술 O O 이벤트 스펙 O O 제품 O O 이벤트 O',
#  'O O O O 제품 O O O O 트렌드 O O O O O O O 이벤트 O 스펙 O O',
#  '서비스 O O 기술 O O O 이벤트 O O O O O 이벤트 O O O O 소재 제품 O 이벤트 O O O',
#  '제품 트렌드 스펙 O O O O O O O O O O O O O',
#  '소재 O O O 기술 O O O 이벤트 O O 이벤트',
#  '서비스 이벤트 스펙 O 기술 기술 O O 제품 제품 O O 스펙 O 이벤트',
#  '제품 O O O O 기술 제품 이벤트 O O O O',
#  '스펙 O O O O O 기술 O O O O',
#  'O O 기술 O O O 이벤트',
#  '제품 O O O O O O',
#  '기술 제품 서비스 기술 스펙 O 스펙 O O 이벤트 O O',
#  'O 이벤트 이벤트 O 서비스 O O O 이벤트',
#  '제품 O O 이벤트 이벤트 기술 이벤트 O O O O',
#  'O 기술 O O 소재 O O O O O 이벤트 O',
#  '스펙 O O 이벤트 기술 제품 O O 이벤트 O O O O O O 이벤트 O O 제품 O 스펙 O O O O O O O O O O 이벤트 O O',
#  'O 이벤트 사건/사고 O O 제품 O O O O O O 이벤트 O',
#  '제품 O O O O 이벤트 O',
#  'O 스펙 O O 스펙 O O O O O O',
#  'O 이벤트 제품 O 제품 O 제품 제품 기술 제품 O O O O O',
#  'O 제품 이벤트 이벤트 O O O O O O O O O O O O O',
#  'O 이벤트 O O 이벤트 O O O O O 이벤트',
#  'O O O O O O O 이벤트 O O O',
#  'O O O 트렌드 O 제품 O O O',
#  '트렌드 O O 이벤트 O O 제품 O O O O',
#  '제품 O O 제품 O O O',
#  'O O O O O O 이벤트 O O O 트렌드 O O O 제품 O 사건/사고 O 스펙',
#  'O 트렌드 O O O 이벤트 O O O',
#  'O 이벤트 O O O 이벤트 O O O 제품 O 이벤트 O O',
#  'O O 이벤트 O',
#  'O O O 제품 O O O 제품 O O O O 이벤트 기술',
#  'O 제품 O 제품 O O O 기술 O',
#  'O O O 제품 제품 O 제품 O O O 이벤트 O O',
#  'O O O 이벤트 O O',
#  '제품 O O 스펙 트렌드 O O O O O',
#  '이벤트 이벤트 O 제품 O O O O O O O O 이벤트',
#  '기술 O O O O 기술 O O O',
#  'O O 이벤트 O O O O O 기술 O 이벤트',
#  'O O 제품 O 제품 기술 O O 이벤트 O 제품 O O O 이벤트 O',
#  '제품 스펙 트렌드 제품 O 제품 O O O O',
#  'O O 트렌드 O O O 스펙 O O O 제품 제품 O O O O O',
#  ...]

# %%
# Train 
'''
with open('LGES_sent_210811.dta', 'wb') as a_sent:
    pickle.dump(article_sent, a_sent)
with open('LGES_sent_ner_level1_210811.dta', 'wb') as a_sent_l1:
    pickle.dump(article_ner_l1, a_sent_l1)   
with open('LGES_sent_ner_level2_210811.dta', 'wb') as a_sent_l2:
    pickle.dump(article_ner_l2, a_sent_l2)  
with open('LGES_label_l1_210811.dta', 'wb') as a_label1:
    pickle.dump(label_ner_l1, a_label1)
'''
# Test 
with open('Test_LGES_sent_210811.dta', 'wb') as a_sent:
    pickle.dump(article_sent, a_sent)
with open('Test_LGES_sent_ner_level1_210811.dta', 'wb') as a_sent_l1:
    pickle.dump(article_ner_l1, a_sent_l1)   
with open('Test_LGES_label_l1_210811.dta', 'wb') as a_label1:
    pickle.dump(label_ner_l1, a_label1)

# %%
label_ner_l1
# Out:
# ['UNK',
#  '기술-B',
#  '기술-I',
#  '사건/사고-B',
#  '사건/사고-I',
#  '서비스-B',
#  '서비스-I',
#  '소재-B',
#  '소재-I',
#  '스펙-B',
#  '스펙-I',
#  '이벤트-B',
#  '이벤트-I',
#  '제품-B',
#  '제품-I',
#  '트렌드-B',
#  '트렌드-I']

# %%
print('총 %d 개 문장'%len(article_ner_l1))
article_ner_l1[0]
# Out:
# 총 605785 개 문장
# 'O O O O O O O O O O O O O O O O O O O'

# %%
tmp_total_sent = ' '.join(artice_ner_l1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-53c7917ed62b> in <module>
# ----> 1 tmp_total_sent = ' '.join(artice_ner_l1)
#
# NameError: name 'artice_ner_l1' is not defined

# %%
for k in range(0, db_tab.shape[0]):
    tmp_ = kss.split_sentences(db_tab[5].iloc[k])
    #print(k)
    for l in range(0, len(tmp_)):
        if tmp_[l][:16] == "기아로 서 는 큰 결단 을 내":
            print(k, l)

# %%
tmp_ = kss.split_sentences(db_tab[5][1])
print(tmp_[18])
# Out:
# 포스코인터내셔널의 곡물 교역량은 2015년 84만 톤에서 지난해 약 800만 톤으로 10배가량 늘었다.

# %%
db_tab[5].iloc[24]#, :]
# Out:
# '르노삼성자동차는 2022년형 XM3에 탑재한 인카페이먼트에 CU 편의점 서비스 기능을 16일부터 추가한다고 밝혔다.\n\nXM3 인카페이먼트 편의점 서비스는 전국 1000여개 CU 편의점에서 이용할 수 있다. 차량 안에서 필요한 편의점 판매 상품이 있을 경우 XM3 내비게이션 화면에서 모빌리티 커머스 플랫폼 오윈 애플리케이션(앱)을 통해 주문할 수 있다.\n\n\n\n주문을 실행하면 해당 편의점까지 길 안내를 제공하며 도착 후 점원 호출 기능으로 차량 안에서 상품을 받을 수 있다. 편의점 직원에게 실시간 교통상황을 반영한 고객 도착 예정 시간 정보를 전달, 상품을 미리 준비할 수 있도록 시스템 업데이트도 진행할 예정이다.\n\nXM3 인카페이먼트 편의점 서비스로 구매 가능한 상품은 삼각김밥과 샐러드, 음료 등 간단한 식음료부터 도시락, 생활용품까지 다양하다. 이달의 핫 이슈 상품이나 세트 메뉴, 할인 상품 등도 파악할 수 있다. 편의점별로 구매 가능한 상품은 다를 수 있으며 주류나 담배 구매 서비스는 제공하지 않는다.\n\n\n\n김태준 르노삼성차 영업마케팅 본부장은 “CU 편의점 서비스 기능 추가로 물건을 구매할 때 대면 접촉과 구매 시간을 최소화할 수 있게 됐다”고 말했다.\n\n\n\n정치연기자 '

# %%
db_tab
# Out:
#                 1       2                                                  4  \
# 0      2021-07-16    서울경제  2년 넘게 벌여온 배터리 전쟁의 종지부를 찍은 LG와 SK가 이번엔 습식 분리막 시...
# 1      2021-07-16    서울경제  우리나라 경제 성장기에 수출 역군으로 활약했던 종합상사가 환골탈태에 나서고 있다. ...
# 2      2021-07-16    한국경제  정의선 현대자동차그룹 회장(사진)이 한 달 만에 다시 미국 출장에 나섰다. 미국 시...
# 3      2021-07-16    매일경제  세계 전기차 배터리 제조 업체들이 전기차용 배터리 주요 재료인 코발트 가격 상승에 ...
# 4      2021-07-16    한국경제  르노삼성자동차가 소형 스포츠유틸리티차량(SUV) XM3 2022년형에 탑재된 '인카...
# ...           ...     ...                                                ...
# 28496  2020-07-16    동아일보  “경찰 예산 삭감하라.” “정의 없이 평화도 없다.” \n \n 미국 독립기념일이던...
# 28497  2020-07-16    중앙일보  “내 절친이 신종 코로나바이러스 감염증(코로나19)으로 세상을 떠났다. 놀라고 슬프...
# 28498  2020-07-16  파이낸셜뉴스  21일께 현대차 남양연구소 방문 \n\n \n\n \n이재용 삼성전자 부회장이 다음...
# 28499  2020-07-16  파이낸셜뉴스  경북도, GS건설 등 55개 기업과 \n투자양해각서 작년比 22건 늘어 \n\n \...
# 28500  2020-07-16   헤럴드경제  [헤럴드경제=이진용 기자]와이앤지(대표 송호영)는 지난 4월 일본 최대 조명기기 전...
#
#                                                        5
# 0      viewer 신학철 LG화학 부회장이 14일 열린 온라인 기자 간담회에서 3대 신성...
# 1      < 저작권자 ⓒ 서울경제, 무단 전재 및 재배포 금지 >\n\n우리나라 경제 성장기...
# 2      귀국길 日들러 양궁대표팀 응원\n\n정의선 현대자동차그룹 회장(사진)이 한 달 만에...
# 3      \n\n\n\n세계 전기차·배터리 제조 업체들이 전기차용 배터리 주요 재료인 코발트...
# 4      전국 1000여개 CU편의점서 이용 가능\n\n르노삼성 "제휴 업체, 범위 늘릴 것...
# ...                                                  ...
# 28496  지난달 9일 미네소타주 미니애폴리스 시민들이 ‘경찰 예산을 삭감하라’라고 적힌 대형...
# 28497  친했던 여성 화가 코로나로 숨져\n\n노래에 그리움과 희망 담고 싶어\n\n참여한 ...
# 28498  21일께 현대차 남양연구소 방문\n\n\n\n이재용 삼성전자 부회장이 다음 주 현대...
# 28499  경북도, GS건설 등 55개 기업과\n\n투자양해각서… 작년比 22건 늘어\n\n\...
# 28500  스탠리전기서 개발 광학소재 탑재 자동차 헤드램프 상용화 예정\n\n와이앤지, 스탠리...
#
# [28442 rows x 4 columns]
